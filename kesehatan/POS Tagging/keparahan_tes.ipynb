# %%
from nltk.tag import CRFTagger
import pandas as pd
from nltk import word_tokenize
import re
import random

# %%
df = pd.read_csv('df_train_noPre.csv')
df.head()
# Out:
#                                                title  \
# 0  Pemprov DKI Siapkan Suntik ORI untuk Atasi Dif...
# 1  KLB Rabies di Sumbawa: 149 Orang Digigit Anjin...
# 2  11 Provinsi Nihil Tambahan, Ini Sebaran 254 Ka...
# 3  Kerabat Virus Corona Menyebabkan Penyakit di I...
# 4  Masih Trauma, Imunisasi Difteri Ponpes di Jemb...
#
#                             date  \
# 0   Jumat, 08 Des 2017 16:38 WIB
# 1  Jumat, 24 Mei  2019 10:05 WIB
# 2  Senin, 09 Mei  2022 16:57 WIB
# 3    Rabu, 29 Jan 2020 14:53 WIB
# 4   Kamis, 01 Mar 2018 16:05 WIB
#
#                                          description         source
# 0  \- Pemprov DKI Jakarta akan melaksanakan progr...  www.detik.com
# 1  \- Kabupaten Sumbawa di Nusa Tenggara Barat (N...  www.detik.com
# 2  \-\n\nPemerintah melaporkan kasus harian posit...  www.detik.com
# 3  \-\n\nPerkembangan virus corona di Indonesia m...  www.detik.com
# 4  \- Pihak SMK Madinatul Ulum, Jember, akhirnya ...  www.detik.com

# %%
ct =CRFTagger()
ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')
def preprocessing(berita):
    s = berita
    s = s.replace('\n', ' ')
    s = s.replace('\r', ' ')
    s = s.replace('COVID-19', ' ')
    s = s.replace('covid 19', ' ')
    s = s.replace('SARS-CoV-2', ' ')
    s=re.sub("\(.*?\)", "", s)
    # s = s.lower()
    tokens = word_tokenize(s)
    return tokens

# %%
def structureCheck(indeks,arr):
    if(arr[0][indeks][1]=='VB' or arr[0][indeks][1]=='IN' or arr[0][indeks][1]=='NN' or arr[0][indeks][1]=='NNP' or arr[0][indeks][1]=='SC' or arr[0][indeks][1]=='JJ' or arr[0][indeks][1]=='PR'  or arr[0][indeks][1]=='NND'  or arr[0][indeks][1]=='RB'  or arr[0][indeks][1]=='SYM'  or arr[0][indeks][1]=='RP' or arr[0][indeks][1]=='PRP' or arr[0][indeks][1]=='DT' or arr[0][indeks][1]=='FW' or arr[0][indeks][1]=='MD' or arr[0][indeks][1]=='NEG' or arr[0][indeks][1]=='UH' or arr[0][indeks][1]=='VH'):
        return 1
    else:
        return 0
def cdStructureCheck(indeks,arr):
    if(arr[0][indeks][1]=='CD' or arr[0][indeks][1]=='OD' or arr[0][indeks][0]=='Sang' or arr[0][indeks][0]=='sang' or arr[0][indeks][0]=='Seorang'  or arr[0][indeks][0]=='seorang'  or arr[0][indeks][0]=='seseorang' or arr[0][indeks][0]=='Seseorang' or arr[0][indeks][0]=='Empat' or arr[0][indeks][0]=='Lima' or arr[0][indeks][0]=='Enam' or arr[0][indeks][0]=='Tujuh' or arr[0][indeks][0]=='Delapan' or arr[0][indeks][0]=='Sembilan' or arr[0][indeks][0]=='Sepuluh'  or arr[0][indeks][0]=='Pasangan'  or arr[0][indeks][0]=='pasangan'  or arr[0][indeks][0]=='belasan'  or arr[0][indeks][0]=='Belasan'):
        return 1
    else:
        return 0

# %%
def struktur1(arr,indeks):
    
    if(indeks-2>=0 
        and cdStructureCheck(indeks-1,arr) 
        and cdStructureCheck(indeks-2,arr)):
        return (arr[0][indeks-2][0] + ' ' + arr[0][indeks-1][0])
    elif(indeks+2<=len(arr[0])-1 
        and cdStructureCheck(indeks+1,arr) 
        and cdStructureCheck(indeks+2,arr)):
        return (arr[0][indeks+1][0] + ' ' + arr[0][indeks+2][0])
    elif(indeks-1>=0 
        and cdStructureCheck(indeks-1,arr)):
        return arr[0][indeks-1][0]
    elif(indeks+1<=len(arr[0])-1 
        and cdStructureCheck(indeks+1,arr)):
        return arr[0][indeks+1][0]
    elif(indeks-3>=0 
        and structureCheck(indeks-1,arr) 
        and cdStructureCheck(indeks-2,arr) and cdStructureCheck(indeks-3,arr)):
        return (arr[0][indeks-3][0] + ' ' + arr[0][indeks-2][0])
    elif(indeks+3<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) 
        and cdStructureCheck(indeks+2,arr) and cdStructureCheck(indeks+3,arr)):
        return (arr[0][indeks+2][0] + ' ' + arr[0][indeks+3][0])
    elif(indeks-2>=0 
        and structureCheck(indeks-1,arr) 
        and cdStructureCheck(indeks-2,arr)):
        return arr[0][indeks-2][0]
    elif(indeks+2<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) 
        and cdStructureCheck(indeks+2,arr)):
        return arr[0][indeks+2][0]
    elif(indeks-4>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) 
        and cdStructureCheck(indeks-3,arr) and cdStructureCheck(indeks-4,arr)):
        return (arr[0][indeks-4][0] + ' ' + arr[0][indeks-3][0])
    elif(indeks+4<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) 
        and cdStructureCheck(indeks+3,arr) and cdStructureCheck(indeks+4,arr)):
        return (arr[0][indeks+3][0] + ' ' + arr[0][indeks+4][0])
    elif(indeks-3>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) 
        and cdStructureCheck(indeks-3,arr)):
        return arr[0][indeks-3][0]
    elif(indeks+3<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) 
        and cdStructureCheck(indeks+3,arr)):
        return arr[0][indeks+3][0]
    elif(indeks-5>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) 
        and cdStructureCheck(indeks-4,arr) and cdStructureCheck(indeks-5,arr)):
        return (arr[0][indeks-5][0] + ' ' + arr[0][indeks-4][0])
    elif(indeks+5<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) 
        and cdStructureCheck(indeks+4,arr) and cdStructureCheck(indeks+5,arr)):
        return (arr[0][indeks+4][0] + ' ' + arr[0][indeks+5][0])
    elif(indeks-4>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) 
        and cdStructureCheck(indeks-4,arr)):
        return arr[0][indeks-4][0]
    elif(indeks+4<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) 
        and cdStructureCheck(indeks+4,arr)):
        return arr[0][indeks+4][0]
    elif(indeks-6>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and cdStructureCheck(indeks-5,arr) and cdStructureCheck(indeks-6,arr)):
        return (arr[0][indeks-6][0] + ' ' + arr[0][indeks-5][0])
    elif(indeks+6<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and cdStructureCheck(indeks+5,arr) and cdStructureCheck(indeks+6,arr)):
        return (arr[0][indeks+5][0] + ' ' + arr[0][indeks+6][0])
    elif(indeks-5>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and cdStructureCheck(indeks-5,arr)):
        return arr[0][indeks-5][0]
    elif(indeks+5<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and cdStructureCheck(indeks+5,arr)):
        return arr[0][indeks+5][0]
    elif(indeks-7>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) 
        and cdStructureCheck(indeks-6,arr) and cdStructureCheck(indeks-7,arr)):
        return (arr[0][indeks-7][0] + ' ' + arr[0][indeks-6][0])
    elif(indeks+7<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) 
        and cdStructureCheck(indeks+6,arr) and cdStructureCheck(indeks+7,arr)):
        return (arr[0][indeks+6][0] + ' ' + arr[0][indeks+7][0])
    elif(indeks-6>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) 
        and cdStructureCheck(indeks-6,arr)):
        return arr[0][indeks-6][0]
    elif(indeks+6<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) 
        and cdStructureCheck(indeks+6,arr)):
        return arr[0][indeks+6][0]
    elif(indeks-8>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) 
        and cdStructureCheck(indeks-7,arr) and cdStructureCheck(indeks-8,arr)):
        return (arr[0][indeks-8][0] + ' ' + arr[0][indeks-7][0])
    elif(indeks+8<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) 
        and cdStructureCheck(indeks+7,arr) and cdStructureCheck(indeks+8,arr)):
        return (arr[0][indeks+7][0] + ' ' + arr[0][indeks+8][0])
    elif(indeks-7>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) 
        and cdStructureCheck(indeks-7,arr)):
        return arr[0][indeks-7][0]
    elif(indeks+7<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) 
        and cdStructureCheck(indeks+7,arr)):
        return arr[0][indeks+7][0]
    elif(indeks-9>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) 
        and cdStructureCheck(indeks-8,arr) and cdStructureCheck(indeks-9,arr)):
        return (arr[0][indeks-9][0] + ' ' + arr[0][indeks-8][0])
    elif(indeks+9<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) 
        and cdStructureCheck(indeks+8,arr) and cdStructureCheck(indeks+9,arr)):
        return (arr[0][indeks+8][0] + ' ' + arr[0][indeks+9][0])
    elif(indeks-8>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) 
        and cdStructureCheck(indeks-8,arr)):
        return arr[0][indeks-8][0]
    elif(indeks+8<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) 
        and cdStructureCheck(indeks+8,arr)):
        return arr[0][indeks+8][0]
    elif(indeks-10>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and cdStructureCheck(indeks-9,arr) and cdStructureCheck(indeks-10,arr)):
        return (arr[0][indeks-10][0] + ' ' + arr[0][indeks-9][0])
    elif(indeks+10<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and cdStructureCheck(indeks+9,arr) and cdStructureCheck(indeks+10,arr)):
        return (arr[0][indeks+9][0] + ' ' + arr[0][indeks+10][0])
    elif(indeks-9>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and cdStructureCheck(indeks-9,arr)):
        return arr[0][indeks-9][0]
    elif(indeks+9<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and cdStructureCheck(indeks+9,arr)):
        return arr[0][indeks+9][0]
    elif(indeks-11>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) 
        and cdStructureCheck(indeks-10,arr) and cdStructureCheck(indeks-11,arr)):
        return (arr[0][indeks-11][0] + ' ' + arr[0][indeks-10][0])
    elif(indeks+11<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) 
        and cdStructureCheck(indeks+10,arr) and cdStructureCheck(indeks+11,arr)):
        return (arr[0][indeks+10][0] + ' ' + arr[0][indeks+11][0])
    elif(indeks-10>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) 
        and cdStructureCheck(indeks-10,arr)):
        return arr[0][indeks-10][0]
    elif(indeks+10<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) 
        and cdStructureCheck(indeks+10,arr)):
        return arr[0][indeks+10][0]
    elif(indeks-12>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) 
        and cdStructureCheck(indeks-11,arr) and cdStructureCheck(indeks-12,arr)):
        return (arr[0][indeks-12][0] + ' ' + arr[0][indeks-11][0])
    elif(indeks+12<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) 
        and cdStructureCheck(indeks+11,arr) and cdStructureCheck(indeks+12,arr)):
        return (arr[0][indeks+11][0] + ' ' + arr[0][indeks+12][0])
    elif(indeks-11>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) 
        and cdStructureCheck(indeks-11,arr)):
        return arr[0][indeks-11][0]
    elif(indeks+11<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) 
        and cdStructureCheck(indeks+11,arr)):
        return arr[0][indeks+11][0]
    elif(indeks-13>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) 
        and cdStructureCheck(indeks-12,arr) and cdStructureCheck(indeks-13,arr)):
        return (arr[0][indeks-13][0] + ' ' + arr[0][indeks-12][0])
    elif(indeks+13<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) 
        and cdStructureCheck(indeks+12,arr) and cdStructureCheck(indeks+13,arr)):
        return (arr[0][indeks+12][0] + ' ' + arr[0][indeks+13][0])
    elif(indeks-12>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) 
        and cdStructureCheck(indeks-12,arr)):
        return arr[0][indeks-12][0]
    elif(indeks+12<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) 
        and cdStructureCheck(indeks+12,arr)):
        return arr[0][indeks+12][0]
    elif(indeks-14>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) and structureCheck(indeks-12,arr) 
        and cdStructureCheck(indeks-13,arr) and cdStructureCheck(indeks-14,arr)):
        return (arr[0][indeks-14][0] + ' ' + arr[0][indeks-13][0])
    elif(indeks+14<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) and structureCheck(indeks+12,arr) 
        and cdStructureCheck(indeks+13,arr) and cdStructureCheck(indeks+14,arr)):
        return (arr[0][indeks+13][0] + ' ' + arr[0][indeks+14][0])
    elif(indeks-13>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) and structureCheck(indeks-12,arr) 
        and cdStructureCheck(indeks-13,arr)):
        return arr[0][indeks-13][0]
    elif(indeks+13<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) and structureCheck(indeks+12,arr) 
        and cdStructureCheck(indeks+13,arr)):
        return arr[0][indeks+13][0]
    elif(indeks-15>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) and structureCheck(indeks-12,arr) 
        and structureCheck(indeks-13,arr) 
        and cdStructureCheck(indeks-14,arr) and cdStructureCheck(indeks-15,arr)):
        return (arr[0][indeks-15][0] + ' ' + arr[0][indeks-14][0])
    elif(indeks+15<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) and structureCheck(indeks+12,arr) 
        and structureCheck(indeks+13,arr) 
        and cdStructureCheck(indeks+14,arr) and cdStructureCheck(indeks+15,arr)):
        return (arr[0][indeks+14][0] + ' ' + arr[0][indeks+15][0])
    elif(indeks-14>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) and structureCheck(indeks-12,arr) 
        and structureCheck(indeks-13,arr) 
        and cdStructureCheck(indeks-14,arr)):
        return arr[0][indeks-14][0]
    elif(indeks+14<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) and structureCheck(indeks+12,arr) 
        and structureCheck(indeks+13,arr) 
        and cdStructureCheck(indeks+14,arr)):
        return arr[0][indeks+14][0]
    elif(indeks-15>=0 
        and structureCheck(indeks-1,arr) and structureCheck(indeks-2,arr) and structureCheck(indeks-3,arr) and structureCheck(indeks-4,arr) 
        and structureCheck(indeks-5,arr) and structureCheck(indeks-6,arr) and structureCheck(indeks-7,arr) and structureCheck(indeks-8,arr) 
        and structureCheck(indeks-9,arr) and structureCheck(indeks-10,arr) and structureCheck(indeks-11,arr) and structureCheck(indeks-12,arr) 
        and structureCheck(indeks-13,arr) and structureCheck(indeks-14,arr) 
        and cdStructureCheck(indeks-15,arr)):
        return arr[0][indeks-15][0]
    elif(indeks+15<=len(arr[0])-1 
        and structureCheck(indeks+1,arr) and structureCheck(indeks+2,arr) and structureCheck(indeks+3,arr) and structureCheck(indeks+4,arr) 
        and structureCheck(indeks+5,arr) and structureCheck(indeks+6,arr) and structureCheck(indeks+7,arr) and structureCheck(indeks+8,arr) 
        and structureCheck(indeks+9,arr) and structureCheck(indeks+10,arr) and structureCheck(indeks+11,arr) and structureCheck(indeks+12,arr) 
        and structureCheck(indeks+13,arr) and structureCheck(indeks+14,arr) 
        and cdStructureCheck(indeks+15,arr)):
        return arr[0][indeks+15][0]
    else:
        return 1

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False

# %%
def convertTeks(string):
    string = string.lower()
    string = string.split()
    string = [x.replace(',','.') for x in string]
    
    arr = []

    if(len(string)==2 and isfloat(string[0])==True  and string[1]=='juta'):
        hasil="{:.0f}".format(float(string[0])*1000000)
        arr.append(hasil)
    elif(len(string)==2 and isfloat(string[0])==True  and string[1]=='ribu'):
        hasil="{:.0f}".format(float(string[0])*1000)
        arr.append(hasil)
    elif(len(string)==2 and isfloat(string[0])==True  and string[1]=='miliar'):
        hasil="{:.0f}".format(float(string[0])*1000000000)
        arr.append(hasil)
    elif(len(string)==2 and isfloat(string[0])==True  and string[1]=='triliun'):
        hasil="{:.0f}".format(float(string[0])*1000000000000)
        arr.append(hasil)
    elif(len(string)==2 and isfloat(string[0])==True  and string[1]=='ratus'):
        hasil="{:.0f}".format(float(string[0])*100)
        arr.append(hasil)
    # elif(len(string)==2 and isfloat(string[0])==True  and string[1]=='belas'):
    #     hasil="{:.0f}".format(float(string[0])*10)
    #     arr.append(hasil)
    # elif(len(string)==2 and isfloat(string[0])==True  and string[1]=='belas'):
    #     hasil="{:.0f}".format(float(string[0])*0)
    #     arr.append(hasil)
    else:
        print('masuk sii2')
        for teks in string:
            print(teks, type(teks))
            if(teks[-1:]=='%' and (teks[:-1].isdigit() or isfloat(teks[:-1])==True)):
                arr.append(str(teks))
            elif(len(teks)==5 and teks[2]=='.' and isfloat(teks)==True):
                arr.append(str(1))
            elif(len(teks)>=5 and teks[-4]=='.' and isfloat(teks)==True):
                teks=teks.replace('.','')
                arr.append(teks)
            elif(teks=="2010" or teks=="2011" or teks=="2012" or teks=="2013" or teks=="2014" or teks=="2015" or teks=="2016" or teks=="2017" or teks=="2018" or teks=="2019" or teks=="2020" or teks=="2021" or teks=="2022"):
                print('masuk sii')
                arr.append(str(1))
            elif(isfloat(teks)==True):
                arr.append(teks)
            elif(teks=="satu" or teks=="seorang" or teks=="seseorang" or teks=="sesosok" or teks=="sang" or teks=="sedikit" or teks=="suatu" or teks=='pertama' or teks=='sebagian' or teks=='paruh'):
                arr.append(str(1))
            elif(teks=="dua" or teks=="kedua" or teks=="keduanya" or teks=="pasangan" or teks=='ke-2'):
                arr.append(str(2))
            elif(teks=="tiga" or teks=="ketiga" or teks=='ke-3'):
                arr.append(str(3))
            elif(teks=="empat" or teks=="keempat" or teks=='ke-4'):
                arr.append(str(4))
            elif(teks=="lima" or teks=="kelima" or teks=='ke-5'):
                arr.append(str(5))
            elif(teks=="enam"  or teks=="keenam" or teks=='ke-6'):
                arr.append(str(6))
            elif(teks=="tujuh"  or teks=="ketujuh" or teks=='ke-7'):
                arr.append(str(7))
            elif(teks=="delapan"  or teks=="kedelapan" or teks=='ke-8'):
                arr.append(str(8))
            elif(teks=="sembilan"  or teks=="kesembilan" or teks=='ke-9'):
                arr.append(str(9))
            elif(teks=="sepuluh"  or teks=="kesepuluh" or teks=="puluhan" or teks=='ke-10'):
                arr.append(str(10))
            elif(teks=="salah" or teks=="sebanyak" or teks=="akibatnya"):
                arr.append('')
            elif(teks=="persen"):
                arr.append('%')
            elif(teks=="belasan"):
                arr.append(str(11))

            #Banyak yang di bawah ini tergantung topik masing2
            elif(teks=="semua"):
                arr.append(str(random.randint(1,5)))
            elif(teks=="sejumlah"):
                arr.append(str(random.randint(6,10)))
            elif(teks=="seluruh"):
                arr.append(str(random.randint(6,15)))
            elif(teks=="beberapa"):
                arr.append(str(random.randint(1,5)))
            elif(teks=="banyak"):
                arr.append(str(random.randint(1,5)))
            elif(teks=="puluh"):
                arr.append(str(0))
            elif(teks=="ratus"):
                arr.append(str(00))
            elif(teks=="ratusan"):
                arr.append(str(100))
            elif(teks=="ribuan"):
                arr.append(str(1000))
            elif(teks=="ribu"):
                arr.append(str(000))
            elif(teks=="jutaan"):
                arr.append(str(1000000))
            elif(teks=="juta"):
                arr.append(str(000000))
            elif(teks=="miliar"):
                arr.append(str(000000000))
            elif(teks=="miliaran"):
                arr.append(str(1000000000))
            elif(teks=="triliun"):
                arr.append(str(000000000000))
            elif(teks=="triliunan"):
                arr.append(str(1000000000000))
            else:
                arr.append(str(1))

    hasil="".join(arr)

    if(hasil[-1:]=='%' and (hasil[:-1].isdigit() or isfloat(hasil[:-1])==True)):
        hasil=float(hasil[:-1])/100
        arr.append(str(hasil))

    return(hasil)

# %%
def indeksKe(arr,indikator):
    for x in range(0, len(arr[0])):
        for y in indikator:
            y=y.split()
            if(len(y)==1 and arr[0][x][0]==y[0]):
                return x
            elif(len(y)==2 and len(arr[0])>x and arr[0][x][0]==y[0] and arr[0][x+1][0]==y[1]):
                return x
    return -1

# %%
# def matiScale(matiCount):
#     matiCount=float(matiCount)
#     if matiCount <=3 :
#       return 1
#     elif matiCount > 3 and matiCount <= 6:
#       return 2
#     return 3

# def sakitScale(sakitCount):
#     sakitCount=float(sakitCount)
#     if sakitCount <= 5:
#       return 1
#     elif sakitCount >= 10 and sakitCount <= 20:
    #   return 2
    # return 3

# def hilangScale(hilangCount):
#     if hilangCount < 4:
#       return 1
#     elif hilangCount >= 4 and hilangCount <= 10:
#       return 2
#     return 3

# def tenggelamScale(tenggelamCount):
#     if tenggelamCount < 4:
#       return 1
#     elif tenggelamCount >= 4 and tenggelamCount <= 10:
#       return 2
#     return 3

# def pesawatScale(pesawatCount):
#     if pesawatCount ==0:
#       return 1
#     elif pesawatCount ==1:
#       return 3

# def calculate(mati, sakit):
#   subtractor = 0
#   total = 0
#   fiturCount = 2

#   if (mati > 0):
#     total += matiScale(matiCount=mati)
#   else:
#     subtractor += 1

#   if (sakit > 0):
#     total += sakitScale(sakitCount=sakit)
#   else:
#     subtractor += 1

  # if (tenggelam > 0):
  #   total += tenggelamScale(tenggelamCount=tenggelam)
  # else:
  #   subtractor += 1
  
  # if (hilang > 0):
  #       total += hilangScale(hilangCount=hilang)
  # else:
  #   subtractor += 1

  # if (pesawat > 0):
  #   total += pesawatScale(pesawatCount=pesawat)
  # else:
  #   subtractor += 1
          

  # divider = (fiturCount - subtractor)
  # severityMean = 0

  # if (divider > 0):
  #   severityMean = total / divider

  # if severityMean <= 1:
  #   return 'rendah'
  # elif severityMean > 1 and severityMean <= 2:
  #   return 'sedang'
  # else:
  #   return 'parah'

# %%
document_result=[]
for i in range(0,len(df)):
# for i in range(0,1):
        print(i)
        arr =[] 
        # judul_teks =preprocessing(df.iloc[i,0])
        # judul_teks.append('.')
        keparahan_teks =preprocessing(df.iloc[i,-2])
        # for x in keparahan_teks:
        #     judul_teks.append(x)
        # arr.append(judul_teks)
        arr.append(keparahan_teks)
        tag_keparahan = ct.tag_sents(arr)

        #kalau buat yang seperti di bawah ini satu jangan lupa buat if else kayak di bawah
        death_indeks= indeksKe(tag_keparahan,['meninggal','mati','tewas','meregang nyawa','menewaskan','merenggut','jenazah','Jenazah','Merenggut','Meninggal','Mati','Tewas','Meregang','Menewaskan']) #kematian #terseret #nyawa #,'jiwa' Merenggut
        injury_indeks= indeksKe(tag_keparahan,['Sakit','sakit','terjangkit','Terjangkit','kritis','kasus','Kasus','dirawat','Kritis','perawatan','Perawatan', 'positif', 'Positif', 'tertular', 'penderita', 'divonis', 'berobat']) #dirawat
        # crash_indeks= indeksKe(tag_keparahan,['menabrak'])
        # lost_indeks= indeksKe(tag_keparahan,['hilang','Hilang'])
        # sink_indeks=indeksKe(tag_keparahan,['tenggelam','tenggelamnya'])
        # plane_indeks=indeksKe(tag_keparahan,['pesawat'])
        #kerugian

        if(death_indeks==-1):
            mati = 0
        else:
            mati = struktur1(tag_keparahan,death_indeks)
            if(isinstance(mati, str)):
                mati=convertTeks(mati)

        if(injury_indeks==-1):
            sakit = 0
        else:
            sakit = struktur1(tag_keparahan,injury_indeks)
            if(isinstance(sakit, str)):
                sakit=convertTeks(sakit)

        keparahan1=''
        if((isinstance(mati,int) or isinstance(mati,float) or mati.isdigit() or isfloat(mati)==True) and (isinstance(sakit,int) or isinstance(sakit,float) or sakit.isdigit() or isfloat(sakit)==True)):
            # lansung parah
            print('asu')
            if(float(mati)>10 and float(sakit)>25):
                print('masuk1')
                keparahan1='parah'
            
            # jika 0
            elif(mati==0 and sakit==0):
                print('masuk2')
                keparahan1='rendah'

            # kategori mati
            elif(float(mati)<=3 and sakit==0):
                print('masuk3')
                keparahan1='rendah'
            elif(float(mati)>3 and float(mati)<=10 and sakit==0):
                print('masuk4')
                keparahan1='sedang'
            elif(float(mati)>10 and sakit==0):
                print('masuk5')
                keparahan1='parah'

            # kategori sakit
            elif(mati==0 and float(sakit)<=10):
                print('masuk6')
                keparahan1='rendah'
            elif(mati==0 and float(sakit)>10 and float(sakit)<=25):
                print('masuk7')
                keparahan1='sedang'
            elif(mati==0 and float(sakit)>25):
                print('masuk8')
                keparahan1='parah'

             # kategori campuran rendah
            elif( float(mati)<=3 and float(sakit)<=10):
                print('masuk9')
                keparahan1='rendah'
             # kategori campuran sedang
            elif(float(mati)>3 and float(mati)<=10 and float(sakit)>10 and float(sakit)<=25):
                print('masuk10')
                keparahan1='sedang'


            # kategori campuran parah
            elif(float(mati)>10 and float(sakit)>=0):
                print('masuk11')
                keparahan1='parah'
            elif(float(mati)>=0 and float(sakit)>25):
                print('masuk12')
                keparahan1='parah'


            #sedang
            elif(float(mati)>=0 and float(sakit)>10 and float(sakit)<=25):
                print('masuk13')
                keparahan1='sedang'
            elif(float(mati)>3 and int(mati)<=10 and float(sakit)>=0):
                print('masuk14')
                keparahan1='sedang'



           

           
            else:
                keparahan1=''
        
        print('masuk',keparahan1)
        # if(lost_indeks==-1):
        #     hilang = 0
        # else:
        #     hilang = struktur1(tag_keparahan,lost_indeks)
        #     if(isinstance(hilang, str)):
        #         hilang=convertTeks(hilang)


        # if(sink_indeks==-1):
        #     tenggelam = 0
        # else:
        #     tenggelam = struktur1(tag_keparahan,sink_indeks)
        #     if(isinstance(tenggelam, str)):
        #         tenggelam=convertTeks(tenggelam)

        # if(plane_indeks==-1):
        #     pesawat = 0
        #     # keparahan1=''
        # else:
        #     pesawat = 1
        #     # keparahan1='parah'
        
        print(mati,sakit)
        
        
        
        data = [i,df.iloc[i,0],df.iloc[i,2],mati, sakit,keparahan1]
        document_result.append(data)
# Out:
# 0
# asu
# masuk2
# masuk rendah
# 0 0
# 1
# masuk sii2
# 19 <class 'str'>
# asu
# masuk13
# masuk sedang
# 1 19
# 2
# masuk sii2
# sebanyak <class 'str'>
# 15 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 254 <class 'str'>
# asu
# masuk1
# masuk parah
# 15 254
# 3
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 5
# 4
# asu
# masuk2
# masuk rendah
# 0 0
# 5
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 6
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 2
# 7
# masuk sii2
# 20 <class 'str'>
# asu
# masuk13
# masuk sedang
# 1 20
# 8
# asu
# masuk2
# masuk rendah
# 0 0
# 9
# asu
# masuk6
# masuk rendah
# 0 1
# 10
# asu
# masuk2
# masuk rendah
# 0 0
# 11
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 7
# 12
# masuk sii2
# 1.011 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 185 <class 'str'>
# asu
# masuk1
# masuk parah
# 1011 185
# 13
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 14
# masuk sii2
# sebanyak <class 'str'>
# 7 <class 'str'>
# asu
# masuk14
# masuk sedang
# 7 1
# 15
# masuk sii2
# 306 <class 'str'>
# masuk sii2
# 3.512 <class 'str'>
# asu
# masuk1
# masuk parah
# 306 3512
# 16
# asu
# masuk9
# masuk rendah
# 1 1
# 17
# asu
# masuk2
# masuk rendah
# 0 0
# 18
# masuk sii2
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 19
# masuk sii2
# 18 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 18
# 20
# asu
# masuk6
# masuk rendah
# 0 1
# 21
# masuk sii2
# 11 <class 'str'>
# asu
# masuk11
# masuk parah
# 11 1
# 22
# asu
# masuk2
# masuk rendah
# 0 0
# 23
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 24
# asu
# masuk6
# masuk rendah
# 0 1
# 25
# asu
# masuk6
# masuk rendah
# 0 1
# 26
# masuk sii2
# enam <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 27
# asu
# masuk2
# masuk rendah
# 0 0
# 28
# asu
# masuk6
# masuk rendah
# 0 1
# 29
# asu
# masuk2
# masuk rendah
# 0 0
# 30
# masuk sii2
# 22 <class 'str'>
# masuk sii2
# 15 <class 'str'>
# asu
# masuk11
# masuk parah
# 22 15
# 31
# asu
# masuk6
# masuk rendah
# 0 1
# 32
# masuk sii2
# 5.000 <class 'str'>
# asu
# masuk11
# masuk parah
# 5000 1
# 33
# asu
# masuk9
# masuk rendah
# 1 1
# 34
# masuk sii2
# 1836 <class 'str'>
# asu
# masuk11
# masuk parah
# 1836 1
# 35
# asu
# masuk2
# masuk rendah
# 0 0
# 36
# asu
# masuk6
# masuk rendah
# 0 1
# 37
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 520 <class 'str'>
# asu
# masuk12
# masuk parah
# 4 520
# 38
# masuk sii2
# _50 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 1000000
# 39
# asu
# masuk6
# masuk rendah
# 0 1
# 40
# asu
# masuk6
# masuk rendah
# 0 1
# 41
# asu
# masuk2
# masuk rendah
# 0 0
# 42
# asu
# masuk6
# masuk rendah
# 0 1
# 43
# asu
# masuk6
# masuk rendah
# 0 1
# 44
# asu
# masuk6
# masuk rendah
# 0 1
# 45
# asu
# masuk6
# masuk rendah
# 0 1
# 46
# asu
# masuk6
# masuk rendah
# 0 1
# 47
# masuk sii2
# sebanyak <class 'str'>
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 48
# asu
# masuk9
# masuk rendah
# 1 1
# 49
# masuk sii2
# 14 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 14
# 50
# asu
# masuk6
# masuk rendah
# 0 1
# 51
# masuk sii2
# 10 <class 'str'>
# asu
# masuk14
# masuk sedang
# 10 1
# 52
# masuk sii2
# semua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 53
# asu
# masuk2
# masuk rendah
# 0 0
# 54
# asu
# masuk6
# masuk rendah
# 0 1
# 55
# asu
# masuk2
# masuk rendah
# 0 0
# 56
# masuk sii2
# 38 <class 'str'>
# asu
# masuk11
# masuk parah
# 38 1
# 57
# masuk sii2
# 32 <class 'str'>
# masuk sii2
# 20 <class 'str'>
# asu
# masuk11
# masuk parah
# 32 20
# 58
# asu
# masuk2
# masuk rendah
# 0 0
# 59
# asu
# masuk2
# masuk rendah
# 0 0
# 60
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 1 1
# 61
# asu
# masuk6
# masuk rendah
# 0 1
# 62
# masuk sii2
# 08 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 08
# 63
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 64
# asu
# masuk6
# masuk rendah
# 0 1
# 65
# asu
# masuk2
# masuk rendah
# 0 0
# 66
# asu
# masuk6
# masuk rendah
# 0 1
# 67
# asu
# masuk6
# masuk rendah
# 0 1
# 68
# asu
# masuk2
# masuk rendah
# 0 0
# 69
# masuk sii2
# 2019 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 70
# asu
# masuk6
# masuk rendah
# 0 1
# 71
# masuk sii2
# 930 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 930
# 72
# asu
# masuk2
# masuk rendah
# 0 0
# 73
# masuk sii2
# 3 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 74
# asu
# masuk3
# masuk rendah
# 1 0
# 75
# asu
# masuk6
# masuk rendah
# 0 1
# 76
# masuk sii2
# 593 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 593
# 77
# masuk sii2
# lima <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 78
# masuk sii2
# 104 <class 'str'>
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk11
# masuk parah
# 104 5
# 79
# asu
# masuk2
# masuk rendah
# 0 0
# 80
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 81
# asu
# masuk6
# masuk rendah
# 0 1
# 82
# asu
# masuk6
# masuk rendah
# 0 1
# 83
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 11
# 84
# masuk sii2
# 1 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 85
# asu
# masuk6
# masuk rendah
# 0 1
# 86
# masuk sii2
# lima <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 5
# 87
# asu
# masuk2
# masuk rendah
# 0 0
# 88
# asu
# masuk6
# masuk rendah
# 0 1
# 89
# asu
# masuk2
# masuk rendah
# 0 0
# 90
# masuk sii2
# 47 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 47
# 91
# masuk sii2
# 7 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 7
# 92
# asu
# masuk6
# masuk rendah
# 0 1
# 93
# asu
# masuk6
# masuk rendah
# 0 1
# 94
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 95
# asu
# masuk6
# masuk rendah
# 0 1
# 96
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 97
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 98
# masuk sii2
# sebanyak <class 'str'>
# 1 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 99
# masuk sii2
# 11 <class 'str'>
# masuk sii2
# sejumlah <class 'str'>
# asu
# masuk11
# masuk parah
# 11 10
# 100
# asu
# masuk6
# masuk rendah
# 0 1
# 101
# asu
# masuk2
# masuk rendah
# 0 0
# 102
# asu
# masuk6
# masuk rendah
# 0 1
# 103
# asu
# masuk6
# masuk rendah
# 0 1
# 104
# masuk sii2
# 6 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 6
# 105
# asu
# masuk6
# masuk rendah
# 0 1
# 106
# asu
# masuk6
# masuk rendah
# 0 1
# 107
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 108
# masuk sii2
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 109
# asu
# masuk6
# masuk rendah
# 0 1
# 110
# masuk sii2
# 23 <class 'str'>
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk11
# masuk parah
# 23 5
# 111
# asu
# masuk2
# masuk rendah
# 0 0
# 112
# asu
# masuk6
# masuk rendah
# 0 1
# 113
# asu
# masuk6
# masuk rendah
# 0 1
# 114
# masuk sii2
# sebanyak <class 'str'>
# 14 <class 'str'>
# asu
# masuk11
# masuk parah
# 14 1
# 115
# masuk sii2
# 33 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 33
# 116
# asu
# masuk2
# masuk rendah
# 0 0
# 117
# masuk sii2
# empat <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 238 <class 'str'>
# asu
# masuk12
# masuk parah
# 4 238
# 118
# asu
# masuk2
# masuk rendah
# 0 0
# 119
# asu
# masuk6
# masuk rendah
# 0 1
# 120
# masuk sii2
# terakhir <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 121
# asu
# masuk2
# masuk rendah
# 0 0
# 122
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 123
# asu
# masuk6
# masuk rendah
# 0 1
# 124
# asu
# masuk2
# masuk rendah
# 0 0
# 125
# asu
# masuk6
# masuk rendah
# 0 1
# 126
# asu
# masuk6
# masuk rendah
# 0 1
# 127
# asu
# masuk2
# masuk rendah
# 0 0
# 128
# asu
# masuk9
# masuk rendah
# 1 1
# 129
# asu
# masuk9
# masuk rendah
# 1 1
# 130
# asu
# masuk6
# masuk rendah
# 0 1
# 131
# masuk sii2
# 42 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 42
# 132
# masuk sii2
# 9 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 133
# asu
# masuk6
# masuk rendah
# 0 1
# 134
# masuk sii2
# empat <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 135
# asu
# masuk6
# masuk rendah
# 0 1
# 136
# asu
# masuk2
# masuk rendah
# 0 0
# 137
# masuk sii2
# 13 <class 'str'>
# asu
# masuk5
# masuk parah
# 13 0
# 138
# asu
# masuk6
# masuk rendah
# 0 1
# 139
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 372 <class 'str'>
# asu
# masuk12
# masuk parah
# 4 372
# 140
# masuk sii2
# sebanyak <class 'str'>
# 174 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 174
# 141
# asu
# masuk2
# masuk rendah
# 0 0
# 142
# masuk sii2
# pertama <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 143
# masuk sii2
# 7 <class 'str'>
# masuk sii2
# sejumlah <class 'str'>
# asu
# masuk14
# masuk sedang
# 7 8
# 144
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 145
# asu
# masuk6
# masuk rendah
# 0 1
# 146
# asu
# masuk6
# masuk rendah
# 0 1
# 147
# asu
# masuk6
# masuk rendah
# 0 1
# 148
# asu
# masuk2
# masuk rendah
# 0 0
# 149
# asu
# masuk6
# masuk rendah
# 0 1
# 150
# asu
# masuk2
# masuk rendah
# 0 0
# 151
# masuk sii2
# 17 <class 'str'>
# asu
# masuk11
# masuk parah
# 17 1
# 152
# asu
# masuk2
# masuk rendah
# 0 0
# 153
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 154
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 5 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 5
# 155
# masuk sii2
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 156
# masuk sii2
# 07.10 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 157
# masuk sii2
# sebanyak <class 'str'>
# 47 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 47
# 158
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 159
# asu
# masuk6
# masuk rendah
# 0 1
# 160
# masuk sii2
# 15 <class 'str'>
# masuk sii2
# 373 <class 'str'>
# asu
# masuk1
# masuk parah
# 15 373
# 161
# asu
# masuk6
# masuk rendah
# 0 1
# 162
# asu
# masuk2
# masuk rendah
# 0 0
# 163
# masuk sii2
# enam <class 'str'>
# masuk sii2
# 2018 <class 'str'>
# masuk sii
# asu
# masuk14
# masuk sedang
# 6 1
# 164
# asu
# masuk6
# masuk rendah
# 0 1
# 165
# asu
# masuk9
# masuk rendah
# 1 1
# 166
# masuk sii2
# 47 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 1933 <class 'str'>
# asu
# masuk1
# masuk parah
# 47 1933
# 167
# masuk sii2
# 39 <class 'str'>
# persen <class 'str'>
# asu
# masuk9
# masuk rendah
# 0.39 1
# 168
# masuk sii2
# tiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 169
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# masuk sii2
# tiga <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 3
# 170
# asu
# masuk2
# masuk rendah
# 0 0
# 171
# masuk sii2
# 42 <class 'str'>
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk11
# masuk parah
# 42 4
# 172
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# 96 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 96
# 173
# asu
# masuk6
# masuk rendah
# 0 1
# 174
# asu
# masuk6
# masuk rendah
# 0 1
# 175
# asu
# masuk6
# masuk rendah
# 0 1
# 176
# masuk sii2
# dua <class 'str'>
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 2
# 177
# masuk sii2
# 126 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 126
# 178
# asu
# masuk6
# masuk rendah
# 0 1
# 179
# asu
# masuk3
# masuk rendah
# 1 0
# 180
# masuk sii2
# 18 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 18
# 181
# asu
# masuk6
# masuk rendah
# 0 1
# 182
# asu
# masuk6
# masuk rendah
# 0 1
# 183
# asu
# masuk6
# masuk rendah
# 0 1
# 184
# masuk sii2
# dua <class 'str'>
# masuk sii2
# 101 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 101
# 185
# asu
# masuk2
# masuk rendah
# 0 0
# 186
# asu
# masuk2
# masuk rendah
# 0 0
# 187
# asu
# masuk9
# masuk rendah
# 1 1
# 188
# asu
# masuk6
# masuk rendah
# 0 1
# 189
# asu
# masuk6
# masuk rendah
# 0 1
# 190
# asu
# masuk6
# masuk rendah
# 0 1
# 191
# asu
# masuk6
# masuk rendah
# 0 1
# 192
# asu
# masuk6
# masuk rendah
# 0 1
# 193
# masuk sii2
# tiga <class 'str'>
# masuk sii2
# 86 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 86
# 194
# asu
# masuk6
# masuk rendah
# 0 1
# 195
# asu
# masuk6
# masuk rendah
# 0 1
# 196
# asu
# masuk2
# masuk rendah
# 0 0
# 197
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 198
# masuk sii2
# sebanyak <class 'str'>
# 10 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 930 <class 'str'>
# asu
# masuk12
# masuk parah
# 10 930
# 199
# asu
# masuk2
# masuk rendah
# 0 0
# 200
# masuk sii2
# sebanyak <class 'str'>
# 14 <class 'str'>
# asu
# masuk11
# masuk parah
# 14 1
# 201
# masuk sii2
# 285 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 285
# 202
# asu
# masuk6
# masuk rendah
# 0 1
# 203
# masuk sii2
# 212 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 212
# 204
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# 8 <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 8
# 205
# asu
# masuk6
# masuk rendah
# 0 1
# 206
# asu
# masuk6
# masuk rendah
# 0 1
# 207
# masuk sii2
# 11 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 11
# 208
# asu
# masuk6
# masuk rendah
# 0 1
# 209
# asu
# masuk6
# masuk rendah
# 0 1
# 210
# masuk sii2
# 2016 <class 'str'>
# masuk sii
# masuk sii2
# 4 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 4
# 211
# asu
# masuk2
# masuk rendah
# 0 0
# 212
# asu
# masuk6
# masuk rendah
# 0 1
# 213
# masuk sii2
# banyak <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 214
# asu
# masuk9
# masuk rendah
# 1 1
# 215
# asu
# masuk2
# masuk rendah
# 0 0
# 216
# asu
# masuk6
# masuk rendah
# 0 1
# 217
# asu
# masuk5
# masuk parah
# 1500000 0
# 218
# asu
# masuk2
# masuk rendah
# 0 0
# 219
# asu
# masuk2
# masuk rendah
# 0 0
# 220
# asu
# masuk6
# masuk rendah
# 0 1
# 221
# masuk sii2
# 7 <class 'str'>
# masuk sii2
# 15 <class 'str'>
# asu
# masuk10
# masuk sedang
# 7 15
# 222
# masuk sii2
# senam <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 223
# asu
# masuk9
# masuk rendah
# 1 1
# 224
# masuk sii2
# separuh <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 225
# asu
# masuk6
# masuk rendah
# 0 1
# 226
# asu
# masuk2
# masuk rendah
# 0 0
# 227
# asu
# masuk6
# masuk rendah
# 0 1
# 228
# masuk sii2
# banyak <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 229
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 230
# asu
# masuk2
# masuk rendah
# 0 0
# 231
# asu
# masuk6
# masuk rendah
# 0 1
# 232
# masuk sii2
# berbagai <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 233
# masuk sii2
# 28 <class 'str'>
# persen <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 0.28
# 234
# masuk sii2
# kelapa <class 'str'>
# asu
# masuk3
# masuk rendah
# 1 0
# 235
# masuk sii2
# 835 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 835
# 236
# asu
# masuk2
# masuk rendah
# 0 0
# 237
# masuk sii2
# 2.900 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 2900
# 238
# masuk sii2
# 321 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 321
# 239
# asu
# masuk2
# masuk rendah
# 0 0
# 240
# asu
# masuk2
# masuk rendah
# 0 0
# 241
# asu
# masuk6
# masuk rendah
# 0 1
# 242
# asu
# masuk6
# masuk rendah
# 0 1
# 243
# masuk sii2
# sejumlah <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 244
# asu
# masuk2
# masuk rendah
# 0 0
# 245
# masuk sii2
# 6 <class 'str'>
# masuk sii2
# 70 <class 'str'>
# asu
# masuk12
# masuk parah
# 6 70
# 246
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 247
# asu
# masuk6
# masuk rendah
# 0 1
# 248
# asu
# masuk2
# masuk rendah
# 0 0
# 249
# masuk sii2
# sebanyak <class 'str'>
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 250
# masuk sii2
# 33 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 33
# 251
# masuk sii2
# 1.300 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 1300
# 252
# asu
# masuk9
# masuk rendah
# 1 1
# 253
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 254
# asu
# masuk2
# masuk rendah
# 0 0
# 255
# asu
# masuk6
# masuk rendah
# 0 1
# 256
# asu
# masuk2
# masuk rendah
# 0 0
# 257
# masuk sii2
# sebanyak <class 'str'>
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 258
# asu
# masuk6
# masuk rendah
# 0 1
# 259
# asu
# masuk6
# masuk rendah
# 0 1
# 260
# asu
# masuk6
# masuk rendah
# 0 1
# 261
# asu
# masuk6
# masuk rendah
# 0 1
# 262
# asu
# masuk2
# masuk rendah
# 0 0
# 263
# masuk sii2
# 3 <class 'str'>
# masuk sii2
# 32 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 32
# 264
# masuk sii2
# setiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 265
# asu
# masuk2
# masuk rendah
# 0 0
# 266
# masuk sii2
# 400.000 <class 'str'>
# asu
# masuk5
# masuk parah
# 400000 0
# 267
# asu
# masuk2
# masuk rendah
# 0 0
# 268
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 8
# 269
# asu
# masuk6
# masuk rendah
# 0 1
# 270
# asu
# masuk6
# masuk rendah
# 0 1
# 271
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 272
# asu
# masuk6
# masuk rendah
# 0 1
# 273
# asu
# masuk9
# masuk rendah
# 1 1
# 274
# masuk sii2
# 60 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 60
# 275
# asu
# masuk2
# masuk rendah
# 0 0
# 276
# masuk sii2
# 8 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 8
# 277
# masuk sii2
# ke-5 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 278
# masuk sii2
# 10 <class 'str'>
# asu
# masuk14
# masuk sedang
# 10 1
# 279
# masuk sii2
# 150 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 150
# 280
# masuk sii2
# sebanyak <class 'str'>
# 5 <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 281
# masuk sii2
# 5.727 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 5727
# 282
# asu
# masuk6
# masuk rendah
# 0 1
# 283
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 284
# asu
# masuk2
# masuk rendah
# 0 0
# 285
# asu
# masuk2
# masuk rendah
# 0 0
# 286
# masuk sii2
# 3 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 287
# asu
# masuk2
# masuk rendah
# 0 0
# 288
# masuk sii2
# 9 <class 'str'>
# masuk sii2
# banyak <class 'str'>
# asu
# masuk14
# masuk sedang
# 9 2
# 289
# asu
# masuk6
# masuk rendah
# 0 1
# 290
# asu
# masuk6
# masuk rendah
# 0 1
# 291
# asu
# masuk2
# masuk rendah
# 0 0
# 292
# masuk sii2
# 1901 <class 'str'>
# masuk sii2
# seorang <class 'str'>
# asu
# masuk11
# masuk parah
# 1901 1
# 293
# masuk sii2
# banyak <class 'str'>
# asu
# masuk4
# masuk sedang
# 5 0
# 294
# asu
# masuk2
# masuk rendah
# 0 0
# 295
# asu
# masuk2
# masuk rendah
# 0 0
# 296
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 297
# masuk sii2
# 23 <class 'str'>
# masuk sii2
# 687 <class 'str'>
# asu
# masuk1
# masuk parah
# 23 687
# 298
# masuk sii2
# 124 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 124
# 299
# asu
# masuk2
# masuk rendah
# 0 0
# 300
# asu
# masuk6
# masuk rendah
# 0 1
# 301
# asu
# masuk2
# masuk rendah
# 0 0
# 302
# masuk sii2
# 9 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 303
# asu
# masuk6
# masuk rendah
# 0 1
# 304
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 305
# asu
# masuk6
# masuk rendah
# 0 1
# 306
# masuk sii2
# 2018 <class 'str'>
# masuk sii
# sebanyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 307
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 308
# masuk sii2
# semua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 309
# asu
# masuk9
# masuk rendah
# 1 1
# 310
# masuk sii2
# 19 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 19
# 311
# asu
# masuk2
# masuk rendah
# 0 0
# 312
# asu
# masuk6
# masuk rendah
# 0 1
# 313
# asu
# masuk2
# masuk rendah
# 0 0
# 314
# masuk sii2
# sebanyak <class 'str'>
# 25 <class 'str'>
# asu
# masuk11
# masuk parah
# 25 1
# 315
# asu
# masuk2
# masuk rendah
# 0 0
# 316
# asu
# masuk9
# masuk rendah
# 1 1
# 317
# masuk sii2
# delapan <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 400 <class 'str'>
# asu
# masuk12
# masuk parah
# 8 400
# 318
# masuk sii2
# lima <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 319
# asu
# masuk6
# masuk rendah
# 0 1
# 320
# masuk sii2
# 6 <class 'str'>
# masuk sii2
# dua <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 2
# 321
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 14
# 322
# masuk sii2
# sebanyak <class 'str'>
# 5 <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 323
# masuk sii2
# 11 <class 'str'>
# asu
# masuk11
# masuk parah
# 11 1
# 324
# asu
# masuk6
# masuk rendah
# 0 1
# 325
# masuk sii2
# 3-18 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 326
# masuk sii2
# 2016 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 1 1
# 327
# asu
# masuk6
# masuk rendah
# 0 1
# 328
# asu
# masuk6
# masuk rendah
# 0 1
# 329
# masuk sii2
# 9 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 330
# asu
# masuk6
# masuk rendah
# 0 1
# 331
# asu
# masuk6
# masuk rendah
# 0 1
# 332
# asu
# masuk2
# masuk rendah
# 0 0
# 333
# asu
# masuk6
# masuk rendah
# 0 1
# 334
# masuk sii2
# 9 <class 'str'>
# asu
# masuk14
# masuk sedang
# 9 1
# 335
# asu
# masuk6
# masuk rendah
# 0 1
# 336
# masuk sii2
# 129 <class 'str'>
# masuk sii2
# pertama <class 'str'>
# asu
# masuk11
# masuk parah
# 129 1
# 337
# masuk sii2
# 4.541 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 4541
# 338
# masuk sii2
# setiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 339
# asu
# masuk9
# masuk rendah
# 1 1
# 340
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 341
# asu
# masuk6
# masuk rendah
# 0 1
# 342
# masuk sii2
# 6 <class 'str'>
# masuk sii2
# tiga <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 3
# 343
# asu
# masuk6
# masuk rendah
# 0 1
# 344
# masuk sii2
# lima <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 366 <class 'str'>
# asu
# masuk12
# masuk parah
# 5 366
# 345
# masuk sii2
# lima <class 'str'>
# masuk sii2
# 315 <class 'str'>
# asu
# masuk12
# masuk parah
# 5 315
# 346
# masuk sii2
# 261 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 261
# 347
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 348
# asu
# masuk6
# masuk rendah
# 0 1
# 349
# asu
# masuk6
# masuk rendah
# 0 1
# 350
# masuk sii2
# 100 <class 'str'>
# asu
# masuk11
# masuk parah
# 100 1
# 351
# asu
# masuk8
# masuk parah
# 0 68000
# 352
# masuk sii2
# 40 <class 'str'>
# masuk sii2
# 40 <class 'str'>
# asu
# masuk1
# masuk parah
# 40 40
# 353
# asu
# masuk6
# masuk rendah
# 0 1
# 354
# masuk sii2
# kelima <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 355
# asu
# masuk6
# masuk rendah
# 0 1
# 356
# asu
# masuk6
# masuk rendah
# 0 1
# 357
# asu
# masuk9
# masuk rendah
# 1 1
# 358
# masuk sii2
# 3.622 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 3622
# 359
# asu
# masuk9
# masuk rendah
# 1 1
# 360
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 361
# asu
# masuk2
# masuk rendah
# 0 0
# 362
# masuk sii2
# 116 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 116
# 363
# masuk sii2
# 28 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 28
# 364
# masuk sii2
# 1 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 15 <class 'str'>
# asu
# masuk13
# masuk sedang
# 1 15
# 365
# asu
# masuk6
# masuk rendah
# 0 1
# 366
# asu
# masuk6
# masuk rendah
# 0 1
# 367
# asu
# masuk6
# masuk rendah
# 0 1
# 368
# masuk sii2
# puluhan <class 'str'>
# masuk sii2
# 95 <class 'str'>
# asu
# masuk12
# masuk parah
# 10 95
# 369
# masuk sii2
# tiga <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 370
# asu
# masuk6
# masuk rendah
# 0 1
# 371
# masuk sii2
# 38 <class 'str'>
# masuk sii2
# 600 <class 'str'>
# asu
# masuk1
# masuk parah
# 38 600
# 372
# asu
# masuk2
# masuk rendah
# 0 0
# 373
# asu
# masuk6
# masuk rendah
# 0 1
# 374
# masuk sii2
# berbagai <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 375
# asu
# masuk6
# masuk rendah
# 0 1
# 376
# asu
# masuk2
# masuk rendah
# 0 0
# 377
# asu
# masuk2
# masuk rendah
# 0 0
# 378
# asu
# masuk6
# masuk rendah
# 0 1
# 379
# asu
# masuk2
# masuk rendah
# 0 0
# 380
# asu
# masuk2
# masuk rendah
# 0 0
# 381
# asu
# masuk6
# masuk rendah
# 0 1
# 382
# asu
# masuk2
# masuk rendah
# 0 0
# 383
# masuk sii2
# 8 <class 'str'>
# masuk sii2
# 17.989 <class 'str'>
# asu
# masuk12
# masuk parah
# 8 17989
# 384
# asu
# masuk2
# masuk rendah
# 0 0
# 385
# asu
# masuk6
# masuk rendah
# 0 1
# 386
# asu
# masuk6
# masuk rendah
# 0 1
# 387
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 388
# asu
# masuk6
# masuk rendah
# 0 1
# 389
# masuk sii2
# 25 <class 'str'>
# masuk sii2
# 25 <class 'str'>
# asu
# masuk11
# masuk parah
# 25 25
# 390
# asu
# masuk6
# masuk rendah
# 0 1
# 391
# masuk sii2
# tiga <class 'str'>
# masuk sii2
# semua <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 2
# 392
# asu
# masuk3
# masuk rendah
# 1 0
# 393
# asu
# masuk2
# masuk rendah
# 0 0
# 394
# masuk sii2
# 17 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 17
# 395
# asu
# masuk6
# masuk rendah
# 0 1
# 396
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 397
# masuk sii2
# 561 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 561
# 398
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 399
# asu
# masuk3
# masuk rendah
# 1 0
# 400
# asu
# masuk2
# masuk rendah
# 0 0
# 401
# asu
# masuk2
# masuk rendah
# 0 0
# 402
# masuk sii2
# 18 <class 'str'>
# asu
# masuk11
# masuk parah
# 18 1
# 403
# masuk sii2
# sebanyak <class 'str'>
# 17 <class 'str'>
# masuk sii2
# 24 <class 'str'>
# asu
# masuk11
# masuk parah
# 17 24
# 404
# asu
# masuk2
# masuk rendah
# 0 0
# 405
# asu
# masuk2
# masuk rendah
# 0 0
# 406
# masuk sii2
# 700 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 700
# 407
# masuk sii2
# lima <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 408
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 409
# masuk sii2
# 628 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 628
# 410
# asu
# masuk2
# masuk rendah
# 0 0
# 411
# masuk sii2
# 5 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 5
# 412
# masuk sii2
# delapan <class 'str'>
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk14
# masuk sedang
# 8 1
# 413
# masuk sii2
# 4 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 414
# asu
# masuk6
# masuk rendah
# 0 1
# 415
# masuk sii2
# sebanyak <class 'str'>
# 3 <class 'str'>
# masuk sii2
# 24 <class 'str'>
# asu
# masuk13
# masuk sedang
# 3 24
# 416
# masuk sii2
# banyak <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 417
# asu
# masuk2
# masuk rendah
# 0 0
# 418
# asu
# masuk6
# masuk rendah
# 0 1
# 419
# asu
# masuk2
# masuk rendah
# 0 0
# 420
# asu
# masuk6
# masuk rendah
# 0 1
# 421
# asu
# masuk2
# masuk rendah
# 0 0
# 422
# masuk sii2
# 20 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 456 <class 'str'>
# asu
# masuk1
# masuk parah
# 20 456
# 423
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 424
# masuk sii2
# 2.245 <class 'str'>
# masuk sii2
# 118 <class 'str'>
# asu
# masuk1
# masuk parah
# 2245 118
# 425
# masuk sii2
# pertama <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 426
# asu
# masuk6
# masuk rendah
# 0 1
# 427
# asu
# masuk6
# masuk rendah
# 0 1
# 428
# asu
# masuk6
# masuk rendah
# 0 1
# 429
# masuk sii2
# 17 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 17
# 430
# asu
# masuk9
# masuk rendah
# 1 1
# 431
# asu
# masuk6
# masuk rendah
# 0 1
# 432
# masuk sii2
# 9 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 433
# asu
# masuk6
# masuk rendah
# 0 1
# 434
# asu
# masuk6
# masuk rendah
# 0 1
# 435
# asu
# masuk6
# masuk rendah
# 0 1
# 436
# asu
# masuk6
# masuk rendah
# 0 1
# 437
# masuk sii2
# 90 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 90
# 438
# asu
# masuk2
# masuk rendah
# 0 0
# 439
# masuk sii2
# sebanyak <class 'str'>
# 4 <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 440
# asu
# masuk2
# masuk rendah
# 0 0
# 441
# asu
# masuk6
# masuk rendah
# 0 1
# 442
# asu
# masuk6
# masuk rendah
# 0 1
# 443
# masuk sii2
# 4.000 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 4000
# 444
# masuk sii2
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 445
# asu
# masuk2
# masuk rendah
# 0 0
# 446
# asu
# masuk2
# masuk rendah
# 0 0
# 447
# asu
# masuk9
# masuk rendah
# 1 1
# 448
# asu
# masuk2
# masuk rendah
# 0 0
# 449
# asu
# masuk6
# masuk rendah
# 0 1
# 450
# asu
# masuk6
# masuk rendah
# 0 1
# 451
# masuk sii2
# 75 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 75
# 452
# masuk sii2
# 7.419 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 7419
# 453
# masuk sii2
# empat <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 454
# asu
# masuk2
# masuk rendah
# 0 0
# 455
# asu
# masuk6
# masuk rendah
# 0 1
# 456
# asu
# masuk6
# masuk rendah
# 0 1
# 457
# asu
# masuk6
# masuk rendah
# 0 1
# 458
# masuk sii2
# satu <class 'str'>
# masuk sii2
# 153 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 153
# 459
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 460
# masuk sii2
# 13 <class 'str'>
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk11
# masuk parah
# 13 1
# 461
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 26 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 26
# 462
# masuk sii2
# satu <class 'str'>
# masuk sii2
# 115 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 115
# 463
# masuk sii2
# 59 <class 'str'>
# asu
# masuk11
# masuk parah
# 59 1
# 464
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 465
# masuk sii2
# 9 <class 'str'>
# asu
# masuk14
# masuk sedang
# 9 1
# 466
# asu
# masuk2
# masuk rendah
# 0 0
# 467
# masuk sii2
# tiga <class 'str'>
# asu
# masuk3
# masuk rendah
# 3 0
# 468
# masuk sii2
# pertama <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 469
# asu
# masuk2
# masuk rendah
# 0 0
# 470
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 471
# masuk sii2
# 19 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 19
# 472
# masuk sii2
# puluhan <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 10
# 473
# asu
# masuk2
# masuk rendah
# 0 0
# 474
# asu
# masuk6
# masuk rendah
# 0 1
# 475
# masuk sii2
# 182 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 182
# 476
# asu
# masuk6
# masuk rendah
# 0 1
# 477
# asu
# masuk6
# masuk rendah
# 0 1
# 478
# asu
# masuk6
# masuk rendah
# 0 1
# 479
# masuk sii2
# empat <class 'str'>
# masuk sii2
# 92 <class 'str'>
# asu
# masuk12
# masuk parah
# 4 92
# 480
# asu
# masuk2
# masuk rendah
# 0 0
# 481
# asu
# masuk2
# masuk rendah
# 0 0
# 482
# asu
# masuk6
# masuk rendah
# 0 1
# 483
# masuk sii2
# setiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 484
# asu
# masuk2
# masuk rendah
# 0 0
# 485
# asu
# masuk2
# masuk rendah
# 0 0
# 486
# masuk sii2
# tiga <class 'str'>
# asu
# masuk3
# masuk rendah
# 3 0
# 487
# masuk sii2
# 12 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 12
# 488
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 489
# masuk sii2
# 1.5 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1.5
# 490
# asu
# masuk6
# masuk rendah
# 0 1
# 491
# asu
# masuk6
# masuk rendah
# 0 1
# 492
# masuk sii2
# 5 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 340 <class 'str'>
# asu
# masuk12
# masuk parah
# 5 340
# 493
# asu
# masuk2
# masuk rendah
# 0 0
# 494
# masuk sii2
# 1.351 <class 'str'>
# asu
# masuk11
# masuk parah
# 1351 1
# 495
# asu
# masuk6
# masuk rendah
# 0 1
# 496
# asu
# masuk2
# masuk rendah
# 0 0
# 497
# asu
# masuk6
# masuk rendah
# 0 1
# 498
# asu
# masuk6
# masuk rendah
# 0 1
# 499
# asu
# masuk6
# masuk rendah
# 0 1
# 500
# asu
# masuk6
# masuk rendah
# 0 1
# 501
# asu
# masuk2
# masuk rendah
# 0 0
# 502
# asu
# masuk6
# masuk rendah
# 0 1
# 503
# masuk sii2
# 5 <class 'str'>
# masuk sii2
# seorang <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 504
# asu
# masuk2
# masuk rendah
# 0 0
# 505
# asu
# masuk9
# masuk rendah
# 1 1
# 506
# masuk sii2
# sebanyak <class 'str'>
# 10 <class 'str'>
# asu
# masuk14
# masuk sedang
# 10 1
# 507
# asu
# masuk2
# masuk rendah
# 0 0
# 508
# masuk sii2
# seorang <class 'str'>
# asu
# masuk3
# masuk rendah
# 1 0
# 509
# asu
# masuk6
# masuk rendah
# 0 1
# 510
# asu
# masuk9
# masuk rendah
# 1 1
# 511
# masuk sii2
# 1.200 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 1200
# 512
# asu
# masuk6
# masuk rendah
# 0 1
# 513
# asu
# masuk6
# masuk rendah
# 0 1
# 514
# asu
# masuk2
# masuk rendah
# 0 0
# 515
# asu
# masuk3
# masuk rendah
# 1 0
# 516
# asu
# masuk2
# masuk rendah
# 0 0
# 517
# asu
# masuk6
# masuk rendah
# 0 1
# 518
# masuk sii2
# 14 <class 'str'>
# masuk sii2
# 121 <class 'str'>
# asu
# masuk1
# masuk parah
# 14 121
# 519
# masuk sii2
# setiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 520
# asu
# masuk6
# masuk rendah
# 0 1
# 521
# asu
# masuk2
# masuk rendah
# 0 0
# 522
# masuk sii2
# semua <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 523
# asu
# masuk2
# masuk rendah
# 0 0
# 524
# asu
# masuk2
# masuk rendah
# 0 0
# 525
# asu
# masuk6
# masuk rendah
# 0 1
# 526
# asu
# masuk9
# masuk rendah
# 1 1
# 527
# masuk sii2
# 64 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 64
# 528
# masuk sii2
# 37 <class 'str'>
# masuk sii2
# 3.109 <class 'str'>
# asu
# masuk1
# masuk parah
# 37 3109
# 529
# asu
# masuk2
# masuk rendah
# 0 0
# 530
# masuk sii2
# 800 <class 'str'>
# masuk sii2
# tiga <class 'str'>
# asu
# masuk11
# masuk parah
# 800 3
# 531
# masuk sii2
# 6 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 6
# 532
# asu
# masuk2
# masuk rendah
# 0 0
# 533
# asu
# masuk6
# masuk rendah
# 0 1
# 534
# asu
# masuk6
# masuk rendah
# 0 1
# 535
# masuk sii2
# tiga <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 627 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 627
# 536
# asu
# masuk6
# masuk rendah
# 0 1
# 537
# asu
# masuk2
# masuk rendah
# 0 0
# 538
# asu
# masuk6
# masuk rendah
# 0 1
# 539
# masuk sii2
# sebanyak <class 'str'>
# 18 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 18
# 540
# asu
# masuk6
# masuk rendah
# 0 1
# 541
# asu
# masuk2
# masuk rendah
# 0 0
# 542
# asu
# masuk6
# masuk rendah
# 0 1
# 543
# asu
# masuk2
# masuk rendah
# 0 0
# 544
# masuk sii2
# sebanyak <class 'str'>
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 545
# masuk sii2
# 156.548 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 345 <class 'str'>
# asu
# masuk1
# masuk parah
# 156548 345
# 546
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 547
# asu
# masuk9
# masuk rendah
# 1 1
# 548
# masuk sii2
# sebanyak <class 'str'>
# 17 <class 'str'>
# masuk sii2
# 24 <class 'str'>
# asu
# masuk11
# masuk parah
# 17 24
# 549
# asu
# masuk6
# masuk rendah
# 0 1
# 550
# masuk sii2
# sebanyak <class 'str'>
# 41 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 1.468 <class 'str'>
# asu
# masuk1
# masuk parah
# 41 1468
# 551
# masuk sii2
# 9 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 1.626 <class 'str'>
# asu
# masuk12
# masuk parah
# 9 1626
# 552
# asu
# masuk9
# masuk rendah
# 1 1
# 553
# masuk sii2
# 22 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 22
# 554
# asu
# masuk2
# masuk rendah
# 0 0
# 555
# asu
# masuk6
# masuk rendah
# 0 1
# 556
# masuk sii2
# 40 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 40
# 557
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 558
# asu
# masuk6
# masuk rendah
# 0 1
# 559
# asu
# masuk2
# masuk rendah
# 0 0
# 560
# asu
# masuk9
# masuk rendah
# 1 1
# 561
# masuk sii2
# 948 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 948
# 562
# asu
# masuk9
# masuk rendah
# 1 1
# 563
# asu
# masuk2
# masuk rendah
# 0 0
# 564
# asu
# masuk6
# masuk rendah
# 0 1
# 565
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# lima <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 5
# 566
# masuk sii2
# 2018 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 567
# masuk sii2
# empat <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 568
# asu
# masuk6
# masuk rendah
# 0 1
# 569
# masuk sii2
# 141 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 141
# 570
# asu
# masuk6
# masuk rendah
# 0 1
# 571
# masuk sii2
# 300 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 300
# 572
# asu
# masuk6
# masuk rendah
# 0 1
# 573
# asu
# masuk2
# masuk rendah
# 0 0
# 574
# asu
# masuk2
# masuk rendah
# 0 0
# 575
# masuk sii2
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 576
# asu
# masuk2
# masuk rendah
# 0 0
# 577
# asu
# masuk6
# masuk rendah
# 0 1
# 578
# asu
# masuk2
# masuk rendah
# 0 0
# 579
# asu
# masuk2
# masuk rendah
# 0 0
# 580
# masuk sii2
# kedua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 581
# masuk sii2
# sembilan <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 582
# asu
# masuk2
# masuk rendah
# 0 0
# 583
# asu
# masuk6
# masuk rendah
# 0 1
# 584
# asu
# masuk2
# masuk rendah
# 0 0
# 585
# masuk sii2
# terakhir <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 586
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 587
# masuk sii2
# 646 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 646
# 588
# masuk sii2
# ketiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 589
# asu
# masuk6
# masuk rendah
# 0 1
# 590
# asu
# masuk6
# masuk rendah
# 0 1
# 591
# masuk sii2
# sebanyak <class 'str'>
# 5 <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 592
# asu
# masuk6
# masuk rendah
# 0 1
# 593
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 594
# asu
# masuk2
# masuk rendah
# 0 0
# 595
# asu
# masuk8
# masuk parah
# 0 30000000
# 596
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 597
# masuk sii2
# 75 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 75
# 598
# masuk sii2
# 16.5 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 16.5
# 599
# masuk sii2
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 600
# asu
# masuk9
# masuk rendah
# 1 1
# 601
# masuk sii2
# 52 <class 'str'>
# masuk sii2
# 16.279 <class 'str'>
# asu
# masuk1
# masuk parah
# 52 16279
# 602
# asu
# masuk2
# masuk rendah
# 0 0
# 603
# masuk sii2
# 2019 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 604
# masuk sii2
# 11 <class 'str'>
# asu
# masuk11
# masuk parah
# 11 1
# 605
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 606
# masuk sii2
# kedua <class 'str'>
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 2
# 607
# asu
# masuk6
# masuk rendah
# 0 1
# 608
# asu
# masuk3
# masuk rendah
# 1 0
# 609
# masuk sii2
# sebanyak <class 'str'>
# 17 <class 'str'>
# asu
# masuk11
# masuk parah
# 17 1
# 610
# masuk sii2
# sang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 611
# asu
# masuk6
# masuk rendah
# 0 1
# 612
# masuk sii2
# 1 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 613
# masuk sii2
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 614
# masuk sii2
# pertama <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 615
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 616
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 6
# 617
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 618
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 619
# asu
# masuk9
# masuk rendah
# 1 1
# 620
# masuk sii2
# 5 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 388 <class 'str'>
# asu
# masuk12
# masuk parah
# 5 388
# 621
# asu
# masuk6
# masuk rendah
# 0 1
# 622
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 623
# asu
# masuk6
# masuk rendah
# 0 1
# 624
# asu
# masuk6
# masuk rendah
# 0 1
# 625
# asu
# masuk2
# masuk rendah
# 0 0
# 626
# masuk sii2
# 109 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 109
# 627
# masuk sii2
# 989 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 989
# 628
# masuk sii2
# 4 <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 629
# asu
# masuk6
# masuk rendah
# 0 1
# 630
# asu
# masuk6
# masuk rendah
# 0 1
# 631
# asu
# masuk2
# masuk rendah
# 0 0
# 632
# masuk sii2
# satu <class 'str'>
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 633
# asu
# masuk2
# masuk rendah
# 0 0
# 634
# masuk sii2
# sebagian <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 635
# masuk sii2
# suatu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 636
# asu
# masuk11
# masuk parah
# 100000 1
# 637
# asu
# masuk2
# masuk rendah
# 0 0
# 638
# masuk sii2
# seorang <class 'str'>
# asu
# masuk3
# masuk rendah
# 1 0
# 639
# asu
# masuk2
# masuk rendah
# 0 0
# 640
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 641
# asu
# masuk6
# masuk rendah
# 0 1
# 642
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 643
# masuk sii2
# 6 <class 'str'>
# masuk sii2
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 6
# 644
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 645
# masuk sii2
# 29 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 29
# 646
# masuk sii2
# puluhan <class 'str'>
# asu
# masuk4
# masuk sedang
# 10 0
# 647
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 648
# asu
# masuk2
# masuk rendah
# 0 0
# 649
# masuk sii2
# belasan <class 'str'>
# asu
# masuk11
# masuk parah
# 11 1
# 650
# asu
# masuk6
# masuk rendah
# 0 1
# 651
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 652
# masuk sii2
# 17.820 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 17820
# 653
# asu
# masuk2
# masuk rendah
# 0 0
# 654
# asu
# masuk2
# masuk rendah
# 0 0
# 655
# masuk sii2
# sebanyak <class 'str'>
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 656
# asu
# masuk2
# masuk rendah
# 0 0
# 657
# masuk sii2
# 24 <class 'str'>
# masuk sii2
# 2017. <class 'str'>
# asu
# masuk1
# masuk parah
# 24 2017.
# 658
# asu
# masuk2
# masuk rendah
# 0 0
# 659
# asu
# masuk6
# masuk rendah
# 0 1
# 660
# masuk sii2
# tiga <class 'str'>
# masuk sii2
# 1.542 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 1542
# 661
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 662
# masuk sii2
# 1.113 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 1113
# 663
# masuk sii2
# 70 <class 'str'>
# masuk sii2
# 154 <class 'str'>
# asu
# masuk1
# masuk parah
# 70 154
# 664
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 665
# asu
# masuk6
# masuk rendah
# 0 1
# 666
# asu
# masuk6
# masuk rendah
# 0 1
# 667
# masuk sii2
# 236 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 236
# 668
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 669
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 670
# masuk sii2
# sebanyak <class 'str'>
# 14 <class 'str'>
# asu
# masuk11
# masuk parah
# 14 1
# 671
# asu
# masuk6
# masuk rendah
# 0 1
# 672
# asu
# masuk6
# masuk rendah
# 0 1
# 673
# asu
# masuk2
# masuk rendah
# 0 0
# 674
# asu
# masuk2
# masuk rendah
# 0 0
# 675
# asu
# masuk6
# masuk rendah
# 0 1
# 676
# asu
# masuk2
# masuk rendah
# 0 0
# 677
# masuk sii2
# sebanyak <class 'str'>
# 6 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 6
# 678
# masuk sii2
# pertama <class 'str'>
# 2020 <class 'str'>
# masuk sii
# masuk sii2
# 4.600 <class 'str'>
# asu
# masuk1
# masuk parah
# 11 4600
# 679
# asu
# masuk6
# masuk rendah
# 0 1
# 680
# asu
# masuk2
# masuk rendah
# 0 0
# 681
# masuk sii2
# 2017 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 682
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 683
# asu
# masuk2
# masuk rendah
# 0 0
# 684
# asu
# masuk6
# masuk rendah
# 0 1
# 685
# asu
# masuk2
# masuk rendah
# 0 0
# 686
# asu
# masuk6
# masuk rendah
# 0 1
# 687
# masuk sii2
# sebanyak <class 'str'>
# 170 <class 'str'>
# asu
# masuk11
# masuk parah
# 170 1
# 688
# asu
# masuk9
# masuk rendah
# 1 1
# 689
# masuk sii2
# lima <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 690
# asu
# masuk2
# masuk rendah
# 0 0
# 691
# asu
# masuk2
# masuk rendah
# 0 0
# 692
# masuk sii2
# tujuh <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 7
# 693
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 694
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 695
# masuk sii2
# 24.4 <class 'str'>
# persen <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 0.244
# 696
# asu
# masuk6
# masuk rendah
# 0 1
# 697
# asu
# masuk6
# masuk rendah
# 0 1
# 698
# asu
# masuk6
# masuk rendah
# 0 1
# 699
# masuk sii2
# seorang <class 'str'>
# asu
# masuk3
# masuk rendah
# 1 0
# 700
# asu
# masuk6
# masuk rendah
# 0 1
# 701
# masuk sii2
# 3 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 368 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 368
# 702
# asu
# masuk6
# masuk rendah
# 0 1
# 703
# masuk sii2
# 1.011 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 57 <class 'str'>
# asu
# masuk1
# masuk parah
# 1011 57
# 704
# asu
# masuk6
# masuk rendah
# 0 1
# 705
# masuk sii2
# 28 <class 'str'>
# masuk sii2
# enam <class 'str'>
# asu
# masuk11
# masuk parah
# 28 6
# 706
# asu
# masuk2
# masuk rendah
# 0 0
# 707
# asu
# masuk6
# masuk rendah
# 0 1
# 708
# masuk sii2
# sebanyak <class 'str'>
# 25 <class 'str'>
# asu
# masuk5
# masuk parah
# 25 0
# 709
# asu
# masuk6
# masuk rendah
# 0 1
# 710
# asu
# masuk6
# masuk rendah
# 0 1
# 711
# asu
# masuk2
# masuk rendah
# 0 0
# 712
# asu
# masuk6
# masuk rendah
# 0 1
# 713
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 714
# asu
# masuk2
# masuk rendah
# 0 0
# 715
# asu
# masuk2
# masuk rendah
# 0 0
# 716
# asu
# masuk9
# masuk rendah
# 1 1
# 717
# asu
# masuk6
# masuk rendah
# 0 1
# 718
# masuk sii2
# sebanyak <class 'str'>
# 12 <class 'str'>
# asu
# masuk11
# masuk parah
# 12 1
# 719
# masuk sii2
# enam <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 720
# asu
# masuk9
# masuk rendah
# 1 1
# 721
# asu
# masuk2
# masuk rendah
# 0 0
# 722
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# masuk sii2
# 418 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 418
# 723
# masuk sii2
# 12 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 12
# 724
# masuk sii2
# 60 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 60
# 725
# asu
# masuk6
# masuk rendah
# 0 1
# 726
# masuk sii2
# terakhir <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 727
# asu
# masuk2
# masuk rendah
# 0 0
# 728
# asu
# masuk6
# masuk rendah
# 0 1
# 729
# masuk sii2
# 71 <class 'str'>
# asu
# masuk11
# masuk parah
# 71 1
# 730
# masuk sii2
# 5\ <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 731
# asu
# masuk6
# masuk rendah
# 0 1
# 732
# masuk sii2
# 2018 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 733
# masuk sii2
# lima <class 'str'>
# masuk sii2
# lima <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 5
# 734
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 735
# masuk sii2
# sejumlah <class 'str'>
# masuk sii2
# seperempat <class 'str'>
# asu
# masuk14
# masuk sedang
# 8 1
# 736
# masuk sii2
# 7 <class 'str'>
# asu
# masuk14
# masuk sedang
# 7 1
# 737
# asu
# masuk6
# masuk rendah
# 0 1
# 738
# asu
# masuk6
# masuk rendah
# 0 1
# 739
# masuk sii2
# banyak <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 740
# masuk sii2
# 998 <class 'str'>
# asu
# masuk11
# masuk parah
# 998 1
# 741
# masuk sii2
# 25 <class 'str'>
# asu
# masuk11
# masuk parah
# 25 1
# 742
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 743
# asu
# masuk3
# masuk rendah
# 1 0
# 744
# asu
# masuk6
# masuk rendah
# 0 1
# 745
# asu
# masuk6
# masuk rendah
# 0 1
# 746
# asu
# masuk2
# masuk rendah
# 0 0
# 747
# asu
# masuk6
# masuk rendah
# 0 1
# 748
# masuk sii2
# berbagai <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 749
# asu
# masuk9
# masuk rendah
# 1 1
# 750
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 751
# asu
# masuk6
# masuk rendah
# 0 1
# 752
# asu
# masuk2
# masuk rendah
# 0 0
# 753
# masuk sii2
# dua <class 'str'>
# masuk sii2
# 112 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 112
# 754
# asu
# masuk6
# masuk rendah
# 0 1
# 755
# asu
# masuk6
# masuk rendah
# 0 1
# 756
# asu
# masuk2
# masuk rendah
# 0 0
# 757
# asu
# masuk9
# masuk rendah
# 1 1
# 758
# masuk sii2
# pertama <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 759
# asu
# masuk2
# masuk rendah
# 0 0
# 760
# masuk sii2
# 21 <class 'str'>
# asu
# masuk11
# masuk parah
# 21 1
# 761
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 762
# asu
# masuk6
# masuk rendah
# 0 1
# 763
# asu
# masuk2
# masuk rendah
# 0 0
# 764
# masuk sii2
# 1.800 <class 'str'>
# asu
# masuk1
# masuk parah
# 1800 5700000
# 765
# masuk sii2
# tiga <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 766
# masuk sii2
# sebanyak <class 'str'>
# masuk
# 0
# 767
# masuk sii2
# 136.000 <class 'str'>
# asu
# masuk11
# masuk parah
# 136000 1
# 768
# masuk sii2
# 15 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 15
# 769
# asu
# masuk6
# masuk rendah
# 0 1
# 770
# asu
# masuk6
# masuk rendah
# 0 1
# 771
# asu
# masuk2
# masuk rendah
# 0 0
# 772
# asu
# masuk6
# masuk rendah
# 0 1
# 773
# asu
# masuk6
# masuk rendah
# 0 1
# 774
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 2
# 775
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk14
# masuk sedang
# 10 1
# 776
# masuk sii2
# 2.500 <class 'str'>
# asu
# masuk1
# masuk parah
# 2500 68000
# 777
# masuk sii2
# 42 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 42
# 778
# asu
# masuk6
# masuk rendah
# 0 1
# 779
# masuk sii2
# 3x24 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 780
# masuk sii2
# dua <class 'str'>
# masuk sii2
# 181 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 181
# 781
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# 580 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 580
# 782
# masuk sii2
# 24 <class 'str'>
# asu
# masuk11
# masuk parah
# 24 1
# 783
# masuk sii2
# lima <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 784
# masuk sii2
# sebanyak <class 'str'>
# 3 <class 'str'>
# masuk sii2
# 627 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 627
# 785
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# 4 <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 4
# 786
# asu
# masuk6
# masuk rendah
# 0 1
# 787
# masuk sii2
# setiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 788
# asu
# masuk6
# masuk rendah
# 0 1
# 789
# masuk sii2
# satu <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 14 <class 'str'>
# asu
# masuk13
# masuk sedang
# 1 14
# 790
# masuk sii2
# sebanyak <class 'str'>
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 791
# masuk sii2
# 4 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 792
# masuk sii2
# 435.000 <class 'str'>
# masuk sii2
# 100 <class 'str'>
# asu
# masuk1
# masuk parah
# 435000 100
# 793
# masuk sii2
# 5.132 <class 'str'>
# masuk sii2
# 3.611 <class 'str'>
# asu
# masuk1
# masuk parah
# 5132 3611
# 794
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 13
# 795
# asu
# masuk6
# masuk rendah
# 0 1
# 796
# asu
# masuk2
# masuk rendah
# 0 0
# 797
# masuk sii2
# 114 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 114
# 798
# asu
# masuk2
# masuk rendah
# 0 0
# 799
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 5 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 5
# 800
# asu
# masuk6
# masuk rendah
# 0 1
# 801
# asu
# masuk2
# masuk rendah
# 0 0
# 802
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# 38 <class 'str'>
# asu
# masuk12
# masuk parah
# 4 38
# 803
# masuk sii2
# pertama <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 804
# masuk sii2
# sejumlah <class 'str'>
# masuk sii2
# 15 <class 'str'>
# asu
# masuk10
# masuk sedang
# 6 15
# 805
# masuk sii2
# 3.280 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 3280
# 806
# masuk sii2
# empat <class 'str'>
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk14
# masuk sedang
# 4 1
# 807
# asu
# masuk9
# masuk rendah
# 1 1
# 808
# masuk sii2
# lima <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 809
# masuk sii2
# 2018 <class 'str'>
# masuk sii
# sebanyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 810
# asu
# masuk9
# masuk rendah
# 1 1
# 811
# asu
# masuk6
# masuk rendah
# 0 1
# 812
# asu
# masuk9
# masuk rendah
# 1 1
# 813
# asu
# masuk9
# masuk rendah
# 1 1
# 814
# asu
# masuk6
# masuk rendah
# 0 1
# 815
# masuk sii2
# 12 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 12
# 816
# asu
# masuk6
# masuk rendah
# 0 1
# 817
# asu
# masuk9
# masuk rendah
# 1 1
# 818
# asu
# masuk6
# masuk rendah
# 0 1
# 819
# masuk sii2
# dua <class 'str'>
# masuk sii2
# 39 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 39
# 820
# masuk sii2
# 43 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 43
# 821
# asu
# masuk6
# masuk rendah
# 0 1
# 822
# asu
# masuk6
# masuk rendah
# 0 1
# 823
# asu
# masuk6
# masuk rendah
# 0 1
# 824
# masuk sii2
# 9 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 825
# asu
# masuk6
# masuk rendah
# 0 1
# 826
# asu
# masuk2
# masuk rendah
# 0 0
# 827
# asu
# masuk6
# masuk rendah
# 0 1
# 828
# asu
# masuk6
# masuk rendah
# 0 1
# 829
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 2
# 830
# masuk sii2
# satu-dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 831
# asu
# masuk6
# masuk rendah
# 0 1
# 832
# asu
# masuk6
# masuk rendah
# 0 1
# 833
# masuk sii2
# satu <class 'str'>
# masuk sii2
# terbanyak <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 834
# asu
# masuk6
# masuk rendah
# 0 1
# 835
# asu
# masuk2
# masuk rendah
# 0 0
# 836
# masuk sii2
# 8 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 8
# 837
# masuk sii2
# 3 <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 838
# masuk sii2
# 13 <class 'str'>
# asu
# masuk11
# masuk parah
# 13 1
# 839
# asu
# masuk6
# masuk rendah
# 0 1
# 840
# asu
# masuk3
# masuk rendah
# 1 0
# 841
# asu
# masuk6
# masuk rendah
# 0 1
# 842
# asu
# masuk6
# masuk rendah
# 0 1
# 843
# masuk sii2
# 17.00 <class 'str'>
# masuk sii2
# 17.00 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 844
# asu
# masuk2
# masuk rendah
# 0 0
# 845
# asu
# masuk6
# masuk rendah
# 0 1
# 846
# asu
# masuk2
# masuk rendah
# 0 0
# 847
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 848
# masuk sii2
# 4 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 4
# 849
# asu
# masuk2
# masuk rendah
# 0 0
# 850
# masuk sii2
# enam <class 'str'>
# masuk sii2
# 32 <class 'str'>
# asu
# masuk12
# masuk parah
# 6 32
# 851
# asu
# masuk6
# masuk rendah
# 0 1
# 852
# masuk sii2
# empat <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 4
# 853
# asu
# masuk2
# masuk rendah
# 0 0
# 854
# masuk sii2
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 855
# asu
# masuk6
# masuk rendah
# 0 1
# 856
# asu
# masuk6
# masuk rendah
# 0 1
# 857
# asu
# masuk6
# masuk rendah
# 0 1
# 858
# masuk sii2
# sebanyak <class 'str'>
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 859
# asu
# masuk6
# masuk rendah
# 0 1
# 860
# asu
# masuk6
# masuk rendah
# 0 1
# 861
# asu
# masuk6
# masuk rendah
# 0 1
# 862
# asu
# masuk2
# masuk rendah
# 0 0
# 863
# asu
# masuk6
# masuk rendah
# 0 1
# 864
# asu
# masuk2
# masuk rendah
# 0 0
# 865
# masuk sii2
# satu <class 'str'>
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 1 1
# 866
# asu
# masuk2
# masuk rendah
# 0 0
# 867
# asu
# masuk6
# masuk rendah
# 0 1
# 868
# asu
# masuk6
# masuk rendah
# 0 1
# 869
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 870
# masuk sii2
# 8 <class 'str'>
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk14
# masuk sedang
# 8 3
# 871
# asu
# masuk2
# masuk rendah
# 0 0
# 872
# asu
# masuk6
# masuk rendah
# 0 1
# 873
# asu
# masuk6
# masuk rendah
# 0 1
# 874
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# seseorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 875
# masuk sii2
# empat <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 876
# masuk sii2
# 112 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 112
# 877
# asu
# masuk6
# masuk rendah
# 0 1
# 878
# asu
# masuk2
# masuk rendah
# 0 0
# 879
# asu
# masuk6
# masuk rendah
# 0 1
# 880
# masuk sii2
# 250.000 <class 'str'>
# masuk sii2
# satu <class 'str'>
# asu
# masuk11
# masuk parah
# 250000 1
# 881
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 518 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 518
# 882
# asu
# masuk6
# masuk rendah
# 0 1
# 883
# asu
# masuk2
# masuk rendah
# 0 0
# 884
# asu
# masuk3
# masuk rendah
# 1 0
# 885
# asu
# masuk2
# masuk rendah
# 0 0
# 886
# asu
# masuk9
# masuk rendah
# 1 1
# 887
# asu
# masuk6
# masuk rendah
# 0 1
# 888
# asu
# masuk6
# masuk rendah
# 0 1
# 889
# asu
# masuk6
# masuk rendah
# 0 1
# 890
# masuk sii2
# tiga <class 'str'>
# masuk sii2
# 246 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 246
# 891
# asu
# masuk2
# masuk rendah
# 0 0
# 892
# masuk sii2
# 1.011 <class 'str'>
# asu
# masuk11
# masuk parah
# 1011 1
# 893
# masuk sii2
# 6 <class 'str'>
# masuk sii2
# 26 <class 'str'>
# asu
# masuk12
# masuk parah
# 6 26
# 894
# asu
# masuk9
# masuk rendah
# 1 1
# 895
# masuk sii2
# banyak <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 896
# asu
# masuk2
# masuk rendah
# 0 0
# 897
# asu
# masuk2
# masuk rendah
# 0 0
# 898
# masuk sii2
# 182 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 182
# 899
# masuk sii2
# 500 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 500
# 900
# asu
# masuk9
# masuk rendah
# 1 1
# 901
# masuk sii2
# 10 <class 'str'>
# asu
# masuk14
# masuk sedang
# 10 1
# 902
# asu
# masuk3
# masuk rendah
# 1 0
# 903
# asu
# masuk6
# masuk rendah
# 0 1
# 904
# masuk sii2
# banyak <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 905
# masuk sii2
# 16 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 16
# 906
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 2
# 907
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 908
# masuk sii2
# sebanyak <class 'str'>
# 3 <class 'str'>
# masuk sii2
# 91 <class 'str'>
# asu
# masuk12
# masuk parah
# 3 91
# 909
# asu
# masuk6
# masuk rendah
# 0 1
# 910
# masuk sii2
# berbagai <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 911
# asu
# masuk2
# masuk rendah
# 0 0
# 912
# asu
# masuk2
# masuk rendah
# 0 0
# 913
# asu
# masuk2
# masuk rendah
# 0 0
# 914
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 915
# asu
# masuk2
# masuk rendah
# 0 0
# 916
# masuk sii2
# 13 <class 'str'>
# masuk sii2
# seorang <class 'str'>
# asu
# masuk11
# masuk parah
# 13 1
# 917
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 4
# 918
# asu
# masuk6
# masuk rendah
# 0 1
# 919
# masuk sii2
# 8 <class 'str'>
# masuk sii2
# disapa <class 'str'>
# asu
# masuk14
# masuk sedang
# 8 1
# 920
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 921
# asu
# masuk3
# masuk rendah
# 1 0
# 922
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 2
# 923
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 924
# asu
# masuk2
# masuk rendah
# 0 0
# 925
# asu
# masuk6
# masuk rendah
# 0 1
# 926
# masuk sii2
# kedua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 927
# asu
# masuk6
# masuk rendah
# 0 1
# 928
# asu
# masuk2
# masuk rendah
# 0 0
# 929
# masuk sii2
# tiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 930
# asu
# masuk2
# masuk rendah
# 0 0
# 931
# asu
# masuk9
# masuk rendah
# 1 1
# 932
# masuk sii2
# 28 <class 'str'>
# masuk sii2
# enam <class 'str'>
# asu
# masuk11
# masuk parah
# 28 6
# 933
# asu
# masuk2
# masuk rendah
# 0 0
# 934
# asu
# masuk6
# masuk rendah
# 0 1
# 935
# asu
# masuk3
# masuk rendah
# 1 0
# 936
# masuk sii2
# 561 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 561
# 937
# asu
# masuk6
# masuk rendah
# 0 1
# 938
# asu
# masuk6
# masuk rendah
# 0 1
# 939
# masuk sii2
# 17.205 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 17205
# 940
# asu
# masuk2
# masuk rendah
# 0 0
# 941
# asu
# masuk2
# masuk rendah
# 0 0
# 942
# masuk sii2
# 561 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 561
# 943
# masuk sii2
# seorang <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 944
# masuk sii2
# 1 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 945
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 946
# asu
# masuk6
# masuk rendah
# 0 1
# 947
# asu
# masuk9
# masuk rendah
# 1 1
# 948
# asu
# masuk6
# masuk rendah
# 0 1
# 949
# asu
# masuk6
# masuk rendah
# 0 1
# 950
# asu
# masuk6
# masuk rendah
# 0 1
# 951
# asu
# masuk2
# masuk rendah
# 0 0
# 952
# asu
# masuk6
# masuk rendah
# 0 1
# 953
# masuk sii2
# 20 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 20
# 954
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 955
# masuk sii2
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 956
# asu
# masuk2
# masuk rendah
# 0 0
# 957
# asu
# masuk6
# masuk rendah
# 0 1
# 958
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 959
# asu
# masuk2
# masuk rendah
# 0 0
# 960
# asu
# masuk9
# masuk rendah
# 1 1
# 961
# asu
# masuk9
# masuk rendah
# 1 1
# 962
# asu
# masuk6
# masuk rendah
# 0 1
# 963
# asu
# masuk6
# masuk rendah
# 0 1
# 964
# asu
# masuk6
# masuk rendah
# 0 1
# 965
# asu
# masuk2
# masuk rendah
# 0 0
# 966
# masuk sii2
# 20 <class 'str'>
# persen <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 0.2
# 967
# masuk sii2
# kedua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 968
# asu
# masuk2
# masuk rendah
# 0 0
# 969
# asu
# masuk2
# masuk rendah
# 0 0
# 970
# asu
# masuk6
# masuk rendah
# 0 1
# 971
# asu
# masuk6
# masuk rendah
# 0 1
# 972
# masuk sii2
# 1 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 242 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 242
# 973
# masuk sii2
# seorang <class 'str'>
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 2
# 974
# asu
# masuk2
# masuk rendah
# 0 0
# 975
# asu
# masuk6
# masuk rendah
# 0 1
# 976
# asu
# masuk6
# masuk rendah
# 0 1
# 977
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 978
# asu
# masuk6
# masuk rendah
# 0 1
# 979
# asu
# masuk6
# masuk rendah
# 0 1
# 980
# masuk sii2
# seorang <class 'str'>
# asu
# masuk3
# masuk rendah
# 1 0
# 981
# masuk sii2
# 28 <class 'str'>
# masuk sii2
# enam <class 'str'>
# asu
# masuk11
# masuk parah
# 28 6
# 982
# asu
# masuk6
# masuk rendah
# 0 1
# 983
# asu
# masuk9
# masuk rendah
# 1 1
# 984
# asu
# masuk2
# masuk rendah
# 0 0
# 985
# masuk sii2
# 195 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 195
# 986
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 987
# masuk sii2
# sebanyak <class 'str'>
# 8.583 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 8583
# 988
# asu
# masuk6
# masuk rendah
# 0 1
# 989
# masuk sii2
# 601 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 601
# 990
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 991
# asu
# masuk6
# masuk rendah
# 0 1
# 992
# asu
# masuk2
# masuk rendah
# 0 0
# 993
# asu
# masuk3
# masuk rendah
# 1 0
# 994
# masuk sii2
# 1.010 <class 'str'>
# asu
# masuk11
# masuk parah
# 1010 1
# 995
# masuk sii2
# sebagian <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 996
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 2
# 997
# masuk sii2
# 1.011 <class 'str'>
# asu
# masuk11
# masuk parah
# 1011 1
# 998
# asu
# masuk6
# masuk rendah
# 0 1
# 999
# asu
# masuk2
# masuk rendah
# 0 0
# 1000
# asu
# masuk6
# masuk rendah
# 0 1
# 1001
# masuk sii2
# setiap <class 'str'>
# masuk sii2
# 242 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 242
# 1002
# asu
# masuk6
# masuk rendah
# 0 1
# 1003
# asu
# masuk6
# masuk rendah
# 0 1
# 1004
# asu
# masuk9
# masuk rendah
# 1 1
# 1005
# masuk sii2
# tujuh <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 7
# 1006
# asu
# masuk6
# masuk rendah
# 0 1
# 1007
# asu
# masuk6
# masuk rendah
# 0 1
# 1008
# masuk sii2
# 20 <class 'str'>
# asu
# masuk13
# masuk sedang
# 1 20
# 1009
# asu
# masuk9
# masuk rendah
# 1 1
# 1010
# asu
# masuk6
# masuk rendah
# 0 1
# 1011
# masuk sii2
# kedua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 1012
# masuk sii2
# 30 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 30
# 1013
# asu
# masuk6
# masuk rendah
# 0 1
# 1014
# asu
# masuk2
# masuk rendah
# 0 0
# 1015
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 14
# 1016
# masuk sii2
# 5 <class 'str'>
# masuk sii2
# tujuh <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 7
# 1017
# masuk sii2
# dua <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 1018
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1019
# asu
# masuk2
# masuk rendah
# 0 0
# 1020
# asu
# masuk6
# masuk rendah
# 0 1
# 1021
# masuk sii2
# semua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 1022
# asu
# masuk2
# masuk rendah
# 0 0
# 1023
# asu
# masuk6
# masuk rendah
# 0 1
# 1024
# masuk sii2
# 3 <class 'str'>
# masuk sii2
# 11 <class 'str'>
# asu
# masuk13
# masuk sedang
# 3 11
# 1025
# masuk sii2
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 1026
# masuk sii2
# semua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 5
# 1027
# masuk sii2
# banyak <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 1028
# masuk sii2
# 10 <class 'str'>
# asu
# masuk14
# masuk sedang
# 10 1
# 1029
# asu
# masuk9
# masuk rendah
# 1 1
# 1030
# asu
# masuk2
# masuk rendah
# 0 0
# 1031
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1032
# asu
# masuk2
# masuk rendah
# 0 0
# 1033
# masuk sii2
# sebanyak <class 'str'>
# 75 <class 'str'>
# asu
# masuk11
# masuk parah
# 75 1
# 1034
# masuk sii2
# 12 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 12
# 1035
# asu
# masuk2
# masuk rendah
# 0 0
# 1036
# asu
# masuk2
# masuk rendah
# 0 0
# 1037
# masuk sii2
# 743 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 743
# 1038
# asu
# masuk2
# masuk rendah
# 0 0
# 1039
# asu
# masuk6
# masuk rendah
# 0 1
# 1040
# masuk sii2
# empat <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 1
# 1041
# masuk sii2
# 3 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 3
# 1042
# masuk sii2
# lima <class 'str'>
# asu
# masuk14
# masuk sedang
# 5 1
# 1043
# asu
# masuk2
# masuk rendah
# 0 0
# 1044
# masuk sii2
# 180.000 <class 'str'>
# masuk sii2
# 15-19 <class 'str'>
# asu
# masuk11
# masuk parah
# 180000 1
# 1045
# masuk sii2
# tiga <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 1046
# asu
# masuk6
# masuk rendah
# 0 1
# 1047
# masuk sii2
# setiap <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 1048
# asu
# masuk6
# masuk rendah
# 0 1
# 1049
# asu
# masuk6
# masuk rendah
# 0 1
# 1050
# asu
# masuk6
# masuk rendah
# 0 1
# 1051
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk6
# masuk rendah
# 0 1
# 1052
# asu
# masuk2
# masuk rendah
# 0 0
# 1053
# asu
# masuk2
# masuk rendah
# 0 0
# 1054
# masuk sii2
# 24 <class 'str'>
# masuk sii2
# 263 <class 'str'>
# asu
# masuk1
# masuk parah
# 24 263
# 1055
# asu
# masuk2
# masuk rendah
# 0 0
# 1056
# asu
# masuk6
# masuk rendah
# 0 1
# 1057
# masuk sii2
# empat <class 'str'>
# asu
# masuk4
# masuk sedang
# 4 0
# 1058
# asu
# masuk2
# masuk rendah
# 0 0
# 1059
# masuk sii2
# 100 <class 'str'>
# masuk sii2
# 16.000 <class 'str'>
# asu
# masuk1
# masuk parah
# 100 16000
# 1060
# asu
# masuk6
# masuk rendah
# 0 1
# 1061
# asu
# masuk2
# masuk rendah
# 0 0
# 1062
# asu
# masuk6
# masuk rendah
# 0 1
# 1063
# asu
# masuk6
# masuk rendah
# 0 1
# 1064
# asu
# masuk2
# masuk rendah
# 0 0
# 1065
# asu
# masuk2
# masuk rendah
# 0 0
# 1066
# asu
# masuk9
# masuk rendah
# 1 1
# 1067
# masuk sii2
# tiga <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 1068
# masuk sii2
# 4 <class 'str'>
# masuk sii2
# 2017 <class 'str'>
# masuk sii
# asu
# masuk14
# masuk sedang
# 4 1
# 1069
# masuk sii2
# sebanyak <class 'str'>
# 1.610 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 1610
# 1070
# asu
# masuk2
# masuk rendah
# 0 0
# 1071
# asu
# masuk6
# masuk rendah
# 0 1
# 1072
# asu
# masuk2
# masuk rendah
# 0 0
# 1073
# asu
# masuk6
# masuk rendah
# 0 1
# 1074
# asu
# masuk6
# masuk rendah
# 0 1
# 1075
# masuk sii2
# 17.30 <class 'str'>
# masuk sii2
# tiga <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 3
# 1076
# asu
# masuk2
# masuk rendah
# 0 0
# 1077
# asu
# masuk9
# masuk rendah
# 1 1
# 1078
# masuk sii2
# setiap <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1079
# masuk sii2
# 4 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 1080
# asu
# masuk6
# masuk rendah
# 0 1
# 1081
# masuk sii2
# dua <class 'str'>
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 2 1
# 1082
# asu
# masuk2
# masuk rendah
# 0 0
# 1083
# asu
# masuk2
# masuk rendah
# 0 0
# 1084
# asu
# masuk6
# masuk rendah
# 0 1
# 1085
# asu
# masuk2
# masuk rendah
# 0 0
# 1086
# asu
# masuk6
# masuk rendah
# 0 1
# 1087
# asu
# masuk6
# masuk rendah
# 0 1
# 1088
# asu
# masuk6
# masuk rendah
# 0 1
# 1089
# asu
# masuk2
# masuk rendah
# 0 0
# 1090
# asu
# masuk6
# masuk rendah
# 0 1
# 1091
# asu
# masuk6
# masuk rendah
# 0 1
# 1092
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1093
# asu
# masuk6
# masuk rendah
# 0 1
# 1094
# masuk sii2
# 33 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 33
# 1095
# masuk sii2
# semua <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 1096
# asu
# masuk2
# masuk rendah
# 0 0
# 1097
# asu
# masuk2
# masuk rendah
# 0 0
# 1098
# asu
# masuk6
# masuk rendah
# 0 1
# 1099
# masuk sii2
# empat <class 'str'>
# masuk sii2
# empat <class 'str'>
# asu
# masuk14
# masuk sedang
# 4 4
# 1100
# asu
# masuk2
# masuk rendah
# 0 0
# 1101
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 390 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 390
# 1102
# asu
# masuk9
# masuk rendah
# 1 1
# 1103
# masuk sii2
# 1.772 <class 'str'>
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk11
# masuk parah
# 1772 1
# 1104
# asu
# masuk6
# masuk rendah
# 0 1
# 1105
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 466 <class 'str'>
# asu
# masuk12
# masuk parah
# 2 466
# 1106
# masuk sii2
# 14 <class 'str'>
# masuk sii2
# sebanyak <class 'str'>
# 335 <class 'str'>
# asu
# masuk1
# masuk parah
# 14 335
# 1107
# asu
# masuk6
# masuk rendah
# 0 1
# 1108
# asu
# masuk6
# masuk rendah
# 0 1
# 1109
# asu
# masuk6
# masuk rendah
# 0 1
# 1110
# asu
# masuk6
# masuk rendah
# 0 1
# 1111
# asu
# masuk2
# masuk rendah
# 0 0
# 1112
# masuk sii2
# sebanyak <class 'str'>
# 18 <class 'str'>
# masuk sii2
# 2021 <class 'str'>
# masuk sii
# asu
# masuk11
# masuk parah
# 18 1
# 1113
# asu
# masuk6
# masuk rendah
# 0 1
# 1114
# masuk sii2
# 2 <class 'str'>
# masuk sii2
# 9 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 9
# 1115
# asu
# masuk6
# masuk rendah
# 0 1
# 1116
# asu
# masuk2
# masuk rendah
# 0 0
# 1117
# masuk sii2
# sebanyak <class 'str'>
# 4 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4
# 1118
# masuk sii2
# 13.597 <class 'str'>
# asu
# masuk11
# masuk parah
# 13597 1
# 1119
# masuk sii2
# tiga <class 'str'>
# asu
# masuk9
# masuk rendah
# 3 1
# 1120
# asu
# masuk6
# masuk rendah
# 0 1
# 1121
# asu
# masuk9
# masuk rendah
# 1 1
# 1122
# asu
# masuk2
# masuk rendah
# 0 0
# 1123
# asu
# masuk9
# masuk rendah
# 1 1
# 1124
# asu
# masuk6
# masuk rendah
# 0 1
# 1125
# asu
# masuk6
# masuk rendah
# 0 1
# 1126
# asu
# masuk9
# masuk rendah
# 1 1
# 1127
# asu
# masuk6
# masuk rendah
# 0 1
# 1128
# asu
# masuk9
# masuk rendah
# 1 1
# 1129
# asu
# masuk8
# masuk parah
# 0 50000
# 1130
# asu
# masuk9
# masuk rendah
# 1 1
# 1131
# masuk sii2
# dosen <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1132
# asu
# masuk6
# masuk rendah
# 0 1
# 1133
# masuk sii2
# kebanyakan <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1134
# asu
# masuk2
# masuk rendah
# 0 0
# 1135
# asu
# masuk6
# masuk rendah
# 0 1
# 1136
# asu
# masuk6
# masuk rendah
# 0 1
# 1137
# asu
# masuk6
# masuk rendah
# 0 1
# 1138
# asu
# masuk9
# masuk rendah
# 1 1
# 1139
# masuk sii2
# satu <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 1140
# asu
# masuk6
# masuk rendah
# 0 1
# 1141
# asu
# masuk9
# masuk rendah
# 1 1
# 1142
# asu
# masuk3
# masuk rendah
# 1 0
# 1143
# asu
# masuk6
# masuk rendah
# 0 1
# 1144
# masuk sii2
# sebanyak <class 'str'>
# 591 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 591
# 1145
# masuk sii2
# satu <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1146
# asu
# masuk6
# masuk rendah
# 0 1
# 1147
# masuk sii2
# sembilan <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 9
# 1148
# masuk sii2
# 12 <class 'str'>
# masuk sii2
# 12 <class 'str'>
# asu
# masuk11
# masuk parah
# 12 12
# 1149
# asu
# masuk6
# masuk rendah
# 0 1
# 1150
# masuk sii2
# tujuh <class 'str'>
# masuk sii2
# 1.184 <class 'str'>
# asu
# masuk12
# masuk parah
# 7 1184
# 1151
# asu
# masuk2
# masuk rendah
# 0 0
# 1152
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 1 1
# 1153
# asu
# masuk2
# masuk rendah
# 0 0
# 1154
# asu
# masuk6
# masuk rendah
# 0 1
# 1155
# asu
# masuk6
# masuk rendah
# 0 1
# 1156
# asu
# masuk2
# masuk rendah
# 0 0
# 1157
# asu
# masuk6
# masuk rendah
# 0 1
# 1158
# masuk sii2
# dua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 1159
# masuk sii2
# 593 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 593
# 1160
# asu
# masuk6
# masuk rendah
# 0 1
# 1161
# asu
# masuk2
# masuk rendah
# 0 0
# 1162
# masuk sii2
# 30 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 30
# 1163
# masuk sii2
# kedua <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 1164
# asu
# masuk6
# masuk rendah
# 0 1
# 1165
# asu
# masuk9
# masuk rendah
# 1 1
# 1166
# asu
# masuk6
# masuk rendah
# 0 1
# 1167
# asu
# masuk6
# masuk rendah
# 0 1
# 1168
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1169
# asu
# masuk6
# masuk rendah
# 0 1
# 1170
# asu
# masuk2
# masuk rendah
# 0 0
# 1171
# masuk sii2
# sebanyak <class 'str'>
# 20 <class 'str'>
# asu
# masuk11
# masuk parah
# 20 1
# 1172
# asu
# masuk6
# masuk rendah
# 0 1
# 1173
# asu
# masuk2
# masuk rendah
# 0 0
# 1174
# asu
# masuk2
# masuk rendah
# 0 0
# 1175
# masuk sii2
# sebanyak <class 'str'>
# 17 <class 'str'>
# asu
# masuk11
# masuk parah
# 17 1
# 1176
# asu
# masuk6
# masuk rendah
# 0 1
# 1177
# masuk sii2
# 32 <class 'str'>
# masuk sii2
# dua <class 'str'>
# asu
# masuk11
# masuk parah
# 32 2
# 1178
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1179
# asu
# masuk2
# masuk rendah
# 0 0
# 1180
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 1 1
# 1181
# masuk sii2
# enam <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 1182
# masuk sii2
# seorang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1183
# asu
# masuk6
# masuk rendah
# 0 1
# 1184
# asu
# masuk9
# masuk rendah
# 1 1
# 1185
# masuk sii2
# 21 <class 'str'>
# asu
# masuk11
# masuk parah
# 21 1
# 1186
# asu
# masuk9
# masuk rendah
# 1 1
# 1187
# masuk sii2
# 2019 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 1 1
# 1188
# masuk sii2
# sebanyak <class 'str'>
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 1189
# masuk sii2
# seluruh <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 11
# 1190
# masuk sii2
# 2007-2019 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 1191
# asu
# masuk2
# masuk rendah
# 0 0
# 1192
# asu
# masuk6
# masuk rendah
# 0 1
# 1193
# asu
# masuk6
# masuk rendah
# 0 1
# 1194
# asu
# masuk3
# masuk rendah
# 1 0
# 1195
# masuk sii2
# 9.800 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 9800
# 1196
# masuk sii2
# 1.851 <class 'str'>
# asu
# masuk8
# masuk parah
# 0 1851
# 1197
# masuk sii2
# 11 <class 'str'>
# asu
# masuk5
# masuk parah
# 11 0
# 1198
# asu
# masuk9
# masuk rendah
# 1 1
# 1199
# asu
# masuk3
# masuk rendah
# 1 0
# 1200
# masuk sii2
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 1201
# asu
# masuk6
# masuk rendah
# 0 1
# 1202
# asu
# masuk2
# masuk rendah
# 0 0
# 1203
# asu
# masuk6
# masuk rendah
# 0 1
# 1204
# masuk sii2
# covid-19 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 1205
# masuk sii2
# sang <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 1
# 1206
# masuk sii2
# 6 <class 'str'>
# asu
# masuk14
# masuk sedang
# 6 1
# 1207
# asu
# masuk6
# masuk rendah
# 0 1
# 1208
# masuk sii2
# 14 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 14
# 1209
# masuk sii2
# 10 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 10
# 1210
# masuk sii2
# covid-19 <class 'str'>
# asu
# masuk9
# masuk rendah
# 1 1
# 1211
# masuk sii2
# beberapa <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 1212
# asu
# masuk6
# masuk rendah
# 0 1
# 1213
# masuk sii2
# 56 <class 'str'>
# persen <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 0.56
# 1214
# masuk sii2
# delapan <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 8
# 1215
# masuk sii2
# 16.099 <class 'str'>
# asu
# masuk12
# masuk parah
# 1 16099
# 1216
# asu
# masuk2
# masuk rendah
# 0 0
# 1217
# masuk sii2
# dua <class 'str'>
# masuk sii2
# 2020 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 2 1
# 1218
# asu
# masuk6
# masuk rendah
# 0 1
# 1219
# masuk sii2
# 2 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 2
# 1220
# asu
# masuk6
# masuk rendah
# 0 1
# 1221
# masuk sii2
# 6 <class 'str'>
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk14
# masuk sedang
# 6 1
# 1222
# asu
# masuk6
# masuk rendah
# 0 1
# 1223
# asu
# masuk2
# masuk rendah
# 0 0
# 1224
# masuk sii2
# sebanyak <class 'str'>
# 2 <class 'str'>
# asu
# masuk9
# masuk rendah
# 2 1
# 1225
# asu
# masuk2
# masuk rendah
# 0 0
# 1226
# masuk sii2
# satu <class 'str'>
# asu
# masuk3
# masuk rendah
# 1 0
# 1227
# asu
# masuk2
# masuk rendah
# 0 0
# 1228
# asu
# masuk2
# masuk rendah
# 0 0
# 1229
# asu
# masuk6
# masuk rendah
# 0 1
# 1230
# asu
# masuk2
# masuk rendah
# 0 0
# 1231
# masuk sii2
# 11 <class 'str'>
# asu
# masuk7
# masuk sedang
# 0 11
# 1232
# masuk sii2
# tiga <class 'str'>
# masuk sii2
# 2022 <class 'str'>
# masuk sii
# asu
# masuk9
# masuk rendah
# 3 1
# 1233
# masuk sii2
# 4 <class 'str'>
# asu
# masuk6
# masuk rendah
# 0 4

# %%
writer = pd.DataFrame(document_result, columns=['No Document','title','Description', 'Mati', 'Sakit','Keparahan'])
writer.to_excel('keparahan_1.xlsx', index=False)

# %%
# # keparahan1=''
# #         if((isinstance(mati,int) or mati.isdigit() or isinstance(mati,float)) and (isinstance(sakit,int) or isinstance(sakit,float) or sakit.isdigit())):
# #             # lansung parah
# #             if(mati>12 and sakit>20):
# #                 print('masuk1')
# #                 keparahan1='parah'
            
# #             # jika 0
# #             elif(mati==0 and sakit==0):
# #                 print('masuk2')
# #                 keparahan1='rendah'

# #             # kategori mati
# #             elif(mati<=3 and sakit==0):
# #                 print('masuk3')
# #                 keparahan1='rendah'
# #             elif(mati>3 and mati<=6 and sakit==0):
# #                 print('masuk4')
# #                 keparahan1='sedang'
# #             elif(mati>6 and sakit==0):
# #                 print('masuk5')
# #                 keparahan1='parah'

# #             # kategori sakit
# #             elif(mati==0 and sakit<=7):
# #                 print('masuk6')
# #                 keparahan1='rendah'
# #             elif(mati==0 and sakit>7 and sakit<=14):
# #                 print('masuk7')
# #                 keparahan1='sedang'
# #             elif(mati==0 and sakit>14):
# #                 print('masuk8')
# #                 keparahan1='parah'

# #              # kategori campuran rendah
# #             elif( mati<=3 and sakit<=7):
# #                 print('masuk9')
# #                 keparahan1='rendah'
# #             elif(mati<=3 and sakit>1):
# #                 print('masuk10')
# #                 keparahan1='rendah'
# #             elif(mati>1 and sakit<=7):
# #                 print('masuk11')
# #                 keparahan1='rendah'

# #              # kategori sedang
# #             elif(mati>3 and mati<=6 and sakit>7 and sakit<=14):
# #                 print('masuk12')
# #                 keparahan1='sedang'

# #             elif(mati>3 and mati<=6 and sakit>1):
# #                 print('masuk13')
# #                 keparahan1='sedang'

# #             elif(mati>1 and sakit>7 and sakit<=14):
# #                 print('masuk14')
# #                 keparahan1='sedang'

# #             # kategori campuran parah
# #             elif(mati>6 and sakit>1):
# #                 print('masuk15')
# #                 keparahan1='parah'
# #             elif(mati>1 and sakit>14):
# #                 print('masuk16')
# #                 keparahan1='parah'

           

           
# #             else:
# #                 keparahan1=''
        
# #         print('masuk',keparahan1)

# keparahan1=''
#         if((isinstance(mati,int) or isinstance(mati,float)) or mati.isdigit()and (isinstance(sakit,int) or isinstance(sakit,float) or sakit.isdigit())):
#             # lansung parah
#             if(int(mati)>10 and int(sakit)>25):
#                 print('masuk1')
#                 keparahan1='parah'
            
#             # jika 0
#             elif(mati==0 and sakit==0):
#                 print('masuk2')
#                 keparahan1='rendah'

#             # kategori mati
#             elif(int(mati)<=3 and sakit==0):
#                 print('masuk3')
#                 keparahan1='rendah'
#             elif(int(mati)>3 and int(mati)<=10 and sakit==0):
#                 print('masuk4')
#                 keparahan1='sedang'
#             elif(int(mati)>10 and sakit==0):
#                 print('masuk5')
#                 keparahan1='parah'

#             # kategori sakit
#             elif(mati==0 and int(sakit)<=10):
#                 print('masuk6')
#                 keparahan1='rendah'
#             elif(mati==0 and int(float(sakit))<=10):
#                 print('masuk 6 float')
#                 keparahan1='rendah' 
#             elif(mati==0 and int(float(sakit))>10 and int(float(sakit))<=25):
#                 print('masuk7')
#                 keparahan1='sedang'
#             elif(mati==0 and int(sakit)>25):
#                 print('masuk8')
#                 keparahan1='parah'

#              # kategori campuran rendah
#             elif( int(float(mati))<=3 and int(float(sakit))<=10):
#                 print('masuk9')
#                 keparahan1='rendah'

#              # kategori campuran sedang
#             elif(int(mati)>3 and int(mati)<=10 and int(sakit)>10 and int(sakit)<=25):
#                 print('masuk10')
#                 keparahan1='sedang'


#             # kategori campuran parah
#             elif(int(mati)>10 and int(sakit)>=0):
#                 print('masuk11')
#                 keparahan1='parah'
#             elif(int(mati)>=0 and int(sakit)>25):
#                 print('masuk12')
#                 keparahan1='parah'


#             #sedang
#             elif(int(mati)>=0 and int(sakit)>10 and int(sakit)<=25):
#                 print('masuk13')
#                 keparahan1='sedang'
#             elif(int(mati)>3 and int(mati)<=10 and int(sakit)>=0):
#                 print('masuk14')
#                 keparahan1='sedang'



           

           
#             else:
#                 keparahan1=''

# %%
teks='12'
print(teks,type(teks))
teks=float(teks)
print(teks,type(teks))
# Out:
# 12 <class 'str'>
# 12.0 <class 'float'>
