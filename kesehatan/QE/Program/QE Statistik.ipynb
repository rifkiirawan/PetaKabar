# %%
# !pip install keybert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keybert
#   Downloading keybert-0.5.1.tar.gz (19 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 8.1 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.21.6)
# Collecting rich>=10.4.0
#   Downloading rich-12.4.4-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 61.3 MB/s
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.7 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (2.6.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (4.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.4.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.19.4-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 49.7 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 67.9 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.7.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (4.11.4)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 8.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.6.2)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 75.6 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.8.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.5.18.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.1-py3-none-any.whl size=21332 sha256=56fa6a0bb7d08b68524355237116d7481d5f708252c9f977a7a9db08c3baada0
#   Stored in directory: /root/.cache/pip/wheels/8e/95/c5/f5ceed2a9f9e80bc1a706a10a6fb03d726df7a3dd11800a58b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=917699cb5806ea587ef4d87f36705b5cae06dd75a6158f9f68d2dbcdf67a6733
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built keybert sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, commonmark, sentence-transformers, rich, keybert
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed commonmark-0.9.1 huggingface-hub-0.7.0 keybert-0.5.1 pyyaml-6.0 rich-12.4.4 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.4

# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.19.4)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.12.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)

# %%
# !pip install yake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 8.2 MB/s
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake) (1.21.6)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 39.1 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake) (0.8.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake) (2.6.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from segtok->yake) (2022.6.2)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=74018 sha256=356fa9d8051ef4055611a6cdef771bd0217248e2bbc494218b22e8fe3af2a8f9
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw-1.4.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2021.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet31.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
# Import library-library
import os
import glob
from tqdm import tqdm
import numpy as np
import string

# Data Preparation and Preprocessing
import pandas as pd
import re
from string import digits

# Word Embedding
import joblib
from sentence_transformers import SentenceTransformer
embedder = SentenceTransformer('xlm-r-distilroberta-base-paraphrase-v1')
from keybert import KeyBERT
kw_extractor = KeyBERT('distilbert-base-nli-mean-tokens')
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy.sparse
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

# Input and Expansion Query
import nltk
import math
from textblob import TextBlob
from yake import KeywordExtractor
from nltk.tokenize import wordpunct_tokenize
from nltk.corpus import stopwords
from nltk import tokenize
from operator import itemgetter
from nltk.tokenize import word_tokenize
from textblob import TextBlob
from typing import Union
# Out:
# Downloading:   0%|          | 0.00/795 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/724 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/556 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
excluded_words = ["tempat", "waktu"]

NLTK_StopWords = stopwords.words('indonesian')
NLTK_StopWords.extend(["detik", "detikjatim", "detikjateng", "detikjabar", "detiksulsel", "detiksumbar", "detikbali", "detikpapua", "detiksulteng", "detikmaluku", "detjatim", "detikcom", "allahumma", "aamiin", "allah", "bismillah"])
NLTK_StopWords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])
txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
NLTK_StopWords.extend(txt_stopword["stopwords"][0].split(' '))
NLTK_StopWords = set(NLTK_StopWords)

# %%
# def preprocessing(berita):
#     # Preprocessing
#     s = berita.lower()
#     s = s.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
#     s = s.encode('ascii', 'replace').decode('ascii')
#     ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", s).split())
#     s.replace("http://", " ").replace("https://", " ")
#     s = re.sub('\s+', ' ', s)
#     s = s.strip()
#     s = s.translate(str.maketrans("","", string.punctuation))
#     s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
#     tokens = [token for token in s.split(" ") if token != ""]

#     # Stopwords checking
#     T = [t for t in tokens if ((t in excluded_words) or (t not in NLTK_StopWords))]
#     return T
def preprocessing(berita):
    s = str(berita)
    s = s.lower()
    s = s.replace('\n', ' ')
    s = s.replace('\r', ' ')
    s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
    tokens = [token for token in s.split(" ") if token != ""]
    T = [t for t in tokens if ((t in excluded_words) or (t not in NLTK_StopWords))]
    return T

# %%
from datetime import datetime, timedelta

month_to_number = {
  'jan': '01',
  'feb': '02',
  'mar': '03',
  'apr': '04',
  'mei': '05',
  'jun': '06',
  'jul': '07',
  'agu': '08',
  'sep': '09',
  'okt': '10',
  'nov': '11',
  'des': '12',
}

def getNewsTime(timestamp: str, news: str, source: str):
  if source == "www.detik.com":
    splitted_timestamp = timestamp.split()
    pre_formatted_time = splitted_timestamp[3] + '-' + month_to_number[splitted_timestamp[2].lower()] + '-' + splitted_timestamp[1] + ' ' + splitted_timestamp[4] + ':00'

    date_time_obj = datetime.strptime(pre_formatted_time, '%Y-%m-%d %H:%M:%S')
    
    # 0 sabtu, 1 05, 2 Mar, 3 2022, 4 15:33, 5 WIB
    if "kemarin" in news:
      yesterday = date_time_obj - timedelta(1)
      return yesterday.strftime('%Y-%m-%d %H:%M:%S')
    elif "selumbari" in news:
      daysago = date_time_obj - timedelta(2)
      return daysago.strftime('%Y-%m-%d %H:%M:%S')
    else:
      return date_time_obj

# %%
df_total = pd.read_csv('df_total.csv')
df_total = df_total[pd.notnull(df_total['description'])]
print(df_total.info())
print ('-'*90)
document_text= joblib.load('document_text_train.pkl')
print(len(document_text))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1372 entries, 0 to 1371
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1372 non-null   object
#  1   date         1372 non-null   object
#  2   description  1372 non-null   object
#  3   source       1372 non-null   object
# dtypes: object(4)
# memory usage: 53.6+ KB
# None
# ------------------------------------------------------------------------------------------
# 1234

# %%
df_test = pd.read_csv('df_test.csv')
df_test = df_test[pd.notnull(df_test['description'])]
print(df_test.info())
print ('-'*90)
document_text_test= joblib.load('document_text_test.pkl')
print(len(document_text_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 0 to 137
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        138 non-null    object
#  1   date         138 non-null    object
#  2   description  138 non-null    object
#  3   source       138 non-null    object
# dtypes: object(4)
# memory usage: 5.4+ KB
# None
# ------------------------------------------------------------------------------------------
# 138

# %%
df_train = pd.read_csv('df_train.csv')
df_train = df_train[pd.notnull(df_train['description'])]
print(df_train.info())
print ('-'*90)
document_text_train= joblib.load('document_text_train.pkl')
print(len(document_text_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1234 entries, 0 to 1233
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1234 non-null   object
#  1   date         1234 non-null   object
#  2   description  1234 non-null   object
#  3   source       1234 non-null   object
# dtypes: object(4)
# memory usage: 48.2+ KB
# None
# ------------------------------------------------------------------------------------------
# 1234

# %%
# Load bow dataset
df_bow_what = pd.read_csv("bow_kesehatan.csv")
df_bow_what.head()

df_bow_when = pd.read_csv("bow_when.csv")
df_bow_when.head()

df_bow_where = pd.read_csv("bow_where.csv")
df_bow_where.head()

df_bow_who = pd.read_csv("bow_who.csv")
df_bow_who.head()
# Out:
#    tingkat setelah parent     parent  \
# 0                       1     pelaku
# 1                       2  pelakunya
# 2                       2   tertuduh
# 3                       2  tersangka
# 4                       2   terdakwa
#
#                                           similarity
# 0  [('pelakunya', 0.705472469329834), ('tertuduh'...
# 1  [('pembunuhnya', 0.7638124823570251), ('tertud...
# 2  [('pemerkosa', 0.7687520980834961), ('terdakwa...
# 3  [('terdakwa', 0.7686344385147095), ('tertuduh'...
# 4  [('tersangka', 0.7686343193054199), ('tertuduh...

# %%
# Ambil parent dari bow
bow_list_what = []
bow_list_when = []
bow_list_where = []
bow_list_who = []

for i in range(0, df_bow_what.shape[0]):
  bow_list_what.append(df_bow_what.iloc[i, 1])

for i in range(0, df_bow_when.shape[0]):
  bow_list_when.append(df_bow_when.iloc[i, 1])

for i in range(0, df_bow_where.shape[0]):
  bow_list_where.append(df_bow_where.iloc[i, 1])

for i in range(0, df_bow_who.shape[0]):
  bow_list_who.append(df_bow_who.iloc[i, 1])

print("What ", bow_list_what[0])
print("When ", bow_list_when[0])
print("Where ", bow_list_where[0])
print("Who ", bow_list_who[0])

print({
  'What': len(bow_list_what),
  'When': len(bow_list_when),
  'Where': len(bow_list_where),
  'Who': len(bow_list_who)
})
# Out:
# What  kanker
# When  nan
# Where  surabaya
# Who  pelaku
# {'What': 22238, 'When': 11112, 'Where': 11111, 'Who': 12221}

# %%
# Use data train
def cari_dokpertama(kueriAsli: str):
    kueriPre = preprocessing(kueriAsli)
    kueriPre = " ".join(kueriPre)
    hasilSearch = []
    tfidf_matrix = joblib.load('tfidf_train.pkl')
    tfidf_vectorizer = joblib.load('vectorizer.pkl')
    query_vec = tfidf_vectorizer.transform([kueriPre])
    results = cosine_similarity(tfidf_matrix, query_vec).reshape((-1))
    for i in results.argsort()[-5:][::-1]:
        hasilSearch.append(df_total.iloc[i,-2])
    hasilSearch=". ".join(hasilSearch)
    
    return hasilSearch

# %%
##Keywords Extraction with YAKE
def keyword_yake(hasilSearch: str) -> list:
    keywordYake=[]

    k_extractor = KeywordExtractor(lan="id", n=1, top=50)
    k_extractor2 = KeywordExtractor(lan="id", n=2, top=50)
    keywords = k_extractor.extract_keywords(text=hasilSearch)
    # keywords = k_extractor2.extract_keywords(text=hasilSearch)
    keywords.extend(k_extractor2.extract_keywords(text=hasilSearch))
    keywordYake = [x for x, y in keywords]
    # keywordYake.append(keywords)
    print('*'*120)
    print('*'*120)
    print("Keyword yake")
    print(keywordYake)
    print('*'*120)
    print('*'*120)
    
    return keywordYake

# %%
#Keywords Extraction with TFIDF
def keyword_tfidf(hasilSearch: str) -> list:

    keywordtfidf=[]
    keywordtfidf2=[]

    total_words = re.sub(r'[^\w]', ' ', hasilSearch)
    total_words = total_words.lower().split()
    #print (total_words)
    total_word_length = len(total_words)
    total_sentences = tokenize.sent_tokenize(hasilSearch)
    total_sent_len = len(total_sentences)

    tf_score = {}
    for each_word in total_words:
        #print (each_word)
        each_word = each_word.replace('.','')
        if (each_word in excluded_words) or (each_word not in NLTK_StopWords):
            if each_word in tf_score:
                tf_score[each_word] += 1
            else:
                tf_score[each_word] = 1

    # Dividing by total_word_length for each dictionary element
    tf_score.update((x, y/int(total_word_length)) for x, y in tf_score.items())
    #print(tf_score)
    def check_sent(word, sentences): 
        final = [all([w in x for w in word]) for x in sentences] 
        sent_len = [sentences[i] for i in range(0, len(final)) if final[i]]
        return int(len(sent_len))

    idf_score = {}
    for each_word in total_words:
        #print (each_word)
        each_word = each_word.replace('.','')
        if (each_word in excluded_words) or (each_word not in NLTK_StopWords):
            if each_word in idf_score:
                idf_score[each_word] = check_sent(each_word, total_sentences)
            else:
                idf_score[each_word] = 1

    # Performing a log and divide
    idf_score.update((x, math.log(int(total_sent_len)/y)) for x, y in idf_score.items())

    #print(idf_score)
    tf_idf_score = {key: tf_score[key] * idf_score.get(key, 0) for key in tf_score.keys()}
    #print(tf_idf_score)
    def get_top_n(dict_elem, n):
        result = dict(sorted(dict_elem.items(), key = itemgetter(1), reverse = True)[:n]) 
        hasil =list(result.keys())
        #print(list(result.keys()))        
        return hasil
    #print(get_top_n(tf_idf_score, 25))
    #print(len(get_top_n(tf_idf_score, 1)))
    keywordtfidf.append(get_top_n(tf_idf_score, 25))
    for i in range(len(keywordtfidf)):
        #print (i)
        totalKw=0
        totalKw=len(keywordtfidf[i])
        for j in range(totalKw):
            #print (j)
            keywordtfidf2.append(keywordtfidf[i][j])
    
    print('*'*120)
    print('*'*120)
    print("Keyword TFIDF")
    print (keywordtfidf2)
    print('*'*120)
    print('*'*120)

    return keywordtfidf2

# %%
#Keywords Extraction with BERT
def keyword_bert(hasilSearch: str) -> list:

    keywordbert=[]

    #for j in range(len(array_text)):
    keyword1 = kw_extractor.extract_keywords(hasilSearch, top_n=50, keyphrase_ngram_range=(1, 1))
    keyword2 = kw_extractor.extract_keywords(hasilSearch, top_n=50, keyphrase_ngram_range=(1, 2))

    #print("Keywords of article\n", keywords)
    for i in range (0,len (keyword1)):
        keywordbert.append(keyword1[i][0])
        keywordbert.append(keyword2[i][0])
    
    print('*'*120)
    print('*'*120)
    print("Keyword Bert")
    print (keywordbert)
    print('*'*120)
    print('*'*120)
    
    return keywordbert

# %%
def rangking (keywordGabung: list, kueriAsli: str) -> list:
    kandidatFinalCek=[]
    kandidatFinalFix=[]
    
    for i in keywordGabung:
        if (i not in kandidatFinalCek and i!=0):
            kandidatFinalCek.append(i)
    queries=[kueriAsli]
    query_embeddings = embedder.encode(queries)
    corpus_embeddings4 = embedder.encode(kandidatFinalCek)
    # Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
    closest_n = 80
    for query, query_embedding in zip(queries, query_embeddings):
        distances = scipy.spatial.distance.cdist([query_embedding], corpus_embeddings4, 'cosine')[0]
        results = zip(range(len(distances)), distances)
        results = sorted(results, key=lambda x: x[1])
        for idx, distance in results[0:closest_n]:
            kandidatFinalFix.append(kandidatFinalCek[idx])

    print('*'*120)
    print('*'*120)
    print ('Kandidat Final Fix Rank: ', kandidatFinalFix)
    print('*'*120)
    print('*'*120)

    return kandidatFinalFix

# %%
def keywordCustomBow(bowList: list, initialQuery: str) -> list:
    cekDuplicate = []
    kandidatFix = []

    for i in bowList:
        if(i not in cekDuplicate and i!=0):
            cekDuplicate.append(i)

    queries=[initialQuery]
    query_embeddings = embedder.encode(queries)
    corpus_embeddings4 = embedder.encode(cekDuplicate)
    
    # Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
    closest_n = 500
    for query, query_embedding in zip(queries, query_embeddings):
        distances = scipy.spatial.distance.cdist([query_embedding], corpus_embeddings4, 'cosine')[0]
        results = zip(range(len(distances)), distances)
        results = sorted(results, key=lambda x: x[1])
        for idx, distance in results[0:closest_n]:
            kandidatFix.append(cekDuplicate[idx])
    
    print('*'*120)
    print('*'*120)
    print("Keyword BoW")
    print ('Kandidat BoW: ', kandidatFix)
    print('*'*120)
    print('*'*120)

    return kandidatFix

# %%
# Creating query for what, when, where, who
what_initial_query = "Kasus penyakit apa yang terjadi pada berita tersebut"
when_initial_query = "kapan waktu berita tersebut terjadi"
where_initial_query = "di daerah mana tempat (korban, pasien )penyakit berita itu terjadi"
who_initial_query = "siapa korban, personel, lembaga, badan, atau organisasi yang terlibat dalam berita"

what_query = preprocessing(what_initial_query)
what_query = " ".join(what_query)
print (what_query)

when_query = preprocessing(when_initial_query)
when_query = " ".join(when_query)
print (when_query)

where_query = preprocessing(where_initial_query)
where_query = " ".join(where_query)
print (where_query)

who_query = preprocessing(who_initial_query)
who_query = " ".join(who_query)
print (who_query)
# Out:
# korban pasien terjangkit penyakit covid tuberkulosis dbd hiv berita
# waktu berita
# daerah tempat korban pasien penyakit berita
# korban personel lembaga badan organisasi terlibat berita

# %%
def prepareWData(initial_query: str, bow_list: list):
    hasilkandidat = []
    keywordGabung = []
    qeGabungan = []
    kueriFix = []

    hasilSearch     = cari_dokpertama(initial_query)
    # (ini yake + tfidf + bert) = qe statistik
    keywordYake     = keyword_yake(hasilSearch) # 20
    keywordtfidf2   = keyword_tfidf(hasilSearch) # 20
    keywordbert     = keyword_bert(hasilSearch) # 20
    # ini qe bow
    keywordBoW      = keywordCustomBow(bow_list, initial_query)

    for keyword1 in keywordYake:
        keywordGabung.append(keyword1)
    for keyword2 in keywordtfidf2:
        keywordGabung.append(keyword2)
    for keyword3 in keywordbert:
        keywordGabung.append(keyword3)  

    # hasilrank = qe statistik
    hasilrank = rangking(keywordGabung, initial_query)
    
    for word1 in hasilrank:
        kueriFix.append(word1)

    for word2 in keywordBoW:
        kueriFix.append(word2)

    for word3 in kueriFix:
        hasilkandidat.append(word3)

    kueriFix = [preprocessing(i) for i in kueriFix]
    
    qeGabunganDelimiter = []

    for word4 in kueriFix:
        for subWord in word4:
            qeGabungan.append(subWord)
            qeGabunganDelimiter.append(subWord)

    qeGabunganDelimiter = list(dict.fromkeys(qeGabunganDelimiter))
    qeGabungan = list(dict.fromkeys(qeGabungan))

    # (hasil ranking + bow) = kandidat final
    qeGabungan = [" ".join(qeGabungan)]

    print('*'*120)
    qeStatistik = hasilrank
    qeBoW = keywordBoW

    return [qeGabungan, qeStatistik, qeBoW, qeGabunganDelimiter]

# %%
whatResultList = prepareWData(what_query, bow_list_what)
print("What")
print()
qeGabunganWhat = whatResultList[0]
qeStatistikWhat = whatResultList[1]
qeBoWWhat = whatResultList[2]
qeGabunganDelimiterWhat = whatResultList[3]
# Out:
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword yake
# ['covid', 'anjing', 'virus', 'malaria', 'nyamuk', 'rabies', 'yurianto', 'orang', 'berbahaya', 'dinyatakan', 'nakes', 'penyakit', 'omicron', 'mikroba', 'sars', 'mers', 'warga', 'hasil', 'dompu', 'terpapar', 'jakarta', 'anak', 'positif', 'isoman', 'pengendalian', 'microsporidia', 'pasien', 'dezi', 'kesehatan', 'terinfeksi', 'menjalani', 'masyarakat', 'pemeriksaan', 'corona', 'menganggap', 'tingkat', 'makassar', 'sembuh', 'influenza', 'keluarga', 'kematiannya', 'bandingkan', 'kecamatan', 'adi', 'liar', 'dinkes', 'difteri', 'pemerintah', 'pusat', 'serangga', 'yurianto covid', 'mers sars', 'sars tingkat', 'berbahaya yurianto', 'menganggap covid', 'berbahaya mers', 'virus rabies', 'covid', 'bandingkan sars', 'keluarga mers', 'bandingkan mers', 'mers bandingkan', 'anjing', 'virus', 'malaria', 'pengendalian penyakit', 'achmad yurianto', 'virus corona', 'tingkat kematiannya', 'kematiannya menganggap', 'keluarga influenza', 'nyamuk', 'wuhan berbahaya', 'berbahaya anggap', 'anggap berbahaya', 'berbahaya angka', 'rabies anjing', 'rabies', 'varian omicron', 'yurianto', 'dinyatakan sembuh', 'orang', 'dasarnya keluarga', 'corona achmad', 'berbahaya', 'kematiannya covid', 'influenza menurutnya', 'angka kematiannya', 'dinyatakan', 'nakes', 'penyakit', 'hasil pemeriksaan', 'dinyatakan terpapar', 'terpapar omicron', 'nakes dinyatakan', 'omicron', 'litbangkes jakarta', 'dinkes makassar', 'media center', 'nakes terpapar']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword TFIDF
# ['5d', 'dezi', '52540684', '5b2020', '05', '06t04', 'tenang', 'menghadapi', 'perkembangan', 'situasi', 'wabah', 'wuhan', 'silam', 'tataran', 'pemahaman', 'penyebabnya', 'juru', 'bicara', 'penanganan', 'achmad', 'media', 'center', 'gedung', 'bina', 'graha']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword Bert
# ['influenza', 'keluarga influenza', '3adf1b2f51', 'pengaduan virus', 'virus', 'penyakit influenza', 'flu', 'virus berbahaya', 'penggunaan', 'influenza virus', 'indonesia', 'virus penyebabnya', 'malaria', 'virus mematikan', 'mengimbau', 'penanganan virus', 'tenggara', 'corona virus', 'menganggap', 'pengendalian malaria', 'menggelewa', 'virus corona', 'mengendalikan', 'virus rabies', 'e48f19dd2a74', 'warga virus', 'pengendalian', 'influenza menurutnya', 'jakarta', 'mengendalikan malaria', '2fmajalah', 'pemblokiran malaria', 'langkah', 'mengandung virus', 'kabupaten', 'malaria kebanyakan', 'lingkungan', 'malaria pemblokiran', 'menghancurkan', 'virus menular', 'meningkatkan', 'wabah virus', 'pendekatan', 'adi virus', '5bilmuwan', 'masyarakat virus', 'kecamatan', 'virus wuhan', '5b2020', 'menghentikan malaria', '20detik', 'meninggal malaria', 'mengejar', 'malaria bertahan', 'mengizinkan', 'daerah virus', 'batuk', 'malaria mikroba', 'meningkat', 'melawan malaria', 'kematiannya', 'virus research', 'mengklaim', 'malaria microsporidia', 'kematian', 'influenza', 'langsung', 'malaria kelompok', 'mengumumkan', 'signifikan malaria', 'menghentikan', 'menekan malaria', 'menginfeksi', 'penyelamat malaria', 'tenggorokan', 'penyebaran virus', '5bdetik', 'rabies menghantui', 'muhammad', 'malaria racun', 'tingkat', 'malaria percobaan', 'rabies', 'litbangkes jakarta', '112104687', 'memblokir malaria', 'lombok', 'malaria memiliki', 'menghadapi', 'nyamuk malaria', 'warga', 'utara malaria', 'menggigit', 'mengandung rabies', 'pemblokiran', 'malaria mewabah', 'pusat', 'kecamatan menggelewa', 'menghantui', 'malaria sulawesi']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword BoW
# Kandidat BoW:  ['tuberkulosis', 'tuberculosis', 'tbc', 'epidemi', 'epidemik', 'infectious', 'infeksi', 'sifilis', 'terjangkit', 'antibiotik', 'patogenesis', 'wabah', 'takikardia', 'virus', 'gonorrhea', 'diagnostik', 'diabetes', 'streptococcus', 'penyakitnya', 'antibiotika', 'diabetik', 'hepatitis', 'bakterial', 'profilaksis', 'dislipidemia', 'trombosis', 'influenza', 'bakteri', 'tirotoksikosis', 'mellitus', 'congenital', 'dbd', 'patologis', 'metabolik', 'biopsi', 'kandidiasis', 'malabsorpsi', 'keguguran', 'difteri', 'diabetic', 'inflamasi', 'diagnosa', 'hipertensi', 'penyakit', 'trombositopenia', 'respiratorik', 'pulmonary', 'meningokokus', 'pneumoniae', 'variola', 'reumatik', 'pasien', 'gagal ginjal', 'kehamilan', 'vaskulitis', 'hpv', 'diagnosis', 'vaksinasi', 'rabies', 'sterilisasi', 'herpes', 'tularemia', 'vaksin', 'pneumonia', 'diare', 'nefritis', 'hamil', 'imunisasi', 'kongenital', 'hipertrofi', 'badai sitokin', 'endokarditis', 'hipofisis', 'gejalanya', 'gejala', 'simtoma', 'rematik', 'gastritis', 'perdarahan', 'obesitas', 'zika', 'eritema', 'kelainan', 'tumor', 'angioedema', 'penularan', 'idiopatik', 'sindroma', 'sindrom', 'distokia', 'hiv', 'patofisiologi', 'bruselosis', 'pankreatitis', 'eritromisin', 'kemoterapi', 'gizi buruk', 'iritasi', 'hipertrofik', 'stenosis', 'rotavirus', 'komplikasi', 'fibrosis', 'disease', 'ulkus', 'radioterapi', 'testis', 'trauma', 'kebutaan', 'konstipasi', 'obstruksi', 'septicemia', 'hipertiroidisme', 'tiroid', 'hipotensi', 'psikosis', 'parvovirus', 'kecacatan', 'typhoid', 'klinis', 'atrofi', 'adenovirus', 'leptospirosis', 'histoplasmosis', 'intestinal', 'mukosa', 'strok', 'gagal jantung', 'epilepsi', 'alergi', 'endometrium', 'retardasi', 'uterus', 'hipotiroidisme', 'prostat', 'tifus', 'asidosis', 'bengkak', 'pendarahan', 'peritonitis', 'hemangioma', 'akut', 'terluka', 'parainfluenza', 'pembedahan', 'disfungsi', 'perikarditis', 'tetanus', 'covid', 'pyogenes', 'urticaria', 'mukus', 'giardiasis', 'kegemukan', 'penyumbatan', 'antihistamin', 'melitus', 'malformasi', 'hipotalamus', 'terapi', 'lutut', 'cmv', 'ppok', 'pandemi', 'psoriasis', 'nervosa', 'muntah', 'rhinitis', 'fibrilasi', 'chlamydia', 'ischemia', 'pandemik', 'mycobacterium', 'listeriosis', 'autis', 'neisseria', 'nefropati', 'chronic', 'trakoma', 'menopause', 'toksoplasmosis', 'kudis', 'bronkitis', 'kelumpuhan', 'otoimun', 'fraktur', 'cacingan', 'karsinoma', 'defisiensi', 'tubulus', 'mimisan', 'gatal', 'paha', 'pembengkakan', 'hepatomegali', 'edema', 'neurologis', 'eksaserbasi', 'skizofrenia', 'paralisis', 'memar', 'cystic', 'bronchitis', 'cacat', 'nekrosis', 'peradangan', 'beguk', 'hipotonia', 'adenoma', 'eksem', 'kelaparan', 'luka', 'kejang', 'nyeri', 'sistik', 'melepuh', 'terkilir', 'pleuritis', 'flu burung', 'tarda', 'skoliosis', 'abnormal', 'sekresi', 'gastroenteritis', 'bisul', 'jerawat', 'artritis', 'rektum', 'kecemasan', 'megaloblastik', 'rubella', 'lukanya', 'cikungunya', 'rheumatoid', 'anafilaksis', 'defek', 'tifoid', 'enteritis', 'aids', 'alternaria', 'haemophilus', 'chikungunya', 'uremia', 'robek', 'pankreas', 'autoimun', 'nefrogenik', 'autisme', 'kram', 'gusi', 'kardiomiopati', 'fobia', 'iskemik', 'neutropenia', 'abses', 'lepuh', 'rubela', 'tenggorokan', 'dadanya', 'mononukleosis', 'urtikaria', 'pirai', 'plak', 'nanah', 'halusinasi', 'reumatoid', 'influenzae', 'demensia', 'tipus', 'kolitis', 'jantung', 'hirschsprung', 'epithelium', 'maag', 'miokardial', 'berkeringat', 'pilek', 'osteoporosis', 'cerebral', 'ruam', 'insomnia', 'sarkoidosis', 'kaposi', 'skleroderma', 'sembelit', 'meningitis', 'limfoma', 'feline', 'granulomatosis', 'bordetella', 'malaria', 'sinusitis', 'keseleo', 'serviks', 'penapisan', 'lesi', 'anemia', 'radang', 'stres', 'apendisitis', 'limpa', 'kolik', 'ulcerative', 'cacar', 'candyloma', 'kusta', 'ketidaknyamanan', 'insipidus', 'kanker', 'pleura', 'migrain', 'alergen', 'pegal', 'hipoglisemia', 'disentri', 'linu', 'zoster', 'aterosklerosis', 'hiperplasia', 'leukemia', 'retinopati', 'degenerasi', 'botulisme', ' ...
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Kandidat Final Fix Rank:  ['terinfeksi', 'penanganan virus', 'menginfeksi', 'warga virus', 'penyebaran virus', 'pengaduan virus', 'mengandung virus', 'virus menular', 'virus penyebabnya', 'wabah virus', 'masyarakat virus', 'mengandung rabies', 'daerah virus', 'virus rabies', 'nyamuk malaria', 'virus mematikan', 'malaria kelompok', 'meninggal malaria', 'virus berbahaya', 'signifikan malaria', 'rabies menghantui', 'influenza virus', 'wabah', 'adi virus', 'virus', 'pengendalian penyakit', 'melawan malaria', 'malaria percobaan', 'pengendalian malaria', 'malaria racun', 'malaria mewabah', 'virus wuhan', 'virus research', 'utara malaria', 'malaria mikroba', 'angka kematiannya', 'penyelamat malaria', 'tingkat kematiannya', 'mengendalikan malaria', 'influenza', 'malaria pemblokiran', 'malaria kebanyakan', 'mikroba', 'menghentikan malaria', 'penyakit influenza', 'influenza menurutnya', 'serangga', 'difteri', 'pemblokiran malaria', 'penyakit', 'corona virus', 'menekan malaria', 'pasien', 'kesehatan', 'memblokir malaria', 'rabies', 'virus corona', 'hasil pemeriksaan', 'malaria microsporidia', 'keluarga influenza', 'wuhan berbahaya', 'nyamuk', 'berbahaya yurianto', 'malaria sulawesi', 'nakes terpapar', 'penanganan', 'litbangkes jakarta', 'menghantui', 'microsporidia', 'malaria bertahan', 'rabies anjing', 'berbahaya angka', 'covid', 'dezi', '112104687', 'dinyatakan sembuh', 'masyarakat', 'malaria memiliki', 'positif', 'muhammad']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# What

# %%
whoResultList = prepareWData(who_query, bow_list_who)
print("Who")
print()
qeGabunganWho = whoResultList[0]
qeStatistikWho = whoResultList[1]
qeBoWWho = whoResultList[2]
qeGabunganDelimiterWho = whoResultList[3]
# Out:
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword yake
# ['stunting', 'hiv', 'roti', 'bayi', 'anak', 'indonesia', 'pemerintah', 'aids', 'pengobatan', 'paru', 'var', 'sarapan', 'kota', 'orang', 'meninggal', 'wanita', 'pneumonia', 'masyarakat', 'gigitan', 'penurunan', 'puskesmas', 'memiliki', 'dbd', 'nasi', 'against', 'anjing', 'kekebalan', 'action', 'rabies', 'tubuh', 'virus', 'mitos', 'perempuan', 'sistem', 'pusat', 'ipul', 'salah', 'percepatan', 'program', 'gizi', 'jembrana', 'rusia', 'kematian', 'berumur', 'siberia', 'penyelidik', 'menderita', 'menyebabkan', 'statemen', 'gus', 'paru paru', 'virus hiv', 'hiv mitos', 'bayi perempuan', 'pusat aids', 'paru bayi', 'penurunan stunting', 'hiv meninggal', 'sistem kekebalan', 'positif hiv', 'stunting', 'menolak pengobatan', 'menderita hiv', 'against stunting', 'hiv', 'bayi positif', 'hiv menolak', 'kematian bayi', 'bayi berumur', 'penyelidik bayi', 'roti', 'terjangkit hiv', 'hiv merusak', 'bayi', 'action against', 'terganggu bayi', 'bayi didiagnosis', 'perempuan meninggal', 'meninggal rusia', 'menderita pneumonia', 'pneumonia menyebabkan', 'siberia wanita', 'aids wilayah', 'terkena aids', 'aids dirawat', 'kepala hiv', 'pengobatan untuknya', 'infeksi paru', 'stunting day', 'pengobatan anak', 'perempuan berumur', 'statemen pusat', 'anak anak', 'siberia penyelidik', 'penyelidik statemen', 'rusia menderita', 'anak', 'indonesia', 'kekebalan tubuh', 'pembunuhan wanita']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword TFIDF
# ['2017', 'hiv', 'gizi', '70', 'ibunya', 'untuknya', 'percaya', 'penyelidikan', 'dinyatakan', 'terjangkit', 'menghadapi', 'tuntutan', 'pembunuhan', 'terancam', 'hukuman', 'penjara', 'maksimum', 'irkutsk', 'februari', 'pneumocystis', 'jenis', 'infeksi', 'terganggu', 'perempuannya', 'dilansir']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword Bert
# ['hiv', 'terjangkit hiv', 'pneumonia', 'menderita hiv', 'menimbulkan', 'hiv meninggal', 'menyosialisasikan', 'pneumonia menyebabkan', 'mendiskriminasi', 'menderita pneumonia', 'meningkatkan', 'mencegah virus', 'mencukupi', 'hiv mitos', 'virus', 'hiv menolak', 'menguatkan', 'akibat pneumonia', 'komersialitas', 'kepala hiv', 'meningkat', 'pneumonia pneumocystis', 'menyalahkan', 'jenis pneumonia', 'menyatukan', 'virus hiv', 'mencegah', 'positif hiv', 'ketidaknikmatan', 'hiv merusak', 'menggerutu', 'pneumonia data', 'mengimbau', 'hiv', 'mengiklankan', 'anggarannya mencukupi', 'mengidentifikasi', 'menyalahkan paramedis', 'menyinggung', 'berpotensi menimbulkan', 'hijau', 'paramedis mengklaim', 'mengantisipasi', 'menyosialisasikan mencegah', 'mencapai', 'mencukupi kebutuhan', 'menyebabkan', 'menyebabkan penyakit', 'menerima', 'mendiskriminasi sanggup', 'mengklaim', 'hiv 10', 'kabupaten', 'menguatkan komitmen', 'menggantikan', 'jembrana mencukupi', 'pengobatan', 'puskesmas menyosialisasikan', 'dengue', 'mengiklankan mentega', 'pendidikan', 'roti mendiskriminasi', 'paramedis', 'kacang hijau', 'digambarkan', 'menimbulkan genangan', 'mengikuti', 'pengobatan mencegah', 'keterlibatan', 'kebersamaan menyatukan', 'gaya', 'pengobatan medis', 'keberhasilan', 'pneumonia', 'meninggal', 'menyinggung gaya', 'menyediakan', 'mengiklankan roti', 'menganggap', 'pungkas dr', 'menyantap', 'menolak pengobatan', 'penghujan', 'menyantap roti', 'kebutuhan', 'meninggal februari', 'tuntutan', 'mencukupi membeli', 'menyuarakan', 'menerima roti', 'epigenetik', 'lingkungan insyaallah', 'puspitarini', 'aids mencapai', 'melengkapi', 'penyakit mengikuti', 'penyembuhan', 'percaya virus', 'kedigdayaan', 'ketidaknikmatan manusia']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword BoW
# Kandidat BoW:  ['wiraswastawan', 'korbannya', 'investigasi', 'penyelidik', 'korban', 'kontroversi', 'stafnya', 'kecemasan', 'akuntabilitas', 'filantropis', 'investigator', 'penggeledahan', 'kemalangan', 'diinterogasi', 'tahlilan', 'pengungkapan', 'penyelidikan', 'kepegawaian', 'dilanggar', 'skandal', 'krisis', 'birokrat', 'penyelamat', 'tunawisma', 'penyangkalan', 'kritikusnya', 'pengusutan', 'sindikat', 'korupsi', 'rekapitulasi', 'penyidikan', 'pelanggaran', 'penganiaya', 'konsekuensi', 'ketidaksetiaan', 'kekejaman', 'persekongkolan', 'penyanderaan', 'sengketa', 'penghinaan', 'disembelih', 'pembasmian', 'penggerebekan', 'provocateur', 'widyawati', 'pemberdayaan', 'simpatisan', 'situasi', 'ekskomunikasi', 'peneliti', 'selamatan', 'dipersalahkan', 'penindakan', 'penuntutan', 'fungsionaris', 'wirausahawan', 'nekrofilia', 'pembalikan', 'kecerobohan', 'tanggungjawab', 'penjagaan', 'memberantas', 'interogasi', 'ketatanegaraan', 'kesukaran', 'pengritik', 'kecurangan', 'etnografer', 'penyadaran', 'pendukungnya', 'penyiksaan', 'prostitusi', 'kebrutalan', 'desepsi', 'narapidana', 'intimidasi', 'pemberantasan', 'perwira', 'pebisnis', 'inspektur', 'pembelajar', 'penderitaan', 'penculikan', 'kesusilaan', 'insiden', 'sanksi', 'sukarelawan', 'penyerbuan', 'perselingkuhan', 'perzinahan', 'pendisiplinan', 'kriminalitas', 'coordinator', 'akuntan', 'kemunafikan', 'kesewenang', 'memvonis', 'interniran', 'konspirasi', 'segregasi', 'konspirator', 'auditing', 'penyuluhan', 'kamerawan', 'megawati', 'keputusan', 'penyelewengan', 'antikorupsi', 'penjudi', 'penyembahnya', 'spekulan', 'penyalahgunaan', 'penindasan', 'penyeludupan', 'penyantun', 'pengusiran', 'pembalasan', 'wirausaha', 'pengintaian', 'persekusi', 'usahawan', 'dipukuli', 'dieksekusi', 'kesengsaraan', 'infiltrasi', 'menganiaya', 'kecurigaan', 'fitnah', 'dimutilasi', 'aborsi', 'kesusahan', 'kriminalisasi', 'disalahgunakan', 'penyalinan', 'ketidakadilan', 'pendahagi', 'konsultasi', 'persoalan', 'penghindaran', 'teknisi', 'ambulans', 'penyandera', 'pelacuran', 'ketertiban', 'biarawati', 'exploit', 'pengungsi', 'akademisi', 'pengkhianatan', 'pembangkang', 'diskriminasi', 'kemungkaran', 'ilmuan', 'sanctie', 'penangkapan', 'penganiayaan', 'penyesed', 'disiksa', 'ditawan', 'pelecehan', 'kelalaian', 'sabotase', 'pemalsuan', 'mematuhi', 'penjarahan', 'kesedihan', 'audit', 'intervensi', 'kemaksiatan', 'overdosis', 'pembajakan', 'kegagalannya', 'masturbasi', 'interogator', 'penyeludup', 'pendampingan', 'stigma', 'gerilyawan', 'konsultan', 'nasionalis', 'mengkhianati', 'pengusaha', 'eksploitasi', 'kotakapolresta', 'kriminal', 'provokasi', 'perekrut', 'homoseksualitas', 'pelanggar', 'deadites', 'dijatuhi', 'kesulitan', 'pengabaian', 'pengucilan', 'dipidana', 'joedodihardjo', 'residivis', 'dijebloskan', 'auditor', 'humaniter', 'kemurtadan', 'informan', 'pidana', 'penculik', 'kaderisasi', 'ketidakpastian', 'pengeroyokan', 'supervisory', 'pencegahan', 'pergolakan', 'penculiknya', 'akikah', 'obregón', 'ditimpakan', 'penggalang', 'tergeletak', 'pewira', 'penyusupan', 'perusakan', 'pemerkosaan', 'repatrian', 'pengamanan', 'mengharamkan', 'penyimpangan', 'penanggulangan', 'pencurian', 'percabulan', 'pingsan', 'siswanto', 'kewajiban', 'penangguhan', 'pembersihan', 'ketidaksukaan', 'petugas', 'dipenggal', 'wenangan', 'preventif', 'kegelisahan', 'ketetapan', 'penikaman', 'prabowo', 'meremehkan', 'webmasters', 'ketidakpuasan', 'dipatuhi', 'pemerasan', 'remisi', 'kebejatan', 'spionase', 'penakut', 'kekisruhan', 'hasutan', 'istinbath', 'permasalahan', 'keangkuhan', 'eutanasia', 'siksaan', 'kesombongan', 'paramedis', 'frustasi', 'hekatonkheire', 'kewenangan', 'pangkopkamtib', 'melacurkan', 'penyergapan', 'pemeriksa', 'dihukum', 'perompakan', 'ketidaksetujuan', 'syariat', 'ketamakan', 'pendusta', 'pembebas', 'keburukan', 'kekeliruan', 'penyusup', 'penjahit', 'perdata', 'stereotipe', 'penahanan', 'wewenang', 'berzina', 'ketentuan', 'embargo', 'sentimen', 'penggugat', 'masalah', 'ditaati', 'abortus', 'profesional', 'te ...
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Kandidat Final Fix Rank:  ['penyelidik statemen', 'penyelidik', 'puskesmas menyosialisasikan', 'aids dirawat', 'kematian bayi', 'pembunuhan wanita', 'kedigdayaan', 'penyelidik bayi', 'penyelidikan', 'perempuan meninggal', 'pusat aids', 'masyarakat', 'paramedis mengklaim', 'hiv merusak', 'infeksi', 'aids wilayah', 'mendiskriminasi', 'menyalahkan paramedis', 'menyebabkan penyakit', 'pengobatan anak', 'penyakit mengikuti', 'roti mendiskriminasi', 'terganggu bayi', 'terjangkit', 'menderita hiv', 'pneumonia data', 'terkena aids', 'mengidentifikasi', 'ketidaknikmatan manusia', 'terganggu', 'keterlibatan', 'penyembuhan', 'kebersamaan menyatukan', 'siberia penyelidik', 'menderita', 'terancam', 'aids mencapai', 'mendiskriminasi sanggup', 'pneumonia menyebabkan', 'keberhasilan', 'ketidaknikmatan', 'menimbulkan genangan', 'menyosialisasikan mencegah', 'penurunan stunting', 'terjangkit hiv', 'kematian', 'dilansir', 'penurunan', 'aids', 'komersialitas', 'paramedis', 'akibat pneumonia', 'puspitarini', 'menyebabkan', 'menyinggung', 'siberia wanita', 'infeksi paru', 'menyatukan', 'pengobatan', 'pendidikan', 'hiv meninggal', 'puskesmas', 'menyantap', 'menimbulkan', 'menyosialisasikan', 'pembunuhan', 'pemerintah', 'penghujan', 'kekebalan tubuh', 'mengiklankan', 'menderita pneumonia', 'hukuman', 'rusia menderita', 'menyuarakan', 'statemen', 'meninggal', 'dinyatakan', 'tuntutan', 'digambarkan', 'mitos']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Who

# %%
whenResultList = prepareWData(when_query, bow_list_when)
print("When")
print()
qeGabunganWhen = whenResultList[0]
qeStatistikWhen = whenResultList[1]
qeBoWWhen = whenResultList[2]
qeGabunganDelimiterWhen = whenResultList[3]
# Out:
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword yake
# ['wawan', 'rusman', 'kesehatan', 'data', 'dono', 'covid', 'bpjs', 'sampel', 'pulang', 'rawa', 'makassar', 'orang', 'kabupaten', 'rumah', 'korban', 'memancing', 'anjing', 'omicron', 'natania', 'kota', 'pemancingan', 'ditemukan', 'desa', 'warga', 'jkn', 'varian', 'gizi', 'inhil', 'sumbawa', 'gigitan', 'masyarakat', 'rabies', 'informasi', 'keluarga', 'epilepsinya', 'dinas', 'kecamatan', 'gumuk', 'mas', 'penyakit', 'kambuh', 'mat', 'bambang', 'keberadaan', 'jasad', 'pelayanan', 'ppid', 'menyebut', 'dusun', 'minggu', 'wawan pulang', 'pulang rusman', 'bpjs kesehatan', 'keberadaan wawan', 'jasad wawan', 'rawa pemancingan', 'wawan', 'rusman wawan', 'data sampel', 'penyakit epilepsinya', 'epilepsinya kambuh', 'rusman pulang', 'gumuk mas', 'mat bambang', 'rusman', 'dono rusman', 'pulang dono', 'wawan ditemukan', 'kesehatan', 'memancing rusman', 'data', 'kematian wawan', 'desa dono', 'dono', 'rusman mat', 'rusman keberadaan', 'bambang dono', 'rawa penyakit', 'wawan dibawa', 'covid', 'gardu dono', 'dono divisum', 'pemancingan ditemukan', 'bernama wawan', 'mendapati wawan', 'wawan tempatnya', 'menduga wawan', 'wawan bertetangga', 'wawan pencarian', 'wawan takdir', 'wawan memiliki', 'jenazah wawan', 'bpjs', 'varian omicron', 'sampel', 'kambuh memancing', 'kota makassar', 'temannya rusman', 'pagi rusman', 'ppid bpjs']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword TFIDF
# ['19', 'gizi', 'covid', 'wawan', 'warga', 'sumbawa', 'varian', 'rawa', 'informasi', 'pemancing', 'tewas', 'panggul', 'melati', 'kepanjen', 'jember', 'terjatuh', 'kapolsek', 'akp', 'sugiharto', 'bernama', '36', 'krajan', 'wonorejo', 'kencong', 'berangkat']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword Bert
# ['keterlibatan', 'terdistribusikan kabupaten', 'kabupaten', 'warga kabupaten', 'mengunjungi', 'wonorejo kecamatan', 'kepesertaan', 'kolaborasi keterlibatan', 'terjangkit', 'kabupaten tergolong', 'mengoptimalkan', 'kemarin mengunjungi', 'lingkungan', 'diedukasi pengolahan', 'kecamatan', 'lingkungan rumah', 'merekomendasikan', 'anjing kabupaten', 'keluarga', 'terpercaya menghindari', 'terdistribusikan', 'kecamatan kencong', 'sugiharto', 'epilepsinya kambuh', 'bantuan', 'kepanjen kecamatan', 'bertetangga', 'kesehatan terdistribusikan', 'terpercaya', 'keluarga deritanya', 'pengendalian', 'kecamatan poto', 'ketersediaan', 'mas kabupaten', 'mengajukan', 'menerima kematian', 'keterbatasan', 'berasal keluarga', 'penyelenggaraan', 'mengikuti kegiatan', 'pemangku', 'keluarga berbuat', 'pembangunan', 'mengunjungi rumah', 'berkunjung', 'mengolahnya pembentukan', 'tenggara', 'divisum keluarga', 'diberitakan', 'kabupaten jember', 'dibutuhkan', 'kecamatan taliwang', 'tugas', 'keterlibatan inovasi', 'penyelenggara', 'kabupaten pulau', 'keberadaan', 'mempercepat pembangunan', 'dievakuasi', 'merekomendasikan gejala', 'kematian', 'pembangunan kesehatan', 'panggul', 'rabies pengendalian', 'pengelolaan', 'suspek 9603', 'kebijakan', 'taliwang tergigit', 'berangkat', 'masyarakat mengajukan', 'menentukan', 'membebaskan keluarga', 'difungsikan', 'kabupaten sumbawa', 'ketua', 'menyebabkan keluarga', 'pengantar', 'anjing kecamatan', 'pembentukan', 'regulasi berlaku', 'penyalahgunaan', 'keluarga menolak', 'tingkat', 'takdir keluarga', 'berlaku', 'tingkat lanjutan', 'kesempatan', 'memutuskan pulang', 'pengolahan', 'mengimbau masyarakat', 'mengikuti', 'korban berangkat', 'diluncurkan', 'rabies kabupaten', 'mengolahnya', 'menentukan kepala', 'minggunya', 'kesehatan meluncurkan', 'tempatnya', 'bertetangga rusman']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword BoW
# Kandidat BoW:  ['zamannya', 'zaman', 'ajalnya', 'ajal', 'waktunya', 'masanya', 'ajalku', 'diwaktu', 'waktu', 'jaman', 'dizaman', 'purnawaktu', 'masa', 'semasa', 'jamannya', 'featurette', 'kisah', 'kisaran', 'saat', 'bermasa', 'siang', 'apabila', 'dimasa', 'ketika', 'disekitar', 'sewaktu', 'survei', 'tempoh', 'numerik', 'penerbitannya', 'vonis', 'saatnya', 'nyaris', 'kesibukannya', 'cerita', 'penayangannya', 'disaat', 'pencabutan', 'manakala', 'kendati', 'dihari', 'sejam', 'subuh', 'peramalan', 'repot', 'perjumlahan', 'harinya', 'penentuan', 'kerap', 'presesi', 'serie', 'perkata', 'ketahuan', 'kondangan', 'acara', 'pencatatan', 'penyamaran', 'dilangsungkan', 'nyadran', 'penayangan', 'pekan', 'diawal', 'kendatipun', 'per', 'menyantap', 'persebaya', 'berjam', 'siangnya', 'sekon', 'meneken', 'perkuliahan', 'menjelang', 'pemungutan', 'kartana', 'taksiran', 'nyepi', 'berurutan', 'hajatan', 'reda', 'kejurnas', 'tiba', 'pengesahan', 'ditaburi', 'kesukaran', 'pagi', 'disiang', 'peluruhan', 'hitungan', 'gelaran', 'menerkam', 'dinihari', 'dilokasi', 'saptaresi', 'seiringnya', 'penjumlahan', 'tayangan', 'diukur', 'onsd', 'telanjur', 'kegelisahan', 'tepakyang', 'hari', 'sepanjang', 'cuplikan', 'erg', 'sambil', 'pengda', 'mendatar', 'sebelum', 'volt', 'dipagi', 'ratus', 'gebyar', 'bergegas', 'imbang', 'estimasi', 'rapatan', 'arakan', 'babak', 'takbiran', 'pemutaran', 'raihaanun', 'tahunya', 'perangan', 'pada', 'dimatangkan', 'jumat', 'berderet', 'maka', 'yadnya', 'selagi', 'witir', 'resepsi', 'diperas', 'ruwatan', 'karir', 'menjebak', 'kabisat', 'serinya', 'chansung', 'sedangkan', 'saking', 'pulalah', 'ketepatan', 'menyusul', 'hubung', 'ytse', 'atraksi', 'era', 'setangkup', 'eranya', 'mbit', 'akhirnya', 'wsp', 'sesaat', 'dirubah', 'tatkala', 'pendataan', 'penyambutan', 'maret', 'terkenang', 'pertanggal', 'cuti', 'pakasa', 'deret', 'nukrashi', 'jam', 'khitanan', 'hayat', 'allaihi', 'lintasnya', 'gemangnya', 'takbir', 'yg', 'rentang', 'menguap', 'kegiatannya', 'dikocok', 'kaping', 'sejenak', 'tahun', 'zuhur', 'menyegi', 'berjumlah', 'seraya', 'ratap', 'infotama', 'tirakatan', 'gondrong', 'terlelap', 'menitnya', 'jumlah', 'berselang', 'kapasitansi', 'nauchnyj', 'pemecatan', 'menyusuri', 'pengeraman', 'priode', 'ketebalannya', 'minggu', 'kemauannya', 'sekarat', 'tersebut', 'terlewati', 'pekannya', 'perhari', 'analisa', 'optimasi', 'berbadai', 'kalibrasi', 'penjelmaan', 'dasawarsa', 'di', 'kesudahannya', 'narasi', 'aktivitasnya', 'dijemur', 'kaget', 'terabit', 'puasa', 'kujelang', 'ribu', 'tahunnya', 'diproses', 'kenduri', 'dihaluskan', 'pemutarannya', 'kemunculannya', 'saklar', 'tahlilan', 'rojak', 'tugas', 'torsi', 'sabtu', 'dzuhur', 'mengurutkan', 'sedari', 'paska', 'kurva', 'kalau', 'cungkring', 'durasi', 'setalah', 'aruh', 'sehar', 'sesuai', 'setebal', 'berhari', 'kegiatan', 'syebat', 'usd', 'kst', 'anno', 'rudra', 'tertentu', 'awatara', 'maghrib', 'birkat', 'pancawara', 'motzei', 'dikala', 'penyebut', 'digoreng', 'rayakan', 'pingsan', 'adlen', 'librasi', 'musim', 'senandung', 'iyatul', 'grasi', 'siklus', 'telat', 'diaduk', 'pergelaran', 'cest', 'penghulu', 'penjadwalannya', 'direndam', 'bersegi', 'tertunda', 'ditunda', 'ronde', 'aksis', 'perkerjaan', 'pertahun', 'kurun', 'mbyte', 'sukat', 'penanggalan', 'suntuk', 'jeda', 'tetapan', 'kemudian', 'akhir', 'wita', 'remisi', 'ketebalan', 'spasi', 'paginya', 'suatu', 'menjalani', 'sapar', 'malaman', 'direbus', 'adven', 'kisahnya', 'galamai', 'kemudia', 'invers', 'pepet', 'jabar', 'bersangkutan', 'putaran', 'bainai', 'sempat', 'alokasi', 'peringati', 'untuk', 'pertandigan', 'seharinya', 'dekade', 'kelengkungan', 'dikemudian', 'dimasak', 'detiknya', 'detik', 'pelataran', 'muharam', 'optimal', 'romlah', 'tatanan', 'yakni', 'menghabiskan', 'diadakan', 'prediksi', 'ngeplang', 'bercucuk', 'konsentrik', 'kasmaran', 'cembung', 'dasarnya', 'periode', 'menentukan', 'upacara', 'didikte', 'fatihah', 'inet', 'tayang', 'malah', 'populasi', 'dirangkai', 'nadanya', 'bergulirnya', 'lembarnya', 'puluh', 'kekuasaa ...
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Kandidat Final Fix Rank:  ['diberitakan', 'berlaku', 'masyarakat', 'dusun', 'terpercaya', 'pengantar', 'krajan', 'minggu', 'sugiharto', 'tugas', 'orang', 'desa', 'kesempatan', 'mengikuti kegiatan', 'menentukan', 'korban', 'gumuk', 'jkn', 'diluncurkan', 'menyebut', 'kota', 'mat', 'ketua', 'sumbawa', 'dono', 'mengimbau masyarakat', 'kapolsek', 'rawa', 'pengolahan', 'difungsikan', 'pembangunan', 'keterlibatan', 'panggul', 'informasi', 'kabupaten', 'jasad wawan', 'kecamatan', 'wawan tempatnya', 'varian', 'bernama', 'covid', 'penyakit', 'minggunya', 'wonorejo', 'keterbatasan', 'natania', 'makassar', 'jember', 'kepanjen', 'jasad', 'wawan', 'tingkat', 'berkunjung', 'rumah', 'tewas', 'mendapati wawan', 'kambuh', 'pulang dono', 'kepesertaan', 'warga', 'mengajukan', 'kematian', 'wawan pulang', 'mengolahnya', 'ketersediaan', 'terdistribusikan', 'lingkungan', 'wawan pencarian', 'kesehatan', 'rusman wawan', 'terjatuh', 'pelayanan', 'pengendalian', 'wawan takdir', 'tenggara', 'sampel', 'menduga wawan', 'kepanjen kecamatan', 'bpjs', 'akp']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# When

# %%
whereResultList = prepareWData(where_query, bow_list_where)
print("Where")
print()
qeGabunganWhere = whereResultList[0]
qeStatistikWhere = whereResultList[1]
qeBoWWhere = whereResultList[2]
qeGabunganDelimiterWhere = whereResultList[3]
# Out:
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword yake
# ['hiv', 'stunting', 'bayi', 'kota', 'aids', 'pengobatan', 'paru', 'orang', 'menolak', 'var', 'pemerintah', 'indonesia', 'meninggal', 'wanita', 'pneumonia', 'makassar', 'penurunan', 'covid', 'gigitan', 'masyarakat', 'anak', 'against', 'puskesmas', 'danny', 'kekebalan', 'dbd', 'anjing', 'warga', 'kesehatan', 'action', 'virus', 'mitos', 'perempuan', 'sistem', 'pusat', 'wilayah', 'rabies', 'rusia', 'berumur', 'siberia', 'penyelidik', 'menderita', 'menyebabkan', 'statemen', 'percepatan', 'ipul', 'positif', 'jembrana', 'aash', 'gus', 'menolak pengobatan', 'hiv menolak', 'paru paru', 'virus hiv', 'hiv mitos', 'bayi perempuan', 'pusat aids', 'aids wilayah', 'sistem kekebalan', 'paru bayi', 'hiv meninggal', 'hiv', 'penurunan stunting', 'menderita hiv', 'stunting', 'wilayah bayi', 'positif hiv', 'bayi berumur', 'penyelidik bayi', 'against stunting', 'bayi positif', 'action against', 'terjangkit hiv', 'hiv merusak', 'bayi', 'perempuan meninggal', 'terganggu bayi', 'bayi didiagnosis', 'meninggal rusia', 'menderita pneumonia', 'pneumonia menyebabkan', 'siberia wanita', 'terkena aids', 'aids dirawat', 'ibunya menolak', 'pengobatan untuknya', 'infeksi paru', 'perempuan berumur', 'statemen pusat', 'siberia penyelidik', 'penyelidik statemen', 'rusia menderita', 'kota', 'pengobatan anak', 'kepala hiv', 'kekebalan tubuh', 'pembunuhan wanita', 'wanita terancam', 'meninggal februari', 'pneumonia pneumocystis']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword TFIDF
# ['gizi', 'lazismu', '70', '743', '16', '63', 'ibunya', 'untuknya', 'percaya', 'penyelidikan', 'terjangkit', 'menghadapi', 'tuntutan', 'pembunuhan', 'terancam', 'hukuman', 'penjara', 'maksimum', 'irkutsk', 'februari', 'pneumocystis', 'jenis', 'infeksi', 'terganggu', 'perempuannya']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword Bert
# ['hiv', 'terjangkit hiv', 'pneumonia', 'menderita hiv', 'menimbulkan', 'hiv meninggal', 'menyosialisasikan', 'pneumonia menyebabkan', 'meningkatkan', 'menderita pneumonia', 'mencukupi', 'mencegah virus', 'menyelesaikan', 'hiv mitos', 'virus', 'hiv menolak', 'menguatkan', 'akibat pneumonia', 'meningkat', 'kepala hiv', 'menyalahkan', 'pneumonia pneumocystis', 'menyatukan', 'jenis pneumonia', 'mencegah', 'virus hiv', 'mengimbau', 'positif hiv', 'mengidentifikasi', 'hiv merusak', 'mengantisipasi', 'pneumonia data', 'mencapai', 'hiv', 'menyebabkan', 'anggarannya mencukupi', 'mengklaim', 'menyalahkan paramedis', 'kabupaten', 'berpotensi menimbulkan', 'pengobatan', 'paramedis mengklaim', 'dengue', 'menyosialisasikan mencegah', 'pendidikan', 'mencukupi kebutuhan', 'paramedis', 'menyebabkan penyakit', 'mengikuti', 'hiv 10', 'keterlibatan', 'menguatkan komitmen', 'meninggal', 'jembrana mencukupi', 'menyediakan', 'puskesmas menyosialisasikan', 'menganggap', 'warga menyelesaikan', 'penghujan', 'menimbulkan genangan', 'kebutuhan', 'pengobatan mencegah', 'tuntutan', 'kebersamaan menyatukan', 'menyuarakan', 'pengobatan medis', 'epigenetik', 'pneumonia', 'puspitarini', 'pungkas dr', 'penyembuhan', 'menolak pengobatan', 'menginisiasi', 'meninggal februari', 'mengajak', 'mencukupi membeli', 'pengembangan', 'lingkungan insyaallah', 'lingkungan', 'aids mencapai', 'pasuruan', 'penyakit mengikuti', 'puskemas', 'percaya virus', 'menumbuhkan', 'danny mengimbau', 'menghadapi', 'tubuh menyebabkan', 'pemangku', 'bertujuan menguatkan', 'detikbali', 'menyediakan anggaran', 'kontribusi', 'pengobatan untuknya', 'kekebalan', 'menekan penyakit', 'anggarannya', 'detikbali telepon', 'pengurangan', 'lingkungan pengasuhan']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Keyword BoW
# Kandidat BoW:  ['kusumanegara', 'tidung', 'waingapu', 'banjarnegara', 'persebaya', 'sumbersuko', 'pangandaran', 'depdikbud', 'mangkunegaran', 'soekapoera', 'pengharepan', 'indragiri', 'kertanegara', 'tidore', 'kotabumi', 'bangkalan', 'pagedangan', 'kesunanan', 'padangsidimpuan', 'stisip', 'kudarat', 'rangkasbitung', 'tulungagung', 'citeureup', 'wijayandanu', 'epicentrum', 'pajajaran', 'kramatwatu', 'peninjawan', 'petilasan', 'ngaglik', 'kepatihan', 'unsrat', 'pulogadung', 'parangtritis', 'madiun', 'majapahit', 'kertapati', 'adiwerna', 'mungkid', 'kasunanan', 'trenggalek', 'mataram', 'karanganyar', 'pelalawan', 'kedungwaringin', 'lekatompessy', 'provinsi', 'qoryati', 'tembilahan', 'propinsi', 'metromini', 'kertosono', 'sidomukti', 'temuguruh', 'marabahan', 'kotagede', 'senopati', 'ternate', 'kauman', 'cibitung', 'condongcatur', 'haurgeulis', 'pejaten', 'danlanud', 'morowali', 'prabumulih', 'pematangsiantar', 'sumenep', 'demangan', 'kediri', 'mukomuko', 'kalimantan', 'caringin', 'pemprov', 'pringsewu', 'padangsidempuan', 'kipan', 'purwakarta', 'pademangan', 'tembalang', 'bengkalis', 'magetan', 'gresik', 'temanggung', 'cisaat', 'pajarakan', 'mempawah', 'medan', 'kauderni', 'persiraja', 'muhamadiyah', 'prapatan', 'mataraman', 'pandeglang', 'kancana', 'cibadak', 'brebes', 'gambringan', 'istana', 'bedagai', 'kahuripan', 'ngemplak', 'skj', 'mangkunagaran', 'prembun', 'sepatan', 'pangkajene', 'prov', 'cigudeg', 'bubutan', 'pabuaran', 'pekalongan', 'pusdik', 'parapat', 'rogojampi', 'sragen', 'kentungan', 'natuna', 'kartasura', 'moencang', 'tapanuli', 'batujajar', 'tembesi', 'ujungberung', 'tanjungpinang', 'cikudapateuh', 'tarakan', 'jogjakarta', 'langkat', 'pekanbaru', 'meruya', 'pepatih', 'sebuku', 'kroya', 'jogyakarta', 'bojonegoro', 'jailolo', 'pengda', 'hadiwijaya', 'cikampek', 'takalar', 'metrotrans', 'nias', 'prupuk', 'pamulang', 'dayeuhkolot', 'pinrang', 'perumnas', 'jakarta', 'jogya', 'persipare', 'meiska', 'belitung', 'sumedang', 'serasan', 'pemkot', 'sukolilo', 'pemkab', 'surakarta', 'sokaraja', 'majalaya', 'supadio', 'sekayu', 'prabu', 'bumiayu', 'perbaungan', 'semplak', 'mindanao', 'lempuyangan', 'kasepuhan', 'nganjuk', 'kendan', 'mahbubah', 'pontianak', 'pemda', 'palembang', 'tanahabang', 'persemalra', 'rantau', 'lumajang', 'kts', 'cimahi', 'halmahera', 'pakualaman', 'cibatu', 'jatiwarna', 'blambangan', 'mranggen', 'depok', 'kutoarjo', 'kerinci', 'manyaran', 'kampar', 'cibiru', 'srondol', 'bondowoso', 'parani', 'kedungjati', 'palangkaraya', 'pasirian', 'pandanaran', 'sunter', 'kunta', 'rukan', 'persigo', 'batanghari', 'jogja', 'karangtengah', 'kalisat', 'sofifi', 'cibubur', 'sindangkasih', 'kadiri', 'resto', 'kepanjen', 'pusdikpassus', 'ketapang', 'gadingrejo', 'sumobito', 'ajibarang', 'tuntang', 'slipi', 'magelang', 'janggala', 'ciranjang', 'ciawi', 'indralaya', 'pangkalpinang', 'labuha', 'rengat', 'husada', 'jebres', 'demak', 'ranuyoso', 'plawad', 'curahmalang', 'rukti', 'namlea', 'tumapel', 'cibeber', 'bandung', 'enrekang', 'parepare', 'makassar', 'cianjur', 'merangin', 'pendapa', 'mengwi', 'batusangkar', 'garut', 'jurug', 'bpn', 'baturaja', 'sulawesi', 'umbulharjo', 'bogor', 'pagaralam', 'cipaku', 'pacitan', 'ciwidey', 'bacan', 'hadiningrat', 'pakunagara', 'buntok', 'pasai', 'singojuruh', 'peterongan', 'suryopranoto', 'lamongan', 'hadiprojo', 'wonorejo', 'nongsa', 'paringin', 'persin', 'jombor', 'persenga', 'bekasi', 'kta', 'kalimalang', 'psbl', 'cinangka', 'cipeundeuy', 'sanana', 'kundur', 'kebumen', 'guguk', 'klaten', 'cijeruk', 'asahan', 'ranai', 'situbondo', 'persma', 'balung', 'tasikmalaya', 'yogyakarta', 'tarempa', 'jatibening', 'unpar', 'poris', 'pusdiklatpassus', 'kridosono', 'tanimbar', 'kalbar', 'sukoharjo', 'samarinda', 'purwosari', 'jatiroto', 'kandangan', 'jombang', 'kalteng', 'kertanagara', 'widyatmaka', 'kosambi', 'tapos', 'sumbar', 'manise', 'wates', 'deli', 'bengkulu', 'sungailiat', 'psps', 'muntilan', 'kendal', 'babelan', 'bitung', 'tanjungbalai', 'tenggarong', 'netpac', 'panaikang', 'tigaraksa', 'sur ...
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Kandidat Final Fix Rank:  ['penyelidik statemen', 'pusat aids', 'lingkungan pengasuhan', 'menekan penyakit', 'aids wilayah', 'menyebabkan penyakit', 'pengobatan anak', 'aids dirawat', 'pengobatan', 'penyakit mengikuti', 'penyelidik', 'masyarakat', 'paramedis', 'infeksi', 'pengobatan medis', 'paramedis mengklaim', 'pneumonia data', 'terjangkit', 'kesehatan', 'terkena aids', 'menyalahkan paramedis', 'puspitarini', 'penyembuhan', 'menderita hiv', 'penyelidik bayi', 'terjangkit hiv', 'pengobatan mencegah', 'wilayah bayi', 'penyelidikan', 'wilayah', 'pembunuhan wanita', 'menginisiasi', 'statemen pusat', 'lingkungan insyaallah', 'pneumonia pneumocystis', 'puskesmas menyosialisasikan', 'perempuan meninggal', 'pneumocystis', 'warga', 'menderita', 'kabupaten', 'detikbali', 'siberia penyelidik', 'pneumonia', 'menimbulkan genangan', 'penghujan', 'pengobatan untuknya', 'infeksi paru', 'puskesmas', 'pengurangan', 'aids', 'kekebalan tubuh', 'akibat pneumonia', 'pengembangan', 'siberia wanita', 'pusat', 'statemen', 'terganggu', 'hiv merusak', 'pneumonia menyebabkan', 'kontribusi', 'penurunan', 'detikbali telepon', 'jenis pneumonia', 'percepatan', 'menimbulkan', 'bayi berumur', 'menderita pneumonia', 'keterlibatan', 'meninggal', 'menyosialisasikan mencegah', 'hukuman', 'mencegah virus', 'menyosialisasikan', 'pembunuhan', 'kepala hiv', 'menolak pengobatan', 'kekebalan', 'menyebabkan', 'puskemas']
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# Where

# %%
def wCalculationWhat():
    document_result = []
    document_result_w = []

    for i in range(0, len(document_text_test)-1):
        hasilWhat = []

        teks = df_total.iloc[i, -2]
        tfidf_vectorizer = joblib.load('vectorizer.pkl')
        tfidf_matrix = tfidf_vectorizer.fit_transform([teks])
        document_result_w.append(df_total.iloc[i, -2])

        query_vec_what = tfidf_vectorizer.transform(qeGabunganWhat)
        results_what = cosine_similarity(tfidf_matrix, query_vec_what).reshape((-1))

        for key in qeGabunganDelimiterWhat:
            cariW = re.findall(key, document_result_w[i])
            print(cariW)
            if cariW:
                hasilWhat.append(key)

        document_result.append([i, 'what', what_query, qeGabunganWhat, qeStatistikWhat, qeBoWWhat, hasilWhat, results_what, 0, 0, 0, document_result_w[i]])
        # ------------------------------------------------------------------------------------------------------
    
    writer = pd.DataFrame(document_result, columns=['Data','W', 'Query', 'QE Gabungan', 'QE Bow', 'QE Statistik', 'Hasil Query', 'Similarity', 'True Positive', 'True Negative', 'Relevansi Berita', 'Skimming News'])
    writer.to_csv('QE_Stat_V2_testing_result_what.csv', index=False, sep=',')

# %%
def wCalculationWho():
    document_result = []
    document_result_w = []

    for i in range(0, len(document_text_test)-1):
        hasilWho = []

        teks = df_total.iloc[i, -2]
        tfidf_vectorizer = joblib.load('vectorizer.pkl')
        tfidf_matrix = tfidf_vectorizer.fit_transform([teks])
        document_result_w.append(df_total.iloc[i, -2])

        query_vec_who = tfidf_vectorizer.transform(qeGabunganWho)
        results_who = cosine_similarity(tfidf_matrix, query_vec_who).reshape((-1))

        for key in qeGabunganDelimiterWho:
            cariW = re.findall(key, document_result_w[i])
            if cariW:
                hasilWho.append(key)

        document_result.append([i, 'who', who_query, qeGabunganWho, qeStatistikWho, qeBoWWho, hasilWho, results_who, 0, 0, 0, document_result_w[i]])
        # ------------------------------------------------------------------------------------------------------
    
    writer = pd.DataFrame(document_result, columns=['Data','W', 'Query', 'QE Gabungan', 'QE Bow', 'QE Statistik', 'Hasil Query', 'Similarity', 'True Positive', 'True Negative', 'Relevansi Berita', 'Skimming News'])
    writer.to_csv('QE_Stat_V2_testing_result_who.csv', index=False, sep=',')

# %%
def wCalculationWhen():
    document_result = []
    document_result_w = []

    for i in range(0, len(document_text_test)-1):
        hasilWhen = []

        teks = df_total.iloc[i, -2]
        date = df_total.iloc[i, -3]
        source = df_total.iloc[i, -1]
        
        # tfidf_vectorizer = joblib.load('corpus/vectorizer/vectorizer.pkl')
        # tfidf_matrix = tfidf_vectorizer.fit_transform([teks])
        # document_result_w.append(df_total.iloc[i, -2])
        # query_vec_when = tfidf_vectorizer.transform(qeGabunganWhen)
        # results_when = cosine_similarity(tfidf_matrix, query_vec_when).reshape((-1))

        # for key in qeGabunganDelimiterWhen:
        #     # key = ""

        #     # if type(a) is list:
        #     #     key = ",".join(a)
        #     # else:
        #     #     key = a

        #     cariW = re.findall(key, document_result_w[i])
        #     if cariW:
        #         hasilWhen.append(key)

        # document_result.append([i, 'when', when_query, qeGabunganWhen, qeStatistikWhen, qeBoWWhen, hasilWhen, results_when, 0, 0, 0, document_result_w[i]])
        extracted_time = getNewsTime(timestamp=date, news=teks, source=source)
        document_result.append([i, 'when', extracted_time, date, teks])
        # ------------------------------------------------------------------------------------------------------
    
    writer = pd.DataFrame(document_result, columns=['Data','W', 'Extracted Time', 'Original Time', 'Skimming News'])
    writer.to_csv('QE_Stat_V2_testing_result_when_time.csv', index=False, sep=',')

    # writer = pd.DataFrame(document_result, columns=['Data','W', 'Query', 'QE Gabungan', 'QE Bow', 'QE Statistik', 'Hasil Query', 'Similarity', 'True Positive', 'True Negative', 'Relevansi Berita', 'Skimming News'])
    # writer.to_csv('QE_Stat_V2_testing_result_when.csv', index=False, sep=',')

# %%
def wCalculationWhere():
    document_result = []
    document_result_w = []

    for i in range(0, len(document_text_test)-1):
        hasilWhere = []

        teks = df_total.iloc[i, -2]
        tfidf_vectorizer = joblib.load('vectorizer.pkl')
        tfidf_matrix = tfidf_vectorizer.fit_transform([teks])
        document_result_w.append(df_total.iloc[i, -2])

        query_vec_where = tfidf_vectorizer.transform(qeGabunganWhere)
        results_where = cosine_similarity(tfidf_matrix, query_vec_where).reshape((-1))

        for key in qeGabunganDelimiterWhere:
            # key = ""

            # if type(a) is list:
            #     key = ",".join(a)
            # else:
            #     key = a
            
            cariW = re.findall(key, document_result_w[i])
            if cariW:
                hasilWhere.append(key)

        document_result.append([i, 'where', where_query, qeGabunganWhere, qeStatistikWhere, qeBoWWhere, hasilWhere, results_where, 0, 0, 0, document_result_w[i]])
        # ------------------------------------------------------------------------------------------------------
    
    writer = pd.DataFrame(document_result, columns=['Data','W', 'Query', 'QE Gabungan', 'QE Bow', 'QE Statistik', 'Hasil Query', 'Similarity', 'True Positive', 'True Negative', 'Relevansi Berita', 'Skimming News'])
    writer.to_csv('QE_Stat_V2_testing_result_where.csv', index=False, sep=',')

# %%
wCalculationWhat()
wCalculationWho()
wCalculationWhen()
wCalculationWhere()
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# []
# []
# []
# []
# ['menurutnya']
# []
# []
# []
# []
# []
# ['kesehatan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['infeksi']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['leptospirosis']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['batuk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['warga', 'warga', 'warga', 'warga', 'warga', 'warga', 'warga', 'warga', 'warga', 'warga', 'warga']
# []
# []
# []
# []
# []
# []
# ['masyarakat', 'masyarakat']
# []
# ['daerah', 'daerah', 'daerah', 'daerah', 'daerah']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['angka']
# []
# []
# ['tingkat', 'tingkat']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['hasil']
# []
# []
# ['keluarga']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['memiliki']
# []
# ['muhammad']
# []
# []
# []
# []
# []
# []
# []
# []
# ['terjangkit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['gejala', 'gejala']
# []
# []
# []
# []
# []
# []
# []
# ['kelainan', 'kelainan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['gizi', 'gizi', 'gizi']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['stunting', 'stunting']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['penanganan']
# []
# []
# ['warga', 'warga']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['adi']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['menurutnya']
# []
# []
# []
# []
# []
# ['kesehatan']
# []
# []
# []
# []
# ['keluarga', 'keluarga', 'keluarga']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['memiliki', 'memiliki']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['stunting']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['warga', 'warga', 'warga', 'warga', 'warga']
# []
# []
# []
# []
# []
# []
# []
# []
# ['daerah']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['menurutnya']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['memiliki']
# []
# ['muhammad']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['kelainan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['gizi']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['kelumpuhan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['stunting', 'stunting']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['warga', 'warga', 'warga']
# []
# []
# []
# ['menular']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['penyakit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['menurutnya', 'menurutnya']
# []
# []
# []
# []
# []
# ['kesehatan', 'kesehatan', 'kesehatan']
# []
# ['hasil', 'hasil']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['hamil', 'hamil', 'hamil']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['kelainan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['gizi']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['virus']
# []
# ['warga']
# ['penyebaran']
# []
# []
# []
# []
# []
# ['masyarakat', 'masyarakat', 'masyarakat']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['adi', 'adi']
# []
# ['penyakit', 'penyakit', 'penyakit']
# []
# []
# []
# []
# []
# []
# []
# []
# ['angka', 'angka', 'angka', 'angka', 'angka', 'angka']
# ['kematiannya']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['pasien', 'pasien']
# ['kesehatan', 'kesehatan']
# []
# []
# ['pemeriksaan', 'pemeriksaan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dinyatakan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['terjangkit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['luka']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dengue']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['masyarakat', 'masyarakat', 'masyarakat']
# []
# ['daerah', 'daerah']
# ['nyamuk']
# []
# []
# []
# ['meninggal', 'meninggal']
# []
# []
# []
# []
# ['adi']
# []
# ['penyakit']
# []
# []
# []
# []
# []
# []
# []
# []
# ['angka', 'angka', 'angka']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['pasien', 'pasien']
# ['kesehatan', 'kesehatan', 'kesehatan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dengue', 'dengue']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['masyarakat']
# []
# []
# []
# []
# []
# []
# []
# []
# ['signifikan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['angka']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['pasien', 'pasien', 'pasien', 'pasien', 'pasien', 'pasien', 'pasien', 'pasien', 'pasien', 'pasien']
# []
# []
# []
# ['pemeriksaan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dbd', 'dbd', 'dbd', 'dbd', 'dbd']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['gejala']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dengue']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['warga']
# []
# []
# []
# []
# []
# []
# ['masyarakat']
# []
# ['daerah']
# ['nyamuk', 'nyamuk', 'nyamuk', 'nyamuk']
# []
# []
# []
# ['meninggal']
# []
# []
# []
# []
# []
# []
# ['penyakit']
# []
# []
# []
# []
# []
# []
# []
# []
# ['angka']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['kesehatan', 'kesehatan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['epidemi']
# []
# []
# []
# []
# ['terjangkit', 'terjangkit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['penularan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['akut']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dengue']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['menular']
# []
# []
# ['masyarakat']
# []
# []
# ['nyamuk', 'nyamuk']
# []
# []
# []
# ['meninggal', 'meninggal', 'meninggal', 'meninggal']
# []
# []
# []
# []
# ['adi']
# []
# ['penyakit', 'penyakit', 'penyakit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['kematiannya']
# []
# ['tingkat']
# []
# []
# []
# []
# ['menurutnya']
# []
# []
# []
# []
# []
# ['kesehatan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['covid']
# []
# []
# ['dinyatakan', 'dinyatakan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['warga', 'warga', 'warga', 'warga']
# ['penyebaran']
# []
# []
# []
# []
# []
# []
# []
# []
# ['nyamuk', 'nyamuk', 'nyamuk', 'nyamuk']
# []
# []
# []
# []
# []
# []
# []
# []
# ['adi']
# []
# ['penyakit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['menurutnya', 'menurutnya']
# []
# []
# []
# []
# []
# ['kesehatan', 'kesehatan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['memiliki']
# ['positif', 'positif']
# []
# []
# []
# []
# ['epidemi']
# []
# []
# []
# []
# ['terjangkit']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd', 'dbd']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['penularan', 'penularan', 'penularan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['luka']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['dengue']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
