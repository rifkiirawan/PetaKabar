# %%
import json

f= open('D:/HERRI/Tugas Akhir/pra/geographical_news_scrapper/NER/Kumpulan_Anotattion/annotations_kecel_benca_krim_kese_ekonom.json')
TRAIN_DATA = json.load(f)

# %%
TRAIN_DATA
# Out:
# {'classes': ['LOKASI', 'TANGGAL', 'ORANG'],
#  'annotations': [['\\- kecelakaan maut terjadi di jalan wates-yogyakarta km 20, kulonprogo. usai menabrak sepeda motor, truk kabur. salah satu korban tewas adalah anggota tni. korban tewas, dwi yulianto (24) anggota tni warga ngramang kedungsari, kecamatan pengasih, kulonprogo dan wasi rasyid hidayah (21) , mahasiswi sekolah kebidanan yang berasal dari pedukuhan iv, tirtorahayu, kecamatan galur, kulonprogo. kedua korban yang terseret hingga 20-an meter itu terluka sangat parah dan dilarian ke rsud wates. sementara, pengemudi truk melarikan diri. sampai saat ini, ia masih dicari aparat polres kulonprogo. petugas lantas polsek sentolo, iptu priyo sejati mengungkapkan berdasarkan hasil olah tkp, tabrak lari ini diduga akibat kelalaian sopir truk. diduga pengemudi truk mengendarai kendaraan dengan kecepatan tinggi. menurut dia, kedua korban tertabrak dari arah berlawanan saat truk menyalip bus di depannya. saat mendahului bus, truk melanggar marka dan menabrak sepeda motor korban. "pengemudi truk langsung kabur," kata priyo usai olah tkp, selasa (5/2/2013). berdasarkan hasil keterangan sejumlah saksi, ciri-ciri truk dengan bak berwarna biru dan spion kanan patah.\r',
#    {'entities': [[60, 71, 'LOKASI'],
#      [170, 182, 'ORANG'],
#      [206, 225, 'LOKASI'],
#      [237, 245, 'LOKASI'],
#      [247, 257, 'LOKASI'],
#      [262, 281, 'ORANG'],
#      [372, 377, 'LOKASI'],
#      [379, 390, 'LOKASI'],
#      [483, 489, 'LOKASI'],
#      [579, 590, 'LOKASI'],
#      [613, 620, 'LOKASI'],
#      [627, 639, 'ORANG'],
#      [1010, 1015, 'ORANG'],
#      [1031, 1048, 'TANGGAL']]}],
#   ['\\- salah satu tersangka korupsi pembebasan lahan underpass simpang lima bandara sultan hasanuddin, makassar, rh meninggal dunia. tersangka yang masih buron ini meninggal akibat terlindas truk. "iya meninggal akibat lakalantas," kata kepala seksi penerangan kajati sulsel, idil kepada detikcom, jumat (13/3/2020). idil mengatakan sebelum pihaknya mengetahui rh meninggal, beberapa petugas kejaksaan telah bersiap untuk menangkap rh yang disebut kembali ke rumahnya. "kita mau sergap di tempatnya karena kita cium kemungkinan dia (rh) pulang kalau malam. rumahnya di sekitar pasar batangase," ungkapnya. saat hendak ditangkap, informan kejaksaan menyampaikan bahwa rh meninggal akibat tertabrak truk. di rumah duka juga sudah ramai warga yang melayat. "kami belum berani masuk. pagi-pagi kami pastikan dan ternyata ada anggota yang pastikan dan dia meninggal," ungkapnya. rh diketahui menjadi menjadi buronan kejaksaan sulsel sejak 2018. selain rh, kejakssaan juga telah menahan ars, tersangka korupsi pembebasan lahan underpass simpang lima bandara sultan hasanuddin, makassar. "sudah delapan kali pemanggilan terhadap rh. sudah bekali kali didatangi rumahnya, sudah berkoordinasi dengan rt rumahnya, pihak keluarga sampai sekarang belum ada hasil," kata kepala seksi penyidikan (kasidik) kejati sulselbar, andi faik di makassar kepada detikcom 2018 lalu. andi faik mengatakan dalam modusnya, rh bertindak sebagai penerima uang ganti rugi lahan. namun setelah dilakukan penyelidikan, lahan yang digantirugikan itu tidak termasuk dalam bidang tanah yang dibangun underpass simpang lima sultan hasanuddin. "tindak pidananya ada satu bidang lahan itu yang menerima pembayaran adalah orang yang tidak berhak. ada kongkalikong," sebut dia. "jadi ada seorang yang bertindak seolah-solah sebagai penerima kuasa ganti. itu diluar sertifkat yang diajukan unntuk dimintakan ganti rugi," tambah dia. selanjutnya __ halaman 1 2\r',
#    {'entities': [[99, 107, 'LOKASI'],
#      [109, 111, 'ORANG'],
#      [264, 270, 'LOKASI'],
#      [272, 276, 'ORANG'],
#      [294, 311, 'TANGGAL'],
#      [313, 317, 'ORANG'],
#      [917, 923, 'LOKASI'],
#      [1067, 1076, 'LOKASI'],
#      [1288, 1294, 'LOKASI'],
#      [1295, 1304, 'LOKASI']]}],
#   ['\\- sebuah pesawat maskapai china eastern airlines dilaporkan jatuh di area pegunungan di wilayah china bagian selatan. pesawat jenis boeing 737 ini membawa 133 orang di dalamnya. seperti dilansir _reuters_ , senin (21/3/2022), laporan media nasional china, cctv, menyebut pesawat itu sedang mengudara dari kunming menuju guangzhou saat terjatuh di area pegunungan. cctv melaporkan bahwa belum diketahui jumlah korban jiwa dalam insiden ini. upaya penyelamatan tengah dilakukan. penyebab jatuhnya pesawat china eastern airlines ini juga belum diketahui secara jelas. data pelacakan flighradar24 menyebut pesawat lepas landas dari kunming pukul 13.11 waktu setempat. pelacakan penerbangan terhadap pesawat itu berhenti pada pukul 14.22 waktu setempat, pada ketinggian 3.225 kaki dengan kecepatan 375 knot. pesawat dijadwalkan mendarat pukul 15.05 waktu setempat. [gambas:video 20detik]\r',
#    {'entities': [[27, 32, 'LOKASI'],
#      [97, 102, 'LOKASI'],
#      [208, 225, 'TANGGAL'],
#      [250, 255, 'LOKASI'],
#      [504, 509, 'LOKASI']]}],
#   ['\\- seorang bocah sd di blitar mengendarai motor dengan kecepatan tinggi tanpa menggunakan helm. ketika tidak bisa menguasai laju kendaraan, si bocah terjatuh. nahas, tubuh mungil sang bocah dihantam motor yang melaju dari arah berlawanan. pengendara motor yang menabraknya bocah tersebut kemudian melarikan diri. berdasarkan keterangan pihak kepolisian, korban kecelakaan itu bernama daniel fransisco. bocah berusia 13 tahun itu merupakan warga lenteng agung, kecamatan jagakarsa, jakarta selatan, dki jakarta. beberapa saksi mata melihat bocah tersebut mengendarai sepeda motor dengan nomor polisi ag-2329-lf. dia memacu motornya dengan kencang di jalan raya beru, wlingi, kabupaten blitar. "kejadiannya sekitar pukul 12.30 wib. korban berjalan dari arah utara ke selatan, memasuki jalan umum kelurahan beru. korban lalu terjatuh mengarah ke kanan hingga melebihi batas jalan. selanjutnya tertabrak sepeda motor tak dikenal yang berjalan dari arah selatan ke utara," kata kasatlantas polres blitar akp moh amirul hakim saat dimintai konfirmasi , kamis (3/11/2019). selanjutnya __ halaman 1 2\r',
#    {'entities': [[23, 29, 'LOKASI'],
#      [384, 401, 'ORANG'],
#      [470, 479, 'LOKASI'],
#      [481, 496, 'LOKASI'],
#      [498, 510, 'LOKASI'],
#      [666, 672, 'LOKASI'],
#      [684, 691, 'LOKASI'],
#      [992, 998, 'LOKASI'],
#      [1047, 1064, 'TANGGAL']]}],
#   ['\\- polsek bontoala menangkap seorang pria bernama rezki (19) yang merupakan pelaku begal payudara di makassar, sulawesi selatan. pelaku melakukan perbuatannya terhadap seorang wanita yang sedang mengendarai sepeda motor. "jadi benar ada seorang perempuan yang melakukan pelaporan di spkt bontoala bahwa kejadiannya pelecehan seksual di mana korban mengendarai sepeda motor dan pelaku berjalan kaki. di saat korban mau belok kendaraannya pelan sehingga tiba-tiba pelaku memegang dada dari pelapor, sehingga pelapor datang ke polsek bontoala dengan laporan pelecehan seksual," kata kanit reskrim polsek bontoala, akp rahim, kepada wartawan, rabu (22/12/2021). peristiwa ini diketahui terjadi di jalan sunu, kota makassar. peristiwa terjadi saat pelaku tengah berjalan kaki kemudian melihat korban melintas dengan sepeda motornya, tiba-tiba pelaku melancarkan aksi bejatnya dengan meremas payudara korban. korban yang kaget lalu berteriak minta tolong. warga sekitar yang mengetahui kejadian tersebut, langsung mengejar dan menangkap pelaku, lalu membawanya ke polsek bontoala. "pelaku sudah kita amankan karena dikhawatirkan keluarga pelapor datang melakukan tindakan main hakim sendiri," ucap rahim. dari hasil interogasi, pelaku mengakui perbuatannya. namun, kata rahim, pelaku mengaku tidak sengaja karena merasa dirinya hampir ditabrak oleh korban di jalan. "kalau menurut pelaku ini dirinya akan ditabrak sepeda motor korban, namun korban kalau dianalisa korban akan berbelok ke kiri otomatis kendaraan ini pelan kemudian pelaku kan berjalan kaki jadi keterangan diduga pelaku ini akan tertabrak sepeda motor korban sehingga tidak sengaja tangannya mengenai dada pelapor," imbuhnya.\r',
#    {'entities': [[10, 18, 'LOKASI'],
#      [50, 55, 'ORANG'],
#      [101, 109, 'LOKASI'],
#      [111, 128, 'LOKASI'],
#      [288, 296, 'LOKASI'],
#      [531, 539, 'LOKASI'],
#      [601, 609, 'LOKASI'],
#      [611, 620, 'ORANG'],
#      [639, 656, 'TANGGAL'],
#      [710, 719, 'LOKASI'],
#      [1065, 1074, 'LOKASI'],
#      [1192, 1198, 'ORANG'],
#      [1264, 1269, 'ORANG']]}],
#   ['\\- masih ingat dengan novi amelia yang menabrak tujuh orang di taman sari, jakarta barat? hari ini foto model itu menghadapi sidang perdana setelah menunggu hampir satu tahun sejak ditetapkan sebagai tersangka. menurut pengacara novi amelia, rendy anggara putra, kliennya akan menghadapi sidang perdana di pn jakarta barat dengan agenda pembacaan dakwaan sekitar pukul 12.00 wib. padahal sebelumnya dijadwalkan sidang akan berlangsung pukul 10.00 wib. "nanti sidangnya kemungkinan setelah salat dhuhur," ujar rendy kepada wartawan saat dihubungi, selasa (28/5/2013) novi amelia menabrak tujuh orang di kawasan taman sari, jakarta barat, kamis (11/10 2012) sekitar pukul 17.30 wib. ketika itu dirinya berkendara honda jazz merah berpelat b 1864 pop dari jl suryopranoto menuju ketapang. dua dari tujuh orang yang tertabrak adalah polisi lalu lintas. kasus kecelakaan ini menjadi perhatian sebab novi didapati hanya mengenakan pakaian dalam. belakangan diketahui wanita yang berprofesi sebagai foto model ini juga dalam pengaruh obat terlarang. dia dinyatakan bersalah melanggar uu no 22 th 2009 pasal 310 tentang lalu lintas dan angkutan jalan.\r',
#    {'entities': [[22, 33, 'ORANG'],
#      [63, 73, 'LOKASI'],
#      [75, 88, 'LOKASI'],
#      [229, 240, 'ORANG'],
#      [242, 261, 'ORANG'],
#      [309, 322, 'LOKASI'],
#      [509, 514, 'ORANG'],
#      [547, 565, 'TANGGAL'],
#      [566, 577, 'ORANG'],
#      [610, 620, 'LOKASI'],
#      [622, 635, 'LOKASI'],
#      [637, 655, 'TANGGAL'],
#      [776, 785, 'LOKASI'],
#      [894, 898, 'ORANG']]}],
#   ['\\- sebuah metromini menabrak perlintasan kereta api dan langsung tersambar kcl yang melintas. akibatnya, kondisi metromini hancur dan 13 orang penumpang dikabarkan meninggal dunia. usai tertabrak, metromini terseret 100 meter dan badannya ringsek pada pukul 08.48 wib, minggu (6/12/2015). bodi bagian depan metromini hancur dan besi body tersangkut pondasi peron. evakuasi berjalan cukup susah, padahal masih ada penumpang yang terjebak. ![](https://akcdn.detik.net.id/community/media/visual/2015/12/06/7c0f314e-cbaa-46b9-9419-77e5c672bb27_169.jpg?w=620&mark=undefined&image_body_visual_id=173962) untuk mempermudah, petugas langsung memotong dua badan metromini tersebut dengan alat berat. bagian atas badan dipotong dengan bagian bawah badan metromini. selain itu, beberapa bagian bodi metromini juga dipotong-potong beberapa bagian. akibat kecelakaan ini, 13 orang meninggal dunia dan 7 orang luka berat. para korban yang masih selamat dilarikan ke rumah sakit terdekat. "metromini menerobos di celah-celah palang pintu yang sudah tertutup," kata kapolsek tambora kompol wirdhanto di lokasi.\r',
#    {'entities': [[269, 287, 'TANGGAL'],
#      [1059, 1066, 'LOKASI'],
#      [1067, 1083, 'ORANG']]}],
#   ['\\- tiga rumah dan dua pohon di jalur bojonegoro-jatirogo, ditabrak truk muat crane. satu orang luka akibat kecelakaan tunggal truk nopol l 9886 uh yang disopiri mulyono (45). seorang saksi, supriyono (40) yang juga pembeli di warung mengaku saat kejadian truk crane berjalan dari arah jatirogo menuju bojonegoro. saat di jalan banjarsari yang jalurnya menurun, mendadak truk crane berjalan ke kiri keluar dari jalan aspal dan menabrak warung milik masulin. setelah menabrak warung, truk crane menabrak rumah yang digunakan warung juga milik rasiyah (67) dan akhirnya menabrak pohon mangga. setelah itu truk crane baru berhenti setelah menabrak rumah milik sri nik\'atun (45). "aku tadi ngopi di warung sebelahnya pas menghadap ke jalan. truk itu dari utara jalan kencang. aku teriak ke sopir, piye iku kok ngiri nyetirnya. akhire bruaak nabrak warung terus rumah dan pohon mangga. sampai pohon itu terjepit di bawah truk," kata supriyono saat di lokasi kejadian, kamis (3/5/2018). ![truk crane tabrak tiga rumah/](https://akcdn.detik.net.id/community/media/visual/2018/05/03/38f3ce30-66c3-4b7d-bf39-9eee2b32161a_169.jpeg?w=620)truk crane tabrak tiga rumah/ foto: ainur rofiq --- akibat kejadian ini, satu orang luka. yakni, nanang (40) warga bangilan jatirogo tuban, mengalami luka di kepala dan tangan patah tulang. korban langsung dibawa ke rumah sakit sosodoro djatikusumo bojonegoro. "hanya satu korban luka yakni pembeli di sebuah warung milik rasiyah, sekaligus dijadikan rumah," kata kasatlantas polres bojonegoro, akp aristianto saat dihubungi. evakuasi yang dilakukan sempat kesulitan karena truk crane terganjal pohon mangga. evakuasi baru berhasil dilakukan setelah diderek truk lain milik rekan kerjanya. hingga kini reruntuhan rumah yang tertabrak masih berantakan dan belum ada proses evakuasi rumah rumah yang rusak tersebut. "anggota lantas dan polsek trucuk sudah di lokasi. penyebab awal mungkin truk rem blong namun nanti pasti ada olah tkp," tegasnya.\r',
#    {'entities': [[161, 168, 'ORANG'],
#      [190, 199, 'ORANG'],
#      [285, 293, 'LOKASI'],
#      [301, 312, 'LOKASI'],
#      [448, 456, 'ORANG'],
#      [541, 548, 'ORANG'],
#      [656, 668, 'ORANG'],
#      [927, 936, 'ORANG'],
#      [962, 978, 'TANGGAL'],
#      [1223, 1229, 'ORANG'],
#      [1250, 1258, 'LOKASI'],
#      [1259, 1264, 'LOKASI'],
#      [1375, 1386, 'LOKASI'],
#      [1448, 1455, 'ORANG'],
#      [1509, 1519, 'LOKASI'],
#      [1521, 1535, 'ORANG'],
#      [1867, 1873, 'LOKASI']]}],
#   ['\\- rifai (19) warga dusun kayen rt 03/12, desa tuko, kecamatan pulokulon, kabupaten grobogan, jawa tengah, tewas tertabrak kereta api barang. korban tertabrak ka karena asyik bermain ponsel pintar sembari pasang headset di telinga dan sembari duduk di rel tak jauh dari rumahnya. kapolsek panunggalan akp wibowo ketika dikonfirmasi menjelaskan korban meninggal dunia karena tertabrak ka barang atau muatan peti kemas. "telah ditemukan seorang laki-laki meninggal dunia tertabrak ka barang atau muat peti kemas dengan nomor loko cc 2061329 di pinggir rel ka turut dusun kayen, desa tuko, kecamatan pulokulon, kabupaten grobogan," kata wibowo kepada detikcom via pesan pendek, kamis (3/1/2019) pihaknya menerima laporan dari warga setempat mulyadi. dua orang saksi yaitu yuni sugiarto warga desa kuwu, kecamatan kradenan, grobogan sekaligus karyawan pt kereta api indonesia (kai) dan yadiman (55) warga setempat. kronologinya lanjut dia, berdasarkan keterangan saksi, ka melintas dari arah barat menuju ke timur. saat masuk wilayah dusun kayen mendekati lokasi, masinis ka, jainuddin (32) telah membunyikan sinyal atau klakson. "masinis sudah menyalakan klakson karena sudah mendekati palang pintu penyebarangan rel, yang berjarak kurang lebih 200 meter. masinis saat melaju dengan jarak 50 meter melihat korban yang sedang duduk di atas rel menghadap ke arah selatan sedang bermain handphone dan memakai headset," tutur dia. menrutnya masinis kembali membunyikan klakson tetapi korban tetap tidak mendengar dan masinis berusaha mengerem laju ka. karena jarak yang sudah dekat, korban tertabrak ka. tubuh korban terlempar sejauh 50 meter ke arah selatan. selanjutnya ka berhenti di dekat pos perlintasan palang pintu penyeberangan rel ka, masinis turun dan melaporkan ke penjaga perlintasan bahwa ada seseorang yang telah tertabrak ka. perjalanan ka pun dilanjutkan kembali. dari hasil pemeriksaan tim medis puskemas kradenan korban mengalami luka robek di kepala bagian kanan dan patah kaki kanan, tinggi korban 155 cm, dan korban mengenakan kaos warna merah celana pendek warna biru. "kurang hati-hatinya korban yang duduk di atas rel ka, memainkan hp dengan memakai headset sehingga tidak mendengar ada ka yang melintas," katanya. setelah dilakukan pemeriksaan, polisi kemudian menyerahkan jasad korban kepada keluarga untuk dimakamkan.\r',
#    {'entities': [[3, 8, 'ORANG'],
#      [63, 72, 'LOKASI'],
#      [84, 92, 'LOKASI'],
#      [94, 105, 'LOKASI'],
#      [289, 300, 'LOKASI'],
#      [301, 311, 'ORANG'],
#      [597, 606, 'LOKASI'],
#      [618, 626, 'LOKASI'],
#      [634, 640, 'ORANG'],
#      [675, 691, 'TANGGAL'],
#      [738, 746, 'ORANG'],
#      [769, 782, 'ORANG'],
#      [810, 818, 'LOKASI'],
#      [820, 828, 'LOKASI'],
#      [882, 889, 'ORANG'],
#      [1072, 1081, 'ORANG']]}],
#   ['\\- sebuah mobil tertabrak kereta di perlintasan sebidang, jalan rawa geni, antara stasiun citayam dan depok lama. petugas pemadam kebakaran mulai mengevakuasi mobil yang terjepit badan kereta. pantauan di lokasi, rabu (20/4/2022), pukul 08.58 wib, ada 3 unit pemadam kebakaran yang dikerahkan. petugas mulai menarik mobil menggunakan tali secara bersama-sama ke bagian samping kanan. sementara itu, petugas kepolisian menertibkan lalu lintas di jalan rawa geni. arus tersendat lantaran mobil damkar yang masih terparkir di bahu jalan. warga sekitar juga memadati lokasi lantaran ingin melihat kondisi. polisi beberapa kali berteriak, "pak, jangan pada _nonton_ , ayo". pemotor yang berhenti untuk melihat diminta untuk melanjutkan perjalanannya. sebelumnya, informasi kecelakaan juga disampaikan akun resmi kai commuter, rabu (20/4). mobil tertabrak kereta di jalur hilir stasiun citayam-depok. "ka 1077 (bogor-jakarta kota) tertemper mobil di antara jalur hilir stasiun citayam-depok, saat ini ka masih dalam pengecekan. kami mohon maaf atas ketidaknyamanannya," demikian keterangan dari kai commuter. pihak kai menerangkan, seluruh penumpang krl dievakuasi. pihak kai meminta maaf atas peristiwa kecelakaan tersebut. sudah menghubungi pt kci untuk mengetahui lebih lanjut terkait kecelakaan ini. namun, hingga berita ini dimuat, belum ada respons dari pt kci. [gambas:video 20detik]\r',
#    {'entities': [[90, 97, 'LOKASI'],
#      [102, 107, 'LOKASI'],
#      [213, 229, 'TANGGAL'],
#      [821, 832, 'TANGGAL']]}],
#   ['\\- kecelakaan terjadi di jalan kebon sirih timur, menteng, jakarta pusat. sebuah mobil honda hrv bernopol b-2748-boz menabrak dua mobil lainnya yang sedang terparkir. "tidak ada korban jiwa, hanya kerugian materi," kata kasat lantas jakarta pusat akbp lilik sumardi dalam keterangan kepada wartawan, sabtu (27/6/2020), kecelakaan terjadi pada jumat (26/6) malam sekitar pukul 22.30 wib. saat itu, mobil honda hrv yang dikemudikan pria berinisial ns melaju dari arah selatan ke utara di jalan kebon sirih timur, menteng, jakarta pusat. "sesampainya di dekat caffe melly, menabrak kendaraan sedan bernopol b-8936-bg," katanya. tak berhenti sampai situ, tabrakan itu juga mengakibatkan mobil honda mobillio bernopol b-2488-syu terdorong saat sedang terparkir di jalan tersebut. kecelakaan itu mengakibatkan mobil honda hrv mengalami kerusakan pada bagian kap mesin, bemper depan gores dan kaca depan pecah. sedangkan mobil sedan mengalami kerusakan pada bagian bemper belakang penyok, kaca belakang pecah, lampu utama depan pecah, kap depan penyok dan bemper penyok. "untuk mobil honda mobilio mengalami kerusakan pada bagian bemper dan pintu belakang penyok," katanya. secara terpisah, kasubdit gakkum ditlantas polda metro jaya akbp fahri siregar mengatakan bahwa pihaknya masih menyelidiki penyebab kecelakaan tersebut. "masih didalami oleh penyidik," kata fahri. [gambas:video 20detik]\r',
#    {'entities': [[50, 57, 'LOKASI'],
#      [59, 73, 'LOKASI'],
#      [233, 246, 'LOKASI'],
#      [247, 265, 'ORANG'],
#      [300, 317, 'TANGGAL'],
#      [343, 355, 'TANGGAL'],
#      [511, 518, 'LOKASI'],
#      [520, 534, 'LOKASI'],
#      [1227, 1245, 'ORANG']]}],
#   ['\\- yatimah (62), warga desa dlangu, kecamatan butuh, kabupaten purworejo, jawa tengah tewas tersambar kereta api (ka) mataram premium, minggu (3/9/2017). diduga korban hendak menyeberang rel menuju namun tidak mengetahui kedatangan ka dari arah jakarta menuju ke arah timur. peristiwa terjadi di desa dlangu, di km 474 - 34 antara stasiun kutoarjo - butuh kejadian tersebut pertama kali diketahui oleh masinis ka jurusan pasar senen jakarta - lempuyangan yogyakarta yang kemudian melaporkan kepada petugas stasiun. karyawan dari stasiun kutoarjo, suwardono (36) bersama petugas polsuska teguh supriyanto (51) kemudian menuju lokasi kejadian. setelah dicek oleh kedua petugas tersebut, korban ditemukan tewas di pinggir rel dengan luka parah di kepala. "saat petugas datang, korban sudah dalam keadaan meninggal karena mengalami luka di kepala," katanya. petugas dari stasiun itu pun kemudian melaporkan kejadian tersebut kepada aparat kepolisian. kapolsek butuh, akp sutrisno mengungkapkan polisi dan tim medis mendatangi lokasi kejadian untuk mengecek korban. yatimah sendiri diketahui hendak pergi ke sawah sebelum akhirnya tertabrak kereta api. "korban hendak ke sawah namun tertabrak kereta dan meninggal di lokasi kejadian," ungkap sutrisno. petugas polisi pun kemudian membawa korban ke rsud dr. tjitrowardojo purworejo. sutrisno menghimbau agar warga yang tinggal di sekitar rel tanpa palang pintu, terutama yang hendak menyeberang harus tetap waspada dan hati-hati demi keselamatan. "kecelakaan seperti ini sering terjadi di rel wilayah kecamatan butuh. oleh karena itu warga sekitar harus hati-hati terutma saat menyeberang. tengok kanan dan kiri. pastikan tidak ada kereta api yang melintas," pungkasnya.\r',
#    {'entities': [[3, 10, 'ORANG'],
#      [46, 51, 'LOKASI'],
#      [63, 72, 'LOKASI'],
#      [74, 85, 'LOKASI'],
#      [135, 152, 'TANGGAL'],
#      [245, 252, 'LOKASI'],
#      [339, 347, 'LOKASI'],
#      [421, 432, 'LOKASI'],
#      [433, 440, 'LOKASI'],
#      [443, 454, 'LOKASI'],
#      [455, 465, 'LOKASI'],
#      [537, 545, 'LOKASI'],
#      [547, 556, 'ORANG'],
#      [587, 603, 'ORANG'],
#      [956, 961, 'LOKASI'],
#      [967, 975, 'ORANG'],
#      [1061, 1068, 'ORANG'],
#      [1237, 1246, 'ORANG'],
#      [1316, 1326, 'LOKASI'],
#      [1327, 1335, 'ORANG']]}],
#   ['\\- kecelakaan melibatkan bus transjakarta terjadi di dekat halte tanjung priok, jakarta utara, pagi tadi. satu orang tewas akibat kecelakaan itu. kapolsek tanjung priok kompol ricky pranata membenarkan terkait adanya kecelakaan itu. namun ricky belum mengetahui kronologi kejadian karena kasusnya ditangani unit lantas. "iya benar (kecelakaan bus transj menewaskan satu orang). tapi penanganannya ke satlantas, ya, karena udah ditangani," ucap ricky saat dimintai konfirmasi, selasa (8/2/2022). ricky berkata, situasi di lokasi kecelakaan kini sudah kondusif. korban kecelakaan telah dievakuasi. "sudah (kondusif)," kata ricky. terpisah, pihak transjakarta mengatakan telah menerima informasi terkait kecelakaan itu. pihak transjakarta kini sedang melakukan investigasi internal dan berkoordinasi dengan pihak kepolisian. "kami sudah menerima info kejadian tersebut, dan saat ini kami sedang lakukan investigasi baik di internal dan juga berkoordinasi dengan pihak berwajib," ujar humas transjakarta dalam keterangan kepada wartawan. kejadian ini viral di media sosial. dalam video yang beredar terlihat seorang korban tergeletak dan ditutupi kardus. seorang pria dalam video itu menerangkan, korban tertabrak karena berada di dekat tikungan jalur transjakarta yang berada di sisi halte. sebab, pria itu menuturkan lokasi tikungan tersebut adalah titik buta atau _blind spot_ bagi para sopir transjakarta. "kejadian pas di jalur bus transjakarta ya, nah ini karena ini posisi tikungan kemungkinan tidak terlihat oleh pengemudi. nah seperti ini kejadiannya pas tikungan. nah seperti ini. makanya kalau _nyeberang_ hati-hati, karena itu termasuk _blind spot_ ," kata pria perekam. pria tersebut menyebutkan korban tertabrak transjakarta. korban, lanjutnya, terpeleset di saluran air sebelum terlindas. "dapat kami laporkan kami di sini, bahwa korban yang terlindas bus transjakarta ini sedang dalam penanganan petugas. korban diduga sebelum terlindas, terpeleset atau terperosok di saluran air. pas di jalur transjakarta. di sini ada lubang kecil, kemungkinan beliau terpeleset sehingga terjatuh," ujar pria tersebut.\r',
#    {'entities': [[65, 78, 'LOKASI'],
#      [80, 93, 'LOKASI'],
#      [155, 168, 'LOKASI'],
#      [169, 189, 'ORANG'],
#      [239, 244, 'ORANG'],
#      [444, 449, 'ORANG'],
#      [476, 493, 'TANGGAL'],
#      [495, 500, 'ORANG'],
#      [621, 627, 'ORANG']]}],
#   ['\\- sebuah mobil menabrak pengendara motor di terminal pulogadung, jakarta timur. akibatnya, pengendara motor mengalami luka-luka. kanit laka lantas polres metro jakarta timur iptu seno mengatakan peristiwa terjadi pada sabtu (19/2) sekitar pukul 00.30 wib. saat itu, mobil melaju dari barat dengan tujuan belok kanan ke arah terminal pulogadung. pada waktu yang bersamaan, dari arah timur melaju lurus tiga kendaraan roda dua menuju arah barat. "ada mobil sigra dari arah barat mau belok kanan ke terminal pulogadung. bersamaan itu, dari arah timur ada tiga kendaraan roda dua, mau jalan lurus ke barat," kata seno saat dihubungi, sabtu (19/2/2022). seno menuturkan dua kendaraan roda dua yang berada di depan sempat mengerem dan belok kanan menuju arah barat. namun, karena jarak terlalu dekat, pemotor lain di belakangnya yang diketahui berboncengan banting setir ke arah kiri hingga motor yang berada di posisi belakang tertabrak mobil. "dia mau belok kanan khawatir menabrak roda dua yang di depan, makanya roda dua yang di belakang banting kiri. tetapi, malah bertabrakan dengan mobil sigra yang dari barat arah kiri," jelasnya. seno menjelaskan, sebelum terjadi kecelakaan, korban melaju dengan kecepatan tinggi. akibat kecelakaan itu, pemotor mengalami luka serius dan dilarikan ke rumah sakit. "pengendara roda dua, kaki kanan patah, kepala keluar darah dari telinga. untuk yang dibonceng hanya lecet. saat ini dirawat di rscm, pengendara kritis. pengemudi mobil tidak mengalami luka," ujarnya. ### tak ada rambu-rambu lalu lintas lebih lanjut seno mengatakan di daerah tersebut memang rawan kecelakaan karena tidak adanya rambu pengatur lalu lintas. dia mengatakan pihaknya akan mengusulkan pemasangan rambu lalu lintas agar insiden serupa tidak terjadi lagi. "memang, standarnya di pertigaan itu harus ada _traffic light_. karena pengguna jalan di situ sering kagok. sering terjadi senggolan, karena pada kurang jaga jarak," katanya. "saya akan usul ke ditkamsel agar mengusulkan ke dishub untuk pasang lampu pengatur, karena seringnya terjadi senggolan antarkendaraan," imbuhnya. [gambas:video 20detik]\r',
#    {'entities': [[54, 64, 'LOKASI'],
#      [66, 80, 'LOKASI'],
#      [161, 174, 'LOKASI'],
#      [175, 184, 'ORANG'],
#      [219, 231, 'TANGGAL'],
#      [334, 345, 'LOKASI'],
#      [506, 517, 'LOKASI'],
#      [610, 614, 'ORANG'],
#      [631, 648, 'TANGGAL'],
#      [650, 654, 'ORANG']]}],
#   ['\\- bus transjakarta menabrak jembatan penyeberangan orang di jalan kyai tapa, jakarta barat. insiden ini terjadi karena bus mencoba menghindari petugas kebersihan yang sedang menyapu jalan. "setelah _flyover_ (jembatan layang) roxy arah grogol, bus hendak masuk jalur. di jalur ada seorang penyapu jalan di sebelah kanan," kata humas transjakarta, wibowo, kepada detikcom, selasa (25/9/2018). karena ada petugas sapu jalan di dalam jaur bus, si sopir mencoba menghindar agar tak menabrak penyapu jalan. dikemudikanlah bus ke arah kiri supaya penyapu jalan tak tertabrak. "bus ke kiri untuk menghindari penyapu jalan. ban sebelah kiri keluar separator kecil (warna kuning). bus hendak ke kanan lagi agar ban sebelah kiri bisa ke jalur busway," tutur wibowo. meski sudah banting setir ke kanan lagi, namun ban belum bisa melewati separator kecil tadi. "alhasil terjadi insiden," kata dia. kecelakaan terjadi pukul 06.30 wib. beruntung, sopir tak mengalami luka-luka. bus bernomor polisi b 7240 tgc itu juga dalam keadaan kosong penumpang saat kecelakaan terjadi. [gambas:video 20detik]\r',
#    {'entities': [[78, 92, 'LOKASI'],
#      [348, 354, 'ORANG'],
#      [373, 391, 'TANGGAL'],
#      [749, 756, 'ORANG']]}],
#   ['\\- imbauan bagi siapa saja yang rumahnya di pinggir jalan raya agar berhati- hati bila anak-anaknya sedang bermain. jika teledor, nyawa bisa melayang. seperti seorang ibu rumah tangga, oni meliana herawati (35) warga jalan cemara kelurahan rembang kecamatan sananwetan kota blitar, yang tewas mengenaskan. bermaksud mengejar anaknya yang berlarian hendak menyeberang jalan, korban malah tertabrak dan terlindas truk gandeng nopol ag 9278 up, di depan rumahnya. truk yang dikendarai suyoto (50) warga jl jati 16 kelurahan sukorejo, yang masih tetangga korban langsung berhenti. seorang saksi mata, sukanti mengaku saat itu korban berlari mengejar anaknya, farizal idris zakaria (3) yang akan menyeberang jalan. "tadi ibu itu lari dari arah timur ke barat, mengejar anaknya yang sudah duluan nyeberang jalan," kata sukanti saat ditemui detikcom di lokasi, sabtu (18/2/2017). korban yang saat itu dalam keadaan panik, lanjut sukanti, tidak melihat truk gandeng yang melaju cepat. tak sempat menghindar, korban beserta anaknya langsung tertabrak truk gandeng. tragisnya, badan korban terjepit ban depan truk dan langsung meninggal di lokasi kejadian. "korban langsung meninggal di tempat kejadian karena badan bagian bawah terlindas di bawah roda depan truk," jelas petugas unit laka satlantas polresta blitar, bripka bagus widianto di lokasi. sementara anak korban mengalami luka parah dan patah tangan kanan. selanjutnya dibawa ke rs mardi waluyo kota blitar. proses evakuasi korban dan truk sempat membuat macet arus lalu lintas di jalan cemara sekitar 2 jam, di akses utama kota blitar menuju tulungagung. banyak pengendara berhenti melihat kejadian tragis tersebut. sedangkan truk dan sopir sudah diamankan di mapolresta blitar. kasatlantas polresta blitar, akp rizky triputra sangat menyesalkan kejadian ini. "semoga ini menjadi pelajaran bagi kita semua untuk lebih waspada dan berhati-hati saat menjaga anak balita kita, terutama mereka yang tinggal di pinggir jalan raya," ungkapnya.\r',
#    {'entities': [[185, 205, 'ORANG'],
#      [258, 268, 'LOKASI'],
#      [274, 280, 'LOKASI'],
#      [482, 488, 'ORANG'],
#      [597, 604, 'ORANG'],
#      [655, 676, 'ORANG'],
#      [854, 871, 'TANGGAL'],
#      [922, 929, 'ORANG'],
#      [1299, 1305, 'LOKASI'],
#      [1314, 1328, 'ORANG'],
#      [1450, 1457, 'LOKASI'],
#      [1579, 1585, 'LOKASI'],
#      [1593, 1605, 'LOKASI'],
#      [1722, 1729, 'LOKASI'],
#      [1751, 1757, 'LOKASI'],
#      [1763, 1777, 'ORANG']]}],
#   ['\\- sekretariat presiden (setpres) angkat bicara mengenai terbaliknya kapal pinisi yang mengangkut wartawan istana di labuan bajo, ntt. peristiwa ini terjadi di luar agenda kepresidenan. "peristiwa tersebut terjadi di luar agenda kepresidenan," ujar deputi bidang protokol, pers, dan media sekretariat presiden, bey machmudin dalam keterangannya, selasa (21/1/2020). kapal yang ditumpangi wartawan, yang diketahui bernama plataran phinisi bali, itu terbalik saat berada di tengah laut. semua wartawan dan anak buah kapal (abk) yang menjadi penumpang kapal tersebut selamat. "sementara para wartawan tersebut memilih untuk ke dermaga untuk menaiki kapal menuju pulau bidadari. dalam perjalanan kembali dari pulau bidadari, saat berada di tengah laut, desca salah satu wartawan yang ikut menyampaikan terjadi perubahan cuaca mendadak, yaitu ombak tinggi dan angin kencang sehingga kapal terbalik," ujar bey. saat terbalik, petugas pantai di hotel plataran yang melihat kejadian tersebut segera bergerak menuju lokasi dengan _speedboat_. setelah itu, para wartawan dibawa ke hotel plataran dan langsung diperiksa oleh tim dokter dari rs siloam labuan bajo. "kapal yang digunakan wartawan tersebut bukan yang digunakan oleh presiden selama berada di labuan bajo. namun kapal tersebut digunakan oleh menteri bumn erick thohir dan menteri lingkungan hidup dan kehutanan siti nurbaya kemarin (senin, 20/1) di labuan bajo," kata bey. saat ini, wartawan istana yang terdiri dari edho ferdihanzah ( _tvri_ ), krismastianto baruno suryokusumo ( _berita satu tv_ ), agus rahmat ( _vivanews.com_ ), lizsa egeham ( _liputan6.com_ ), desca lidya natalia (lkbn _antara_ ), nina susilo ( _kompas_ ), dan anindyka pribadi ( _sctv_ ) itu sudah berada di bandara komodo, labuan bajo, untuk kembali ke jakarta menggunakan pesawat pukul 15.40 wita. [gambas:video 20detik]\r',
#    {'entities': [[117, 128, 'LOKASI'],
#      [130, 134, 'LOKASI'],
#      [311, 324, 'ORANG'],
#      [346, 364, 'TANGGAL'],
#      [438, 442, 'LOKASI'],
#      [749, 754, 'ORANG'],
#      [900, 904, 'ORANG'],
#      [1140, 1152, 'LOKASI'],
#      [1245, 1257, 'LOKASI'],
#      [1307, 1319, 'ORANG'],
#      [1363, 1375, 'ORANG'],
#      [1385, 1396, 'TANGGAL'],
#      [1401, 1412, 'LOKASI'],
#      [1469, 1485, 'ORANG'],
#      [1498, 1530, 'ORANG'],
#      [1553, 1564, 'ORANG'],
#      [1585, 1597, 'ORANG'],
#      [1618, 1637, 'ORANG'],
#      [1656, 1667, 'ORANG'],
#      [1686, 1702, 'ORANG'],
#      [1750, 1761, 'LOKASI'],
#      [1780, 1787, 'LOKASI']]}],
#   ['\\- dua bocah di pangandaran tewas usai ditabrak motor gede (moge) harley davidson. kini, dua penabrak mati bocah itu sudah ditetapkan polisi sebagai tersangka. insiden bermula saat rombongan harley davidson yang tergabung dalam harley davidson club indonesia (hdci) bandung melakukan touring ke pangandaran pada sabtu (12/3/2022) lalu. saat itu, ada dua moge yang menabrak bocah kembar hasan-husen. kecelakaan lalu lintas itu terjadi di jalan raya banjar-pangandaran. hendi (27), warga setempat mengatakan, kedua bocah kembar itu tertabrak dua jenis moge yang berbeda. "korban pertama tertabrak moge berwarna putih, sementara satunya lagi moge warna hitam," ucapnya. menurutnya, kedua moge tersebut berjalan sangat kencang dan ugal-ugalan, lalu menabrak dua bocah yang hendak menyebrang. sehingga, korban mengalami luka parah sehingga meninggal dunia di lokasi kejadian. polisi bergerak untuk menangani insiden itu. dua unit moge lalu diamankan polisi. dua kendaraan moge yang terlibat kecelakaan maut tersebut dibawa ke mapolsek kalipucang pangandaran. sekadar informasi, kasus kecelakaan ini ditangani polres ciamis. "masih (dua pengendara moge diamankan) di polsek, belum dilimpahkan ke kita. kan kita sudah beda wilayah hukum jadi harus ada serah terima. sedangkan kita belum dapat," ujar kasat lantas polres ciamis akp zanuar cahyo wibowo, sabtu (12/3/2022). di satu sisi, pihak hdci melakukan pertemuan dengan keluarga korban. mereka akhirnya berdamai di kantor polisi. kakak korban iwa kartiwa (36) mengaku ikhlas dengan musibah tersebut. "saya mewakili keluarga sudah ikhlas dan menerima musibah yang menimpa kami," ucapnya kepada detikjabar, sabtu (12/3/2022). meski sudah melakukan perdamaian, polisi tetap melanjutkan proses penyelidikan. kapolda jabar irjen suntana bahkan buka suara dan menegaskan kasus terus berlanjut. "untuk kasus itu terus diproses secara hukum sesuai aturan yang ada karena itu kan menghilangkan nyawa seseorang," ujar suntana kepada wartawan saat ditemui di polsek lembang, senin (14/3/2022). polisi kemudian melakukan gelar perkara atas insiden itu. berdasarkan hasil gelar perkara, polisi meningkatkan status kedua penabrak menjadi tersangka. "ya, sudah ditersangkakan," ucap kabid humas polda jabar kombes ibrahim tompo kepada detikjabar, selasa (15/3/2022). penetapan tersangka tersebut berdasarkan hasil gelar perkara yang dilakukan oleh penyidik polres ciamis. atas status ini, kedua pengendara tersebut ditahan. "ditahan. iya (dua orang)," kata dia. [gambas:video 20detik]\r',
#    {'entities': [[266, 273, 'LOKASI'],
#      [312, 329, 'TANGGAL'],
#      [468, 473, 'ORANG'],
#      [1030, 1040, 'LOKASI'],
#      [1041, 1053, 'LOKASI'],
#      [1111, 1118, 'LOKASI'],
#      [1313, 1319, 'LOKASI'],
#      [1324, 1343, 'ORANG'],
#      [1345, 1362, 'TANGGAL'],
#      [1489, 1500, 'ORANG'],
#      [1651, 1668, 'TANGGAL'],
#      [1758, 1763, 'LOKASI'],
#      [1764, 1777, 'ORANG'],
#      [1954, 1961, 'ORANG'],
#      [2001, 2008, 'LOKASI'],
#      [2010, 2027, 'TANGGAL'],
#      [2232, 2237, 'LOKASI'],
#      [2245, 2258, 'ORANG'],
#      [2278, 2296, 'TANGGAL'],
#      [2395, 2402, 'LOKASI']]}],
#   ['\\- giovani hezekiah chandra (20) menabrak seorang pejalan kaki dan seorang pengendara sepeda ontel saat melaju di kawasan kelapa gading, jakarta utara. salah satu korban tewas, jaenal arifin (35) sempat terseret mobil toyota vios milik giovani sejauh 70 meter. "pejalan kaki mental, jatuh keseret. kemudian dia terseret hampir 70 meter," ujar kasatlantas polres jakarta utara, akbp sudharmanto, di kantornya, jl gunung sahari, jakarta, sabtu (9/1/2016). giovani setelah menabrak jaenal tidak langsung berhenti. pemuda 20 tahun itu malah menancap gas mobilnya dalam-dalam. jaenal yang terpental setelah tertabrak kemudian terseret jauh. "di saat melaju itu, lalu nabrak lagi pengemudi sepeda ontel bernama anen," jelas sudharmanto. meski sudah menabrak dua orang, giovani tidak berhenti. dia tetap berusaha lari. warga pun mengejar. "dia sempat kabur usai menabrak ke arah rs gading pluit, tetapi baru sampai depan gerbang rs gading pluit mobilnya mogok," tutur sudharmanto. giovani hezekiah chandra (20) karena menewaskan dua orang pejalan kaki di kelapa gading jakarta utara. giovani terancam penjara 6 tahun akibat perbuatannya.\r',
#    {'entities': [[3, 27, 'ORANG'],
#      [122, 135, 'LOKASI'],
#      [137, 151, 'LOKASI'],
#      [177, 190, 'ORANG'],
#      [362, 375, 'LOKASI'],
#      [382, 393, 'ORANG'],
#      [427, 434, 'LOKASI'],
#      [436, 452, 'TANGGAL'],
#      [454, 461, 'ORANG'],
#      [479, 485, 'ORANG'],
#      [705, 709, 'ORANG'],
#      [718, 730, 'ORANG'],
#      [763, 770, 'ORANG'],
#      [961, 973, 'ORANG'],
#      [974, 998, 'ORANG'],
#      [1048, 1061, 'LOKASI'],
#      [1062, 1076, 'LOKASI'],
#      [1077, 1084, 'ORANG']]}],
#   ['\\- sebuah mobil tertabrak kereta di wilayah indramayu, jawa barat. polisi mengatakan ada delapan penumpang mobil yang tewas akibat peristiwa tersebut. pt kai daop iii mengatakan mobil melintas di perlintasan kereta yang tak berpalang. tabrakan itu terjadi di perlintasan sebidang antara haurgeulis dan cilegeh. perlintasan tersebut tidak memiliki palang pintu dan tidak ada penjaganya. "ya benar, terjadi kecelakaan lalu lintas di perlintasan sebidang tidak dijaga antara haurgeulis dan cilegeh di km 143 +1 pada pukul 15.15 wib," ucap humas pt kai daop iii cirebon kuswardoyo bhiworo dalam keterangannya, sabtu (29/6/2019). menurut kuswardoyo, mobil terios dengan pelat nomor e-1826-ra itu tertabrak ka jayabaya rute pasar senen-malang. kecelakaan itu mengakibatkan pengendara dan penumpang mobil meninggal dunia. "kecelakaan lalu lintas tersebut mengakibatkan tujuh penumpang mobil terios meninggal dunia. korban sudah dievakuasi ke rs bhayangkara indramayu," sebut kuswardoyo. keterangan kuswardoyo soal korban tewas berbeda dengan polisi. dirlantas polda jawa barat kombes m aris menyebut korban berjumlah delapan orang. "betul. info terakhir jadi delapan orang (meninggal dunia)," kata dirlantas polda jawa barat kombes m aris saat dimintai konfirmasi.\r',
#    {'entities': [[44, 53, 'LOKASI'],
#      [55, 66, 'LOKASI'],
#      [287, 297, 'LOKASI'],
#      [302, 310, 'LOKASI'],
#      [472, 482, 'LOKASI'],
#      [487, 494, 'LOKASI'],
#      [558, 565, 'LOKASI'],
#      [566, 584, 'ORANG'],
#      [606, 623, 'TANGGAL'],
#      [633, 643, 'ORANG'],
#      [950, 959, 'LOKASI'],
#      [968, 979, 'ORANG'],
#      [991, 1001, 'ORANG'],
#      [1059, 1069, 'LOKASI'],
#      [1079, 1083, 'ORANG'],
#      [1207, 1217, 'LOKASI'],
#      [1227, 1231, 'ORANG']]}],
#   ['\\- kecelakaan terjadi di jalan simpenan, kampung kiarakoneng, desa kertajaya, kecamatan simpenan, kabupaten sukabumi. seorang warga tewas akibat kejadian tersebut. informasi dihimpun, kejadian bermula saat truk melaju dengan kecepatan tinggi dari arah palabuhanratu menuju simpenan. tiba di lokasi kejadian, tepatnya saat jalan menikung, tiba-tiba truk oleng dan menghantam pembatas di kanan jalan. "truk kehilangan kendali, langsung tabrak pembatas langsung nabrak dua orang warga mamad dan didin, satu orang atas nama mamad meninggal dunia," kata endang, warga di lokasi kepada , senin (30/5/2022). satu korban lagi dikatakan nanang mengalami luka-luka dan dibawa ke rsud palabuhanratu. sedangkan korban mamad dikabarkan sempat terseret sejauh 10 meter saat kejadian. sementara itu, ipda m yanuar fajar selaku kanit gakkum satlantas polres sukabumi mengatakan kecelakaan itu terjadi sekitar pukul 06.00 wib. "tidak hati-hatinya pengemudi kendaraan mitsubishi light truck no.pol : f 8665 ql pada saat mengemudikan kendaraannya tidak konsentrasi sehingga hilang kendali ke sebelah kanan jalan," kata fajar. fajar menjelaskan kecelakaan lalu lintas tersebut bermula ketika truk yang dikendarai kamal, pada saat melintasi jalan tikungan kemudian lurus diduga tidak konsentrasi sehingga hilang kendali ke sebelah kanan jalan dan menabrak pagar pembatas jalan yang berada di sebelah kanan jalan. "truk terus melaju menabrak dua orang pejalan kaki didin dan mamad yang sedang berdiri di bahu jalan sebelah kanan. dikarenakan jarak sudah terlalu dekat maka kecelakaan lalu lintas tersebut tidak dapat terhindarkan lagi," ujar fajar. saat ini polisi masih melakukan olah tkp dan mengamankan barang bukti. "sopir masih menjalani pemeriksaan," pungkasnya. [gambas:video 20detik]\r',
#    {'entities': [[88, 96, 'LOKASI'],
#      [108, 117, 'LOKASI'],
#      [252, 265, 'LOKASI'],
#      [273, 282, 'LOKASI'],
#      [482, 487, 'ORANG'],
#      [492, 497, 'ORANG'],
#      [520, 525, 'ORANG'],
#      [549, 555, 'ORANG'],
#      [582, 599, 'TANGGAL'],
#      [674, 688, 'LOKASI'],
#      [790, 804, 'ORANG'],
#      [842, 850, 'LOKASI'],
#      [1100, 1106, 'ORANG'],
#      [1107, 1112, 'ORANG'],
#      [1193, 1198, 'ORANG'],
#      [1443, 1448, 'ORANG'],
#      [1453, 1458, 'ORANG'],
#      [1620, 1626, 'ORANG']]}],
#   ['\\- sepasang suami istri askin (49) dan enggar (40) tertabrak ka tawang alun jurusan banyuwangi-malang. keduanya tewas setelah terseret sejauh 300 meter. kecelakaan terjadi sekitar pukul 7.30 wib di jalan mangga, kelurahan jember lor, kecamatan patrang, jember. mereka tertabrak ka saat melintas dari jalan mangga menuju jalan slamet riyadi. akibat kecelakaan tersebut, kedua korban terseret sejauh 300 meter dan langsung tewas di lokasi kejadian. motor yang dikendarai korban hancur tak berbentuk. "korban melintas di perlintasan kereta, dari barat menuju ke timur, mengendarai motor honda vario bernopol p 8901 qk," kata anggota satlantas polres jember bripka agung, selasa (2/7/2019) pagi. saat tiba di perlintasan kereta, kata agung, pasangan suami istri itu tidak mengetahui datangnya kereta. kedua korban kecelakaan tinggal di jalan mastip lingkungan tegalboto, kelurahan/kecamatan sumbersari. "terjadilah laka tersebut. selanjutnya kami mengumpulkan bahan keterangan dari saksi yang mengetahui kecelakaan tersebut," imbuhnya. kedua korban dievakuasi dan dibawa ke rsd dr soebandi, jember. sementara saat dikonfirmasi terpisah, relawan penjaga pos perlintasan suparman mengaku pintu perlintasan kereta sudah rusak sejak lama. "sudah lama rusak mas itu (pintu perlintasan). sehingga kita pun melaporkan ini ke dishub. tetapi belum ada perbaikan sampai sekarang," kata suparman. [gambas:video 20detik]\r',
#    {'entities': [[24, 29, 'ORANG'],
#      [39, 45, 'ORANG'],
#      [244, 251, 'LOKASI'],
#      [253, 260, 'LOKASI'],
#      [647, 653, 'LOKASI'],
#      [661, 666, 'ORANG'],
#      [668, 685, 'TANGGAL'],
#      [730, 735, 'ORANG'],
#      [887, 898, 'LOKASI'],
#      [1087, 1094, 'LOKASI'],
#      [1372, 1381, 'ORANG']]}],
#   ['\\- polisi menggelar olah tkp kecelakaan maut antara kereta api (ka) jayabaya dengan mobil mitsubishi l300 di perlintasan desa beji, kecamatan beji, kabupaten pasuruan. hasilnya, kecelakaan disebabkan kelalaian sopir mobil. "olah tkp untuk mengetahui kronologi kejadian serta penyebab kecelakaan," kata kasubditbingakkum ditlantas polda jatim akbp m budi hendrawan di lokasi, rabu (9/1/2019). olah tkp dilakukan bersama dinas perhubungan jatim, pt kai daop 8, jasa raharja, sat lantas polres pasuruan dan dinas perhubungan kabupaten pasuruan. dalam olah tkp petugas memintai keterangan sejumlah saksi serta memeriksa kondisi mobil l300 bernopol p 1264 de. menurut budi hendrawan, dari hasil olah tkp sementara diketahui bahwa saat kejadian tak ada lampu penerangan jalan. sopir mobil, mambaul fadil (42) diduga lalai dan tak memperhatikan laju ka jayabaya dari arah barat ke timur. "ada kelalaian sopir di sini, dia tidak mengetahui medan tetapi tidak waspada. sopirnya kan dari luar daerah sini," tandas budi. seperti diberitakan, kecelakaan maut antara mobil travel mitsubishi l 300 bernopol p 1264 de dan ka jayabaya 145 dengan nomor lokomotif cc 20161306 terjadi di perlintasan sebidang tanpa palang pintu desa beji, kecamatan beji, kabupaten pasuruan, rabu (9/1/2019) dinihari. kecelakaan ini menyebabkan 5 penumpang mobil tewas. sedangkan seorang penumpang mengalami luka-luka.\r',
#    {'entities': [[142, 146, 'LOKASI'],
#      [158, 167, 'LOKASI'],
#      [336, 341, 'LOKASI'],
#      [347, 363, 'ORANG'],
#      [375, 390, 'TANGGAL'],
#      [437, 442, 'LOKASI'],
#      [491, 499, 'LOKASI'],
#      [532, 541, 'LOKASI'],
#      [663, 677, 'ORANG'],
#      [784, 797, 'ORANG'],
#      [1004, 1009, 'ORANG'],
#      [1230, 1234, 'LOKASI'],
#      [1246, 1254, 'LOKASI'],
#      [1256, 1271, 'TANGGAL']]}],
#   ['\\- kecelakaan maut melibatkan mobil, motor dan becak terjadi di jalan raya sedarum kecamatan nguling, kabupaten pasuruan, selasa (13/8/2013). tiga orang tewas dalam kecelakaan tersebut. informasi yang dihimpun , kecelakaan terjadi saat mobil daihatsu espass bernopol dk 744 eb melaju dari arah surabaya menuju probolinggo. tiba di lokasi, mobil espass tiba-tiba melaju tanpa kendali. selain itu muncul motor kawasaki bernopol n 5483 fu dan becak motor juga melaju dari arah berlawanan. akibat tertabrak mobil, pasangan suami-istri pengendara motor dan seorang penumpang becak tewas seketika di lokasi. tiga korban tewas dalam kecelakaan maut itu, yakni pasutri mintijo (55) dan rumimi (50), warga kelurahan jodipan, wetan kecamatan blimbing, kota malang dan penumpang becak yang belum teridentifikasi. "selain tiga korban tewas, ada empat korban terluka dan dua diantaranya luka parah," kata kasat lantas polres pasuruan kota akp nadzir syahbasri. korban tewas kemudian dibawa ke kamar mayat rsud dr r soedarsono kota pasuruan. sedangkan korban luka mendapat perawatan intensif di rumah sakit yang sama. "sopir espass bernama holid, warga ambar ketawang, gamping, sleman juga mengalami patah kaki," jelas nadzir.\r',
#    {'entities': [[93, 100, 'LOKASI'],
#      [112, 120, 'LOKASI'],
#      [122, 140, 'TANGGAL'],
#      [294, 302, 'LOKASI'],
#      [310, 322, 'LOKASI'],
#      [661, 668, 'ORANG'],
#      [678, 684, 'ORANG'],
#      [732, 740, 'LOKASI'],
#      [747, 753, 'LOKASI'],
#      [912, 920, 'LOKASI'],
#      [930, 947, 'ORANG'],
#      [1018, 1027, 'LOKASI'],
#      [1126, 1131, 'ORANG'],
#      [1145, 1153, 'LOKASI'],
#      [1155, 1162, 'LOKASI'],
#      [1164, 1170, 'LOKASI'],
#      [1205, 1211, 'ORANG']]}],
# ...
#    {'entities': [[38, 42, 'LOKASI'],
#      [44, 60, 'LOKASI'],
#      [62, 68, 'LOKASI'],
#      [244, 264, 'ORANG'],
#      [274, 290, 'TANGGAL'],
#      [334, 342, 'LOKASI'],
#      [370, 374, 'LOKASI'],
#      [376, 389, 'TANGGAL'],
#      [576, 586, 'LOKASI'],
#      [588, 603, 'LOKASI'],
#      [605, 612, 'LOKASI'],
#      [624, 630, 'LOKASI'],
#      [632, 641, 'LOKASI'],
#      [643, 649, 'LOKASI'],
#      [724, 732, 'ORANG'],
#      [739, 748, 'ORANG'],
#      [755, 761, 'ORANG'],
#      [794, 800, 'ORANG'],
#      [809, 814, 'ORANG'],
#      [897, 907, 'ORANG'],
#      [909, 927, 'ORANG'],
#      [1369, 1376, 'ORANG']]}],
#   ['\\- ramadhan alias rama (32), nelayan di kecamatan torue, kabupaten parigi moutong (parimo), sulawesi tengah (sulteng), ditemukan tewas. sebelumnya, korban dilaporkan hilang saat mencari ikan. "pagi, tadi sekitar pukul 09.30 wita, kami menemukan korban dalam posisi mengapung," kata kepala sar kota palu basrano kepada wartawan, selasa (12/5/2020). basarno menjelaskan, jasad korban ditemukan sekitar 20 meter dari lokasi terbaliknya kapal. jasad kini telah dievakuasi ke rumah duka. "sekitar 20 meter dari lokasi kejadian. kemudian dievakuasi ke rumah duka," ujar basrano. selanjutnya __ halaman 1 2\r',
#    {'entities': [[3, 22, 'ORANG'],
#      [50, 55, 'LOKASI'],
#      [67, 81, 'LOKASI'],
#      [83, 89, 'LOKASI'],
#      [92, 107, 'LOKASI'],
#      [109, 116, 'LOKASI'],
#      [298, 302, 'LOKASI'],
#      [303, 310, 'ORANG'],
#      [328, 346, 'TANGGAL'],
#      [348, 355, 'ORANG'],
#      [564, 572, 'ORANG']]}],
#   ['\\- sebuah truk bermuatan 13.000 kilogram cairan gas lpg terguling di jalan trans sulawesi, kabupaten mamuju, sulawesi barat (sulbar). kecelakaan tunggal itu disebabkan rem blong. kernet truk bernama firman menduga kecelakaan disebabkan rem blong karena truk sempat hilang kendali saat melewati jalan menikung dalam kecepatan tinggi, "kalau lihat posisi ban yang basah, kayaknya rem blong, ini kami lagi menunggu informasi dari bos karena mobil mau dievakuasi," kata firman kepada wartawan, rabu (4/3/2020). kecelakaan terjadi pada subuh tadi. truk bernomor polisi dc-8751-aw itu melaju dari makassar, sulawesi selatan, menuju belang-belang, kecamatan kalukku, kabupaten mamuju. bagian muka truk tersebut ringsek setelah menabrak tiang listrik di pinggir jalan. tidak ada korban jiwa dalam peristiwa ini. sang sopir berhasil dievakuasi warga, setelah terjepit badan mobil. sopir tersebut dilarikan ke rumah sakit akibat menderita luka pada bagian kepala dan kaki. kecelakaan ini turut mengakibatkan pasokan listrik pada sejumlah wilayah di daerah ini terputus. sebab ada kabel yang putus akibat tiang listrik tertabrak truk tersebut.\r',
#    {'entities': [[81, 89, 'LOKASI'],
#      [101, 107, 'LOKASI'],
#      [109, 123, 'LOKASI'],
#      [125, 131, 'LOKASI'],
#      [199, 205, 'ORANG'],
#      [466, 472, 'ORANG'],
#      [490, 505, 'TANGGAL'],
#      [591, 599, 'LOKASI'],
#      [601, 617, 'LOKASI'],
#      [651, 658, 'LOKASI'],
#      [670, 677, 'LOKASI']]}],
#   ['\\- insiden nahas menimpa dua mahasiswa institut agama islam negeri (iain) parepare, sulawesi selatan (sulsel). keduanya tewas usai terlibat tabrakan dengan mobil pikap yang sedang ngebut dan lawan arus di kabupaten pinrang. peristiwa itu terjadi di desa leppangeng, kecamatan patampanua, kabupaten pinrang pada minggu (8/5) sekitar pukul 06.30 wita. kedua korban tewas di tempat. "benar, telah terjadi kecelakaan lalu lintas di jalan poros pinrang-polman tadi pagi antara motor dan pikap. dua orang meninggal di tkp," ujar kasatlantas polres pinrang akp nawir kepada , minggu (8/5). kecelakaan bermula saat mobil pikap dengan nomor polisi dd 8234 rk melaju kencang dan hendak menyalip kendaraan lain. mobil tersebut mengambil lajur kendaraan dari arah berlawanan sehingga terjadi tabrakan. "saat bersamaan datang sepeda motor yang dikendarai saenab ali berboncengan dengan nurul inayah, sehingga terjadi tabrakan," tuturnya. korban dalam insiden nahas itu merupakan mahasiswi iain parepare. keduanya dilaporkan berasal dari kabupaten polewali mandar, sulawesi barat (sulbar). "saenab ali dan nurul inayah meninggal di tkp. keduanya berstatus mahasiswi di parepare dan berasal dari kabupaten polman," bebernya. dalam insiden itu, dua penumpang pikap mengalami luka-luka atas nama syamsul dan bahtiar. keduanya langsung dilarikan ke rsud lasinrang untuk mendapatkan perawatan. sementara, pengemudi pikap atas nama muchtar langsung diamankan di polres pinrang untuk mempertanggungjawabkan perbuatannya. dia dijerat pasal 310 ayat (4) uu ri nomor 22 tahun 2009 tentang lalu lintas dan angkutan jalan dengan ancaman hukuman penjara paling lama 6 tahun. "pengemudi pikap sudah kami tahan. sudah ditetapkan sebagai tersangka. ancaman hukuman di atas lima tahun penjara," terangnya. [gambas:video 20detik]\r',
#    {'entities': [[74, 82, 'LOKASI'],
#      [84, 100, 'LOKASI'],
#      [102, 108, 'LOKASI'],
#      [215, 223, 'LOKASI'],
#      [276, 286, 'LOKASI'],
#      [298, 305, 'LOKASI'],
#      [311, 323, 'TANGGAL'],
#      [542, 549, 'LOKASI'],
#      [569, 581, 'TANGGAL'],
#      [842, 852, 'ORANG'],
#      [873, 885, 'ORANG'],
#      [981, 990, 'LOKASI'],
#      [1034, 1049, 'LOKASI'],
#      [1051, 1065, 'LOKASI'],
#      [1067, 1073, 'LOKASI'],
#      [1076, 1087, 'ORANG'],
#      [1092, 1104, 'ORANG'],
#      [1155, 1163, 'LOKASI'],
#      [1191, 1197, 'LOKASI'],
#      [1279, 1286, 'ORANG'],
#      [1291, 1299, 'ORANG'],
#      [1449, 1456, 'LOKASI']]}],
#   ['\\- reni anggraeni (12), pelajar smp yang ditabrak metro mini di daerah layur, pulogadung, jakarta timur, sudah siuman. reni mengalami trauma kepala dan luka-luka. orangtua reni berharap sopir metro mini yang menabrak anaknya dan dua pelajar lainnya dihukum berat. "kalau bisa sih seumur hidup saja, biar pada kapok enggak ugal-ugalan lagi," kara orangtua reni, nurhayati (40), di ruang perawatan rs antam medika, jl pemuda no. 1a, jaktim, rabu (24/7/2013). nurhayati mengatakan, anaknya merupakan pribadi yang pendiam. anaknya enggan bercerita kecuali dipaksa-paksa. "orang dia kemarin ditanya polisi juga bilangnya enggak tahu. ditanya sama dokter juga sakitnya apa enggak, enggak gitu aja," ujar wanita beranak empat tersebut. nurhayati mendapat kabar dari anaknya tertabrak metro mini dari sepupu reni. saat itu metro mini 47 jurusan senen-pondok kopi menabrak reni dan dua orang rekannya di dekat halte busway layur, pulogadung. akibat kecelakaan ini satu orang rekan reni, beniti lini manata, meninggal dunia. sedangkan satu korban lainnya adalah rahmi utami (12) yang dirawat di rs tarakan. "sebenarnya saat itu ada lima anak yang mau menyebrang. mungkin yang dua enggak jadi nyebrang, saya juga enggak tahu, diceritain sepupunya," ujar wanita yang tinggal di daerah rawamangun tersebut. polisi telah menetapkan sopir metro mini maut itu sebagai tersangka. ws (22) terancam hukuman kurungan selama 6 tahun. tersangka juga ternyata tidak memiliki sim dan hanya membawa photocopy stnk.\r',
#    {'entities': [[3, 17, 'ORANG'],
#      [78, 88, 'LOKASI'],
#      [90, 103, 'LOKASI'],
#      [355, 359, 'ORANG'],
#      [361, 370, 'ORANG'],
#      [431, 437, 'LOKASI'],
#      [439, 455, 'TANGGAL'],
#      [457, 466, 'ORANG'],
#      [729, 738, 'ORANG'],
#      [864, 868, 'ORANG'],
#      [921, 932, 'LOKASI'],
#      [972, 976, 'ORANG'],
#      [978, 996, 'ORANG'],
#      [1052, 1063, 'ORANG']]}],
#   ['\\- mobil audi a4 menabrak bajaj di kawasan cempaka mas, jakarta pusat, dinihari tadi. kondisi kendaraan mewah itu rusak cukup parah. ini penampakannya. sedan bernopol b 418 rfs itu kini teronggok di pos lantas jaktim, kebon nanas, jakarta timur, selasa (28/5/2013). seluruh bagian depannya hancur, bahkan ada bagian mesin yang terlempar keluar. bagian yang mengalami kerusakan cukup parah ada di sebelah kiri depan. airbag di bangku penumpang kiri juga terbuka. kaca mobil hancur. bajaj yang tertabrak mobil itu juga rusak. namun kondisinya masih berbentuk. hanya kaca depan yang hancur dan beberapa bagian lampu patah. kendaraan roda tiga bernopol b 2596 oe itu menurut pemiliknya masih bisa diperbaiki. peristiwa ini terjadi sekitar pukul 02.00 wib di perempatan cempaka mas, jakpus. menurut polisi, mobil audi terlibat kecelakaan dengan bajaj tersebut hingga mengalami kerusakan parah.\r',
#    {'entities': [[43, 54, 'LOKASI'],
#      [56, 69, 'LOKASI'],
#      [210, 216, 'LOKASI'],
#      [218, 229, 'LOKASI'],
#      [231, 244, 'LOKASI'],
#      [246, 264, 'TANGGAL'],
#      [765, 776, 'LOKASI'],
#      [778, 785, 'LOKASI']]}],
#   ['\\- sebuah truk tronton menabrak pohon di jl metro pondok indah, kebayoran lama, jaksel. akibatnya, seorang pengendara motor terluka. kasubdit gakkum ditlantas polda metro jaya akbp fahri siregar mengatakan, kecelakaan terjadi di jl metro pondok indah, kebayoran lama, jaksel sekitar pukul 05.00 wb pagi tadi. "aealnya, truk tronton melaju dari arah utara menuju ke selatan di jalan metro pondok indah, tepatnya di depan kantor metro pondok," kata fahri dalam keterangannya kepada wartawan, sbtu (21/3/2020). karena kurang berhati-hati dan konsentrasi, truk oleng ke kanan. truk kemudian menabrak pondasi penerangan jalan dan pohon yang ada di median jalan," imbuhnya. kejadian ini kemudian mengakibatkan pohon tumbang ke arah jalan berlawanan. bersamaan dengan kejadian itu, pengemudi motor honda beat berinisial nar melintas dan tertimpa pohon. "pohon tumbang menimpa motor honda beat tersebut. memgakibatkan pengemudi pada pengendara dan penumpang motor honda beat mengalami luka dibawa ke rs," jelas fahri. sementara sopir truk, fh diamankan polisi. dia dimintai keterangan atas kejadian itu.\r',
#    {'entities': [[50, 62, 'LOKASI'],
#      [64, 78, 'LOKASI'],
#      [80, 87, 'LOKASI'],
#      [176, 194, 'ORANG'],
#      [238, 250, 'LOKASI'],
#      [252, 266, 'LOKASI'],
#      [268, 274, 'LOKASI'],
#      [388, 400, 'LOKASI'],
#      [447, 452, 'ORANG'],
#      [490, 506, 'TANGGAL'],
#      [1003, 1009, 'ORANG']]}],
#   ['\\- kecelakaan beruntun terjadi di jalan mt haryono, jakarta selatan (jaksel). kecelakaan itu melibatkan tujuh unit motor dan dua unit mobil. lokasi kecelakaan itu tepatnya di depan menara saidah, jalan mt haryono, jakarta. kecelakaan terjadi sekitar pukul 20.00 wib, rabu (25/5/2022). panit lantas wilayah pancoran iptu denny setiawan mengatakan kecelakaan itu mengakibatkan dua orang tewas. "betul tadi di tkp kurang lebih yang meninggal di tempat ada dua. kemudian yang luka berat, luka ringan udah dibawa ke rumah sakit," kata denny kepada wartawan di lokasi. pantauan di lokasi, kecelakaan itu menyebabkan kemacetan lalu lintas. tampak kendaraan-kendaraan yang terlibat kecelakaan itu mengalami kerusakan cukup parah. polisi membawa kendaraan tersebut ke kantor tmc polda metro jaya di pancoran, jakarta selatan. sopir yang diduga menjadi penyebab kecelakaan beruntun telah diamankan ke polda metro jaya. "sementara sudah diamankan di polda," ujarnya. [gambas:video 20detik]\r',
#    {'entities': [[52, 67, 'LOKASI'],
#      [69, 75, 'LOKASI'],
#      [214, 222, 'LOKASI'],
#      [267, 283, 'TANGGAL'],
#      [530, 535, 'ORANG'],
#      [800, 816, 'LOKASI']]}],
#   ['\\- bus transjakarta b 7823 tgb yang menabrak pejalan kaki perempuan di mampang dibawa ke unit kecelakaan lalu lintas (laka lantas) di pancoran, jaksel. korban yang diperkirakan masih remaja ini meninggal dunia di lokasi. kecelakaan terjadi di depan tunas toyota mampang di lajur busway arah ke hr rasuna said, kuningan, jumat (9/12/2016). kecelakaan ini membuat jalur transj ditutup dan menyebabkan kemacetan di jalur biasa. saksi mata bernama sarjudin menyebut korban tengah menyeberang bersama dua orang lainnya. saat itu bus transj melaju dan membunyikan klakson sebagai peringatan. namun satu orang tertabrak dan meninggal dunia. petugas juga masih mengatur lalu lintas karena kemacetan dan kerumunan warga di lokasi.\r',
#    {'entities': [[134, 142, 'LOKASI'],
#      [144, 151, 'LOKASI'],
#      [310, 318, 'LOKASI'],
#      [320, 337, 'TANGGAL']]}],
#   ['\\- pejalan kaki di jalan raya puspiptek, setu, tangerang selatan (tangsel), tertabrak truk sekitar pukul 03.30 wib tadi. akibatnya, pejalan kaki itu tewas di tempat karena terlindas truk. kanit laka polres tangsel iptu nanda menjelaskan, saat itu truk datang dari arah muncul menuju pamulang melewati jalan raya puspiptek. setiba di dekat perumahan panorama serpong, truk menabrak pejalan kaki hingga terpental dan terlindas di bagian kepalanya. "kendaraan _dump truck_ yang tidak diketahui identitasnya datang dari arah timur menuju barat atau dari arah muncul ke arah pamulang melewati jalan raya puspiptek," kata nanda kepada wartawan, sabtu (19/3/2022). "setibanya di dekat perumahan panorama serpong, diduga menabrak pejalan kaki yang identitasnya belum diketahui, yang berjalan dari arah utara ke arah selatan sehingga terpental dan terlindas pada bagian kepala," sambungnya. pejalan kaki yang identitasnya tidak diketahui itu tewas di tempat. nanda mengatakan korban langsung dievakuasi ke rsud tangerang. "akibat kecelakaan lalu lintas tersebut, pejalan kaki yang identitasnya tidak diketahui mengalami cedera kepala berat dan meninggal dunia di tkp, kemudian dievakuasi ke rsud tangerang," tutur nanda. nanda menjelaskan identitas dari sopir truk yang menabrak pejalan kaki itu belum diketahui. saat ini polisi masih melakukan penyelidikan. "sementara truknya masih kami selidiki," imbuhnya. [gambas:video 20detik]\r',
#    {'entities': [[41, 45, 'LOKASI'],
#      [47, 64, 'LOKASI'],
#      [66, 73, 'LOKASI'],
#      [206, 213, 'LOKASI'],
#      [283, 291, 'LOKASI'],
#      [358, 365, 'LOKASI'],
#      [616, 621, 'ORANG'],
#      [639, 656, 'TANGGAL'],
#      [697, 704, 'LOKASI'],
#      [1002, 1012, 'LOKASI'],
#      [1187, 1196, 'LOKASI'],
#      [1205, 1211, 'ORANG'],
#      [1212, 1217, 'ORANG']]}],
#   ['\\- deni hermawan (33) tewas di rel kereta api kampung serpong, serpong, tangerang selatan. korban diduga bunuh diri dengan menabrakkan tubuhnya ke kereta api. "korban berlari sambil berteriak ingin bunuh diri mengikuti jalur kereta api dan tak menghiraukan adanya lintasan kereta api," kata kasat reskrim polres tangsel akp alexander yurikho dalam keterangannya, rabu (14/3/2018). peristiwa itu terjadi pada selasa (13/3) sekitar pukul 19.00 wib. saat itu, korban yang mengendarai sepeda motor berhenti di tengah jalur kereta api. "korban berhenti dengan kendaraan sepeda motor di tengah jalur kereta api, kemudian korban ditegur saksi dan korban tidak menghiraukan," lanjut alexander. korban lalu tertabrak dan terseret sejauh 200 meter. nyawanya tak terselamatkan karena cedera parah. "korban mengalami luka parah. badan terbelah di bagian perut dan dada. kedua kaki patah. kepala, tangan dan dada bagian kanan hancur," imbuhnya. jasad korban lalu dibawa ke rsu tangerang. polisi masih mencari keluarga korban untuk mengetahui motif bunuh diri yang dilakukan korban.\r',
#    {'entities': [[3, 16, 'ORANG'],
#      [63, 70, 'LOKASI'],
#      [72, 90, 'LOKASI'],
#      [312, 319, 'LOKASI'],
#      [320, 341, 'ORANG'],
#      [363, 379, 'TANGGAL'],
#      [408, 421, 'TANGGAL'],
#      [675, 685, 'ORANG'],
#      [964, 974, 'LOKASI']]}]]}

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("id")
# the DocBin will store the example documents
db = DocBin()
for text, annotations in tqdm(TRAIN_DATA['annotations']):
    doc = nlp(text)
    ents = []
    for start, end, label in annotations['entities']:
        span = doc.char_span(start, end, label=label,alignment_mode='contract')
        if span is None:
            print('Skipping entity')
        else:
            ents.append(span)
    doc.ents = ents
    db.add(doc)
db.to_disk("./train.spacy")
# Out:
#  11%|█▏        | 45/395 [00:01<00:05, 60.45it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
#  56%|█████▌    | 220/395 [00:02<00:00, 188.68it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
#  76%|███████▌  | 299/395 [00:02<00:00, 173.42it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# 100%|██████████| 395/395 [00:02<00:00, 132.09it/s]
