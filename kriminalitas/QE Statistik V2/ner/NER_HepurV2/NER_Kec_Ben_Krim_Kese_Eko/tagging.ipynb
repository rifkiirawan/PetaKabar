# %% [markdown]
# # Data Preparation

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Evaluation

# %%
# import package for displaying NER results
from spacy import load, displacy
import pandas as pd
import joblib
import re
import time
import datetime
from datetime import datetime as dt

# %%
kodePos= pd.read_csv('dataset/lokasi2.csv')
kodePos.head()
# Out:
#   provinsi kabupaten     kecamatan
# 0     bali    badung  kuta selatan
# 1     bali    badung          kuta
# 2     bali    badung    kuta utara
# 3     bali    badung        petang
# 4     bali    badung    abiansemal

# %%
listLokasi=[]
for x in range(0,len(kodePos)):
    arr=[kodePos.iloc[x,0],kodePos.iloc[x,1],kodePos.iloc[x,2]]
    listLokasi.append(arr)

# %%
import joblib

joblib.dump(listLokasi,"listProvKabKec.pkl")
# Out:
# ['listProvKabKec.pkl']

# %%
def compareToDatasetLocation(provinsi,kabupaten,kecamatan):
      trueLocation= checkLocation(provinsi,kabupaten,kecamatan)
      print(trueLocation)
      if(len(trueLocation)==3):
            for i in range(0,len(kodePos)):
                  if(kodePos.iloc[i,0]==trueLocation[2] and kodePos.iloc[i,1]==trueLocation[1] and kodePos.iloc[i,2]==trueLocation[0]):
                        return trueLocation
                  
            trueLocation.insert(0,'-')
            trueLocation.insert(1,'-')
            trueLocation.insert(2,'-')
            return trueLocation

      elif(len(trueLocation)==2):
            for i in range(0,len(kodePos)):
                  if(kodePos.iloc[i,0]==trueLocation[1] and kodePos.iloc[i,1]==trueLocation[0]):
                        trueLocation.insert(0,'-')
                        return trueLocation
                  elif(kodePos.iloc[i,1]==trueLocation[1] and kodePos.iloc[i,2]==trueLocation[0]):
                        trueLocation.insert(2,kodePos.iloc[i,0])
                        return trueLocation
                  elif(kodePos.iloc[i,0]==trueLocation[1] and kodePos.iloc[i,2]==trueLocation[0]):
                        trueLocation.insert(1,'-')
                        return trueLocation
      
            trueLocation.insert(0,'-')
            trueLocation.insert(1,'-')
            trueLocation.insert(2,'-')
            return trueLocation

      elif(len(trueLocation)==1):
            for i in range(0,len(kodePos)):
                  if(kodePos.iloc[i,0]==trueLocation[0] ):
                        trueLocation.insert(0,'-')
                        trueLocation.insert(1,'-')
                        return trueLocation
                  elif(kodePos.iloc[i,1]==trueLocation[0] ):
                        trueLocation.insert(0,'-')
                        trueLocation.insert(2,kodePos.iloc[i,0])
                        return trueLocation
                  elif(kodePos.iloc[i,2]==trueLocation[0] ):
                        trueLocation.insert(1,'-')
                        trueLocation.insert(2,kodePos.iloc[i,0])
                        return trueLocation
      
            trueLocation.insert(0,'-')
            trueLocation.insert(1,'-')
            trueLocation.insert(2,'-')
            return trueLocation
            
      else:
            trueLocation.insert(0,'-')
            trueLocation.insert(1,'-')
            trueLocation.insert(2,'-')
            return trueLocation

# %%
def checkLocation(provinsi,kabupaten,kecamatan):
    hasil=[]
    if(len(provinsi)>0 and len(kabupaten)>0 and len(kecamatan)>0):
        provinsi_top=provinsi[0]
        kabupaten_top=kabupaten[0]
        kecamatan_top=kecamatan[0]
        if(kecamatan_top[1]<kabupaten_top[1]<provinsi_top[1]):
            if(kabupaten_top[1]-kecamatan_top[2]<=60 and provinsi_top[1]-kabupaten_top[2]<=60):
                hasil.append(kecamatan_top[0])
                hasil.append(kabupaten_top[0])
                hasil.append(provinsi_top[0])
            elif(kabupaten_top[1]-kecamatan_top[2]<=60 and provinsi_top[1]-kabupaten_top[2]>60):
                hasil.append(kecamatan_top[0])
                hasil.append(kabupaten_top[0])
            elif(kabupaten_top[1]-kecamatan_top[2]>60 and provinsi_top[1]-kabupaten_top[2]>60):
                hasil.append((kecamatan_top[0]))
        elif((kecamatan_top[1]<kabupaten_top[1])and(kabupaten_top[1]>provinsi_top[1])and(kecamatan_top[1]<provinsi_top[1])):
            if(provinsi_top[1]-kecamatan_top[2]<=60):
                hasil.append(kecamatan_top[0])
                hasil.append(provinsi_top[0])
            elif(provinsi_top[1]-kecamatan_top[2]>60):
                hasil.append(kecamatan_top[0])
        elif((kecamatan_top[1]>kabupaten_top[1])and(kabupaten_top[1]<provinsi_top[1])and(kecamatan_top[1]>provinsi_top[1])):
            if(provinsi_top[1]-kabupaten_top[2]<=60):
                hasil.append(kabupaten_top[0])
                hasil.append(provinsi_top[0])
            elif(provinsi_top[1]-kabupaten_top[2]>60):
                hasil.append((kabupaten_top[0]))
        elif((kecamatan_top[1]>kabupaten_top[1])and(kabupaten_top[1]<provinsi_top[1])and(kecamatan_top[1]<provinsi_top[1])):
            hasil.append(kabupaten_top[0])
        elif((kecamatan_top[1]<kabupaten_top[1])and(kabupaten_top[1]>provinsi_top[1])and(kecamatan_top[1]>provinsi_top[1])):
            hasil.append(provinsi_top[0])
        elif(kecamatan_top[1]>kabupaten_top[1]>provinsi_top[1]):
            hasil.append(provinsi_top[0])
    elif(len(provinsi)>0 and len(kabupaten)>0 and len(kecamatan)==0):
        provinsi_top=provinsi[0]
        kabupaten_top=kabupaten[0]
        if(kabupaten_top[1]<provinsi_top[1]):
            if(provinsi_top[1]-kabupaten_top[2]<=60):
                hasil.append(kabupaten_top[0])
                hasil.append(provinsi_top[0])
            else:
                hasil.append(kabupaten_top[0])
        elif(kabupaten_top[1]>provinsi_top[1]):
            hasil.append(provinsi_top[0])
    elif(len(provinsi)>0 and len(kabupaten)==0 and len(kecamatan)>0):
        provinsi_top=provinsi[0]
        kecamatan_top=kecamatan[0]
        if(kecamatan_top[1]<provinsi_top[1]):
            if(provinsi_top[1]-kecamatan_top[2]<=60):
                hasil.append(kecamatan_top[0])
                hasil.append(provinsi_top[0])
            else:
                hasil.append(kecamatan_top[0])
        elif(kecamatan_top[1]>provinsi_top[1]):
            hasil.append(provinsi_top[0])
    elif(len(provinsi)==0 and len(kabupaten)>0 and len(kecamatan)>0):
        kabupaten_top=kabupaten[0]
        kecamatan_top=kecamatan[0]
        if(kecamatan_top[1]<kabupaten_top[1]):
            if(kabupaten_top[1]-kecamatan_top[2]<=60):
                hasil.append(kecamatan_top[0])
                hasil.append(kabupaten_top[0])
            else:
                hasil.append(kecamatan_top[0])
        elif(kecamatan_top[1]>kabupaten_top[1]):
            hasil.append(kabupaten_top[0])
    elif(len(provinsi)>0 and len(kabupaten)==0 and len(kecamatan)==0):
        hasil.append(provinsi[0][0])
    elif(len(provinsi)==0 and len(kabupaten)>0 and len(kecamatan)==0):
        hasil.append(kabupaten[0][0])
    elif(len(provinsi)==0 and len(kabupaten)==0 and len(kecamatan)>0):
        hasil.append(kecamatan[0][0])
    elif(len(provinsi)==0 and len(kabupaten)==0 and len(kecamatan)==0):
        return hasil
    
    return hasil

# %%
# import model
link_to_model = "output/model-last"
loaded_model = load(link_to_model)

# %%
test_text = """beliau pulang dinas aceh melewati jalan lokasi penembakan kabid humas bandung polda maluku kombes Muhammad Roem ohoirat roem bharaka tewas ditembak jalan mengaku mengkonfirmasi bharaka ditembak berkendara jalan ditembak situlah versi situ berboncengan versi roem roem ditangani pom ad penjelasan terkait kronologi penembakan memeriksa pom ad diberitakan menembak bharaka pratu ri menembak rekannya anggota tni prada prada dilaporkan kritis meninggal kondisi kritis rumah sakit di aceh barat meninggal anggota brimob kapendam xvi pattimura kolonel arh adi prayogo choirul fajar wartawan rabu 163 penembakan anggota tni polri rabu 163 pratu ri menjalani pemeriksaan intensif polisi militer motif penembakan pratu ri di jakarta barat diduga mengalami depresi bandar pasir mandoge indikasinya kondisi depresi akut pemeriksaan psikologis barat kejiwaan didalami diperiksa"""

# %%
doc = loaded_model(test_text)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">beliau pulang dinas
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aceh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOKASI</span>
# </mark>
#  melewati jalan lokasi penembakan kabid humas bandung polda
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maluku
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOKASI</span>
# </mark>
#  kombes Muhammad Roem ohoirat roem bharaka tewas ditembak jalan mengaku mengkonfirmasi bharaka ditembak berkendara jalan ditembak situlah versi situ berboncengan versi roem roem ditangani pom ad penjelasan terkait kronologi penembakan memeriksa pom ad diberitakan menembak bharaka pratu ri menembak rekannya anggota tni prada prada dilaporkan kritis meninggal kondisi kritis rumah sakit di aceh barat meninggal anggota brimob kapendam xvi pattimura kolonel arh
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adi prayogo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORANG</span>
# </mark>
#  choirul fajar wartawan rabu 163 penembakan anggota tni polri rabu 163 pratu ri menjalani pemeriksaan intensif polisi militer motif penembakan pratu ri di
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jakarta barat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOKASI</span>
# </mark>
#  diduga mengalami depresi bandar pasir mandoge indikasinya kondisi depresi akut pemeriksaan psikologis barat kejiwaan didalami diperiksa</div></span>

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# aceh 20 24 LOKASI
# maluku 84 90 LOKASI
# adi prayogo 551 562 ORANG
# jakarta barat 717 730 LOKASI

# %%
df_test = pd.read_csv('dataset/df_test_lower.csv')
df_test.head()
# Out:
#                                                title  \
# 0  Aksi Brutal Koki Hajar Wanita Teman Kencan Pak...
# 1  Perampok Minimarket Curhat, Sakit Hati Gegara ...
# 2  Pria Ancam Patahkan Leher Walkot Bobby Dilapor...
# 3  Jual Motor Curian Via Facebook, 2 Anak di Beka...
# 4  Oknum Brimob Suruhan Eks Kasatpol PP Buang Jak...
#
#                             date  \
# 0  Sabtu, 14 Mei  2022 08:34 WIB
# 1  Kamis, 19 Mei  2022 06:11 WIB
# 2  Minggu, 24 Apr 2022 14:09 WIB
# 3   Sabtu, 05 Feb 2022 21:13 WIB
# 4  Jumat, 20 Mei  2022 11:07 WIB
#
#                                          description         source
# 0  \- aksi percobaan perampokan bersenjata ulekan...  www.detik.com
# 1  \- aksi perampokan di sebuah minimarket di jl ...  www.detik.com
# 2  \- pria yang ancam patahkan leher wali kota me...  www.detik.com
# 3  \- polisi menangkap dua orang anak berusia 13 ...  www.detik.com
# 4  \- oknum anggota brimob polda sulsel chaerul a...  www.detik.com

# %%
lokasi_csv = 'dataset/location.csv'
df_lokasi = pd.read_csv(lokasi_csv)
df_lokasi.head()
# Out:
#               nama    lokasi
# 0             bali  provinsi
# 1  bangka belitung  provinsi
# 2           banten  provinsi
# 3         bengkulu  provinsi
# 4    di yogyakarta  provinsi

# %%
list_provinsi=joblib.load('dataset/modelLokasi/provinsi.pkl')
list_kabupaten=joblib.load('dataset/modelLokasi/kabupaten.pkl')
list_kecamatan=joblib.load('dataset/modelLokasi/kecamatan.pkl')

# %%
def getNewsTime(dateTime: str):
    month_to_number = {
      'jan': '1',
      'feb': '2',
      'mar': '3',
      'apr': '4',
      'mei': '5',
      'jun': '6',
      'jul': '7',
      'agu': '8',
      'sep': '9',
      'okt': '10',
      'nov': '11',
      'des': '12',
    }

    splitted_timestamp = dateTime.split()
    pre_formatted_time = splitted_timestamp[1] + '/' + month_to_number[splitted_timestamp[2].lower()] + '/' + splitted_timestamp[3]
    
    return pre_formatted_time

# %%
def compareDateArray(sortByLength,newsDate):
    print("newsDate : ", newsDate)
    print("sortByLength : ", sortByLength)
    year = newsDate.split('/')[2]
    timestampList = []
    
    def convertToTimestapms(date):
        return int(time.mktime(datetime.datetime.strptime(date, "%d/%m/%Y").timetuple()))

    for i, tempTime in enumerate(sortByLength):
        # Find the content inside parentheses
        print("tempTime : ", tempTime)
        if(tempTime[-1:]!=')'):
            tempTime=tempTime+')'
            
        currTime = re.search(r'\((.*?)\)', tempTime)
        
        if (currTime != None):
            currTime = currTime.group(1)
            currTime = str(currTime)
            currTime=currTime.replace("\\", "")
        
            
        print("currTime : ", currTime,type(currTime))
        
        if (tempTime.lower() == 'kemarin' or ('kemarin' in tempTime.lower())):
            timestampList.append(convertToTimestapms(newsDate) - (24*60*60))
        
        if (currTime == None or currTime==''):
            
            return newsDate
        else:
            # Find the year
            print("currTime2 : ", currTime)
            splitted = currTime.split('/')
            print("splitted : ", splitted)

            formattedDate = None
            if (len(splitted) == 3):
                if(len(splitted[2])==2):
                    splitted[2]=year
                    currTime="/".join(splitted)
                year = splitted[2]
                timestampList.append(convertToTimestapms(currTime))
            elif (len(splitted) == 2):
                formattedDate = (splitted[0] + '/' + splitted[1] + '/' + year)
                timestampList.append(convertToTimestapms(formattedDate))
            
    print(timestampList)
    return dt.fromtimestamp(sorted(timestampList)[0]).strftime('%d/%m/%Y')

# %%
def toOriginal(teks):
    hasil=''
    if(teks=='sulsel'):
        hasil='sulawesi selatan'
    elif(teks=='sultra'):
        hasil='sulawesi tenggara'
    elif(teks=='sulut'):
        hasil='sulawesi utara'
    elif(teks=='sulteng'):
        hasil='sulawesi tengah'
    elif(teks=='sulbar'):
        hasil='sulawesi barat'
    elif(teks=='kaltim'):
        hasil='kalimantan timur'
    elif(teks=='kaltara'):
        hasil='kalimantan utara'
    elif(teks=='kalteng'):
        hasil='kalimantan tengah'
    elif(teks=='kalsel'):
        hasil='kalimantan selatan'
    elif(teks=='kalbar'):
        hasil='kalimantan barat'
    elif(teks=='jatim'):
        hasil='jawa timur'
    elif(teks=='jateng'):
        hasil='jawa tengah'
    elif(teks=='jabar'):
        hasil='jawa barat'
    elif(teks=='diy'):
        hasil='di yogyakarta'
    elif(teks=='jakbar'):
        hasil='jakarta barat'
    elif(teks=='jaktim'):
        hasil='jakarta timur'
    elif(teks=='jaksel'):
        hasil='jakarta selatan'
    elif(teks=='jakpus'):
        hasil='jakarta pusat'
    elif(teks=='jakut'):
        hasil='jakarta utara'
    elif(teks=='nad'):
        hasil='nanggroe aceh darussalam'
    elif(teks=='sumsel'):
        hasil='sumatera selatan'
    elif(teks=='sumut'):
        hasil='sumatera utara'
    elif(teks=='sumbar'):
        hasil='sumatera barat'
    else:
        hasil=teks
    return hasil

# %%
document_results = []
for i in range(0, df_test.shape[0]):
# for i in range(0, 1):
      print(i)
      news = df_test.iloc[i, -2]
      doc = loaded_model(news)

      # newsDate = getNewsTime(df_test.iloc[21,1])
      newsDate = getNewsTime(df_test.iloc[i,1])

      provinsi = []
      kabupaten = []
      kecamatan = []
      tanggal = []
      orang = []
      visited = []

      tanggal_asli=''

      for ent in doc.ents:
            if(ent.label_== 'LOKASI'):
                  if(ent.text[-1:]=='.'):
                        teks = ent.text[:-1]
                        teks = toOriginal(teks)
                        if ((teks in list_provinsi) and (teks not in visited)):
                              provinsi.append([teks,ent.start_char,ent.end_char])
                              visited.append(teks)
                        elif ((teks in list_kabupaten) and (teks not in visited)):
                              kabupaten.append([teks,ent.start_char,ent.end_char])
                              visited.append(teks)
                        elif ((teks in list_kecamatan) and (teks not in visited)):
                              kecamatan.append([teks,ent.start_char,ent.end_char])
                              visited.append(teks)
                  else:
                        teks = toOriginal(ent.text)
                        if ((teks in list_provinsi) and (teks not in visited)):
                              provinsi.append([teks,ent.start_char,ent.end_char])
                              visited.append(teks)
                        elif ((teks in list_kabupaten) and (teks not in visited)):
                              kabupaten.append([teks,ent.start_char,ent.end_char])
                              visited.append(teks)
                        elif ((teks in list_kecamatan) and (teks not in visited)):
                              kecamatan.append([teks,ent.start_char,ent.end_char])
                              visited.append(teks)
            elif(ent.label_== 'TANGGAL'):
                  if(ent.text[-1:]=='.'):
                        teks = ent.text[:-1]
                        if (teks not in visited):
                              tanggal.append(teks)
                              visited.append(teks)
                  else:
                        if (ent.text not in visited):
                              tanggal.append(ent.text)
                              visited.append(ent.text)
            elif(ent.label_== 'ORANG'):
                  if(ent.text[-1:]=='.'):
                        teks = ent.text[:-1]
                        if (teks not in visited):
                              orang.append(teks)
                              visited.append(teks)
                  else:
                        if (ent.text not in visited):
                              orang.append(ent.text)
                              visited.append(ent.text)

      visited.clear()

      sortedTimes = sorted(tanggal, key=len, reverse=True)
      # if array is empty return news date
      if(len(sortedTimes) == 0):
            tanggal_asli=newsDate
            # print(newsDate)
      # if array not empty and not contain kemarin
      elif (len(sortedTimes) >= 1):
            tanggal_asli=compareDateArray(sortedTimes,newsDate)
            print(tanggal_asli)
            # print(compareDateArray(sortedTimes,newsDate))

      lokasi2 = compareToDatasetLocation(provinsi,kabupaten,kecamatan)

      
      if(len(orang)==0):
            trueTopik=0
      else:
            trueTopik=1
      if(tanggal_asli is not None):
            trueTanggal=1
      else:
            trueTanggal=0
      if(lokasi2[2]=='-' and lokasi2[1]=='-' and lokasi2[0]=='-'):
            trueLokasi=0
      else:
            trueLokasi=1

      document_results.append([
      orang,
      trueTopik,
      tanggal_asli,
      trueTanggal,
      df_test.iloc[i,1],
      lokasi2[2],
      lokasi2[1],
      lokasi2[0],
      trueLokasi,
      '',
      '',
      '',
      news,
      ])

writer = pd.DataFrame(document_results, columns=['Who','True Who','When','True When','date','Provinsi','Kabupaten','Kecamatan','True Where', 'True Positif', 'True Negative', 'Relevansi Berita', 'Skimming News'])
writer.to_excel('result/result.xlsx', index=False)
# Out:
# 0
# newsDate :  14/5/2022
# sortByLength :  ['jumat (13/5/2022)', 'kamis (12/5)', 'rabu (11/5)']
# tempTime :  jumat (13/5/2022)
# currTime :  13/5/2022 <class 'str'>
# currTime2 :  13/5/2022
# splitted :  ['13', '5', '2022']
# tempTime :  kamis (12/5)
# currTime :  12/5 <class 'str'>
# currTime2 :  12/5
# splitted :  ['12', '5']
# tempTime :  rabu (11/5)
# currTime :  11/5 <class 'str'>
# currTime2 :  11/5
# splitted :  ['11', '5']
# [1652374800, 1652288400, 1652202000]
# 11/05/2022
# ['semarang', 'jawa tengah']
# 1
# newsDate :  19/5/2022
# sortByLength :  ['selasa (17/5/2022)', 'selasa (15/4)', 'rabu (4/5)']
# tempTime :  selasa (17/5/2022)
# currTime :  17/5/2022 <class 'str'>
# currTime2 :  17/5/2022
# splitted :  ['17', '5', '2022']
# tempTime :  selasa (15/4)
# currTime :  15/4 <class 'str'>
# currTime2 :  15/4
# splitted :  ['15', '4']
# tempTime :  rabu (4/5)
# currTime :  4/5 <class 'str'>
# currTime2 :  4/5
# splitted :  ['4', '5']
# [1652720400, 1649955600, 1651597200]
# 15/04/2022
# ['senen', 'jakarta pusat']
# 2
# newsDate :  24/4/2022
# sortByLength :  ['minggu (24/4/2022)', 'sabtu (23/4/2022)']
# tempTime :  minggu (24/4/2022)
# currTime :  24/4/2022 <class 'str'>
# currTime2 :  24/4/2022
# splitted :  ['24', '4', '2022']
# tempTime :  sabtu (23/4/2022)
# currTime :  23/4/2022 <class 'str'>
# currTime2 :  23/4/2022
# splitted :  ['23', '4', '2022']
# [1650733200, 1650646800]
# 23/04/2022
# ['medan']
# 3
# newsDate :  05/2/2022
# sortByLength :  ['sabtu (5/2/2022)']
# tempTime :  sabtu (5/2/2022)
# currTime :  5/2/2022 <class 'str'>
# currTime2 :  5/2/2022
# splitted :  ['5', '2', '2022']
# [1643994000]
# 05/02/2022
# ['bekasi']
# 4
# newsDate :  20/5/2022
# sortByLength :  ['jumat (20/5/2022)']
# tempTime :  jumat (20/5/2022)
# currTime :  20/5/2022 <class 'str'>
# currTime2 :  20/5/2022
# splitted :  ['20', '5', '2022']
# [1652979600]
# 20/05/2022
# ['sulawesi selatan']
# 5
# newsDate :  31/5/2022
# sortByLength :  ['selasa (31/5/2022)']
# tempTime :  selasa (31/5/2022)
# currTime :  31/5/2022 <class 'str'>
# currTime2 :  31/5/2022
# splitted :  ['31', '5', '2022']
# [1653930000]
# 31/05/2022
# ['tangerang']
# 6
# newsDate :  12/4/2022
# sortByLength :  ['senin (11/4/2022)']
# tempTime :  senin (11/4/2022)
# currTime :  11/4/2022 <class 'str'>
# currTime2 :  11/4/2022
# splitted :  ['11', '4', '2022']
# [1649610000]
# 11/04/2022
# ['majalengka', 'jawa barat']
# 7
# newsDate :  14/4/2022
# sortByLength :  ['kamis (14/4/2022)']
# tempTime :  kamis (14/4/2022)
# currTime :  14/4/2022 <class 'str'>
# currTime2 :  14/4/2022
# splitted :  ['14', '4', '2022']
# [1649869200]
# 14/04/2022
# []
# 8
# newsDate :  23/2/2022
# sortByLength :  ['rabu (23/2/2022)', 'selasa (22/2)', 'senin (21/2)']
# tempTime :  rabu (23/2/2022)
# currTime :  23/2/2022 <class 'str'>
# currTime2 :  23/2/2022
# splitted :  ['23', '2', '2022']
# tempTime :  selasa (22/2)
# currTime :  22/2 <class 'str'>
# currTime2 :  22/2
# splitted :  ['22', '2']
# tempTime :  senin (21/2)
# currTime :  21/2 <class 'str'>
# currTime2 :  21/2
# splitted :  ['21', '2']
# [1645549200, 1645462800, 1645376400]
# 21/02/2022
# ['mojokerto']
# 9
# newsDate :  28/4/2022
# sortByLength :  ['kamis (28/4/2022)']
# tempTime :  kamis (28/4/2022)
# currTime :  28/4/2022 <class 'str'>
# currTime2 :  28/4/2022
# splitted :  ['28', '4', '2022']
# [1651078800]
# 28/04/2022
# ['fatuleu', 'kupang', 'nusa tenggara timur']
# 10
# newsDate :  19/4/2022
# sortByLength :  ['minggu (17/4/2022)', 'senin (18/4/2022)', 'sabtu (16/4)']
# tempTime :  minggu (17/4/2022)
# currTime :  17/4/2022 <class 'str'>
# currTime2 :  17/4/2022
# splitted :  ['17', '4', '2022']
# tempTime :  senin (18/4/2022)
# currTime :  18/4/2022 <class 'str'>
# currTime2 :  18/4/2022
# splitted :  ['18', '4', '2022']
# tempTime :  sabtu (16/4)
# currTime :  16/4 <class 'str'>
# currTime2 :  16/4
# splitted :  ['16', '4']
# [1650128400, 1650214800, 1650042000]
# 16/04/2022
# ['sulawesi utara']
# 11
# newsDate :  10/6/2022
# sortByLength :  ['jumat (10/6/2022)', 'rabu (8/6)']
# tempTime :  jumat (10/6/2022)
# currTime :  10/6/2022 <class 'str'>
# currTime2 :  10/6/2022
# splitted :  ['10', '6', '2022']
# tempTime :  rabu (8/6)
# currTime :  8/6 <class 'str'>
# currTime2 :  8/6
# splitted :  ['8', '6']
# [1654794000, 1654621200]
# 08/06/2022
# ['medan']
# 12
# newsDate :  20/4/2022
# sortByLength :  ['rabu (20/4/2022)', 'kamis (14/4)']
# tempTime :  rabu (20/4/2022)
# currTime :  20/4/2022 <class 'str'>
# currTime2 :  20/4/2022
# splitted :  ['20', '4', '2022']
# tempTime :  kamis (14/4)
# currTime :  14/4 <class 'str'>
# currTime2 :  14/4
# splitted :  ['14', '4']
# [1650387600, 1649869200]
# 14/04/2022
# ['konawe', 'sulawesi tenggara']
# 13
# newsDate :  02/6/2022
# sortByLength :  ['rabu (1/6/2022)', 'selasa (31/5)']
# tempTime :  rabu (1/6/2022)
# currTime :  1/6/2022 <class 'str'>
# currTime2 :  1/6/2022
# splitted :  ['1', '6', '2022']
# tempTime :  selasa (31/5)
# currTime :  31/5 <class 'str'>
# currTime2 :  31/5
# splitted :  ['31', '5']
# [1654016400, 1653930000]
# 31/05/2022
# ['kolaka utara', 'sulawesi tenggara']
# 14
# newsDate :  17/5/2022
# sortByLength :  ['selasa (17/5/3022)']
# tempTime :  selasa (17/5/3022)
# currTime :  17/5/3022 <class 'str'>
# currTime2 :  17/5/3022
# splitted :  ['17', '5', '3022']
# [33209629200]
# 17/05/3022
# ['rancasari', 'bandung']
# 15
# newsDate :  25/3/2022
# sortByLength :  ['jumat (25/3/2022)']
# tempTime :  jumat (25/3/2022)
# currTime :  25/3/2022 <class 'str'>
# currTime2 :  25/3/2022
# splitted :  ['25', '3', '2022']
# [1648141200]
# 25/03/2022
# ['ciracap', 'sukabumi']
# 16
# newsDate :  11/6/2022
# sortByLength :  ['sabtu (11/6/2022)', 'jumat (10/6)']
# tempTime :  sabtu (11/6/2022)
# currTime :  11/6/2022 <class 'str'>
# currTime2 :  11/6/2022
# splitted :  ['11', '6', '2022']
# tempTime :  jumat (10/6)
# currTime :  10/6 <class 'str'>
# currTime2 :  10/6
# splitted :  ['10', '6']
# [1654880400, 1654794000]
# 10/06/2022
# ['semarang', 'jawa tengah']
# 17
# newsDate :  26/5/2021
# sortByLength :  ['selasa (25/5/2021)', 'selasa \\(25/5\\)', 'selasa (25/5)']
# tempTime :  selasa (25/5/2021)
# currTime :  25/5/2021 <class 'str'>
# currTime2 :  25/5/2021
# splitted :  ['25', '5', '2021']
# tempTime :  selasa \(25/5\)
# currTime :  25/5 <class 'str'>
# currTime2 :  25/5
# splitted :  ['25', '5']
# tempTime :  selasa (25/5)
# currTime :  25/5 <class 'str'>
# currTime2 :  25/5
# splitted :  ['25', '5']
# [1621875600, 1621875600, 1621875600]
# 25/05/2021
# ['jakarta pusat']
# 18
# newsDate :  19/5/2022
# sortByLength :  ['kamis (19/5/2022)']
# tempTime :  kamis (19/5/2022)
# currTime :  19/5/2022 <class 'str'>
# currTime2 :  19/5/2022
# splitted :  ['19', '5', '2022']
# [1652893200]
# 19/05/2022
# []
# 19
# newsDate :  11/2/2022
# sortByLength :  ['jumat (11/02/2022)', 'rabu (26/1)']
# tempTime :  jumat (11/02/2022)
# currTime :  11/02/2022 <class 'str'>
# currTime2 :  11/02/2022
# splitted :  ['11', '02', '2022']
# tempTime :  rabu (26/1)
# currTime :  26/1 <class 'str'>
# currTime2 :  26/1
# splitted :  ['26', '1']
# [1644512400, 1643130000]
# 26/01/2022
# ['bandungan', 'semarang']
# 20
# newsDate :  31/5/2022
# sortByLength :  ['selasa (31/5/2022)']
# tempTime :  selasa (31/5/2022)
# currTime :  31/5/2022 <class 'str'>
# currTime2 :  31/5/2022
# splitted :  ['31', '5', '2022']
# [1653930000]
# 31/05/2022
# ['tangerang']
# 21
# newsDate :  18/5/2022
# sortByLength :  ['rabu (18/5/2022)', 'selasa (17/5)', 'rabu (4/5)']
# tempTime :  rabu (18/5/2022)
# currTime :  18/5/2022 <class 'str'>
# currTime2 :  18/5/2022
# splitted :  ['18', '5', '2022']
# tempTime :  selasa (17/5)
# currTime :  17/5 <class 'str'>
# currTime2 :  17/5
# splitted :  ['17', '5']
# tempTime :  rabu (4/5)
# currTime :  4/5 <class 'str'>
# currTime2 :  4/5
# splitted :  ['4', '5']
# [1652806800, 1652720400, 1651597200]
# 04/05/2022
# ['senen', 'jakarta pusat']
# 22
# newsDate :  30/5/2022
# sortByLength :  ['minggu (29/5/2022)', 'senin (30/05/2022)']
# tempTime :  minggu (29/5/2022)
# currTime :  29/5/2022 <class 'str'>
# currTime2 :  29/5/2022
# splitted :  ['29', '5', '2022']
# tempTime :  senin (30/05/2022)
# currTime :  30/05/2022 <class 'str'>
# currTime2 :  30/05/2022
# splitted :  ['30', '05', '2022']
# [1653757200, 1653843600]
# 29/05/2022
# []
# 23
# newsDate :  21/3/2022
# sortByLength :  ['selasa (28/12/2021)', 'senin (21/3/2022)', 'kamis (']
# tempTime :  selasa (28/12/2021)
# currTime :  28/12/2021 <class 'str'>
# currTime2 :  28/12/2021
# splitted :  ['28', '12', '2021']
# tempTime :  senin (21/3/2022)
# currTime :  21/3/2022 <class 'str'>
# currTime2 :  21/3/2022
# splitted :  ['21', '3', '2022']
# tempTime :  kamis (
# currTime :   <class 'str'>
# 21/3/2022
# ['bogor', 'jawa barat']
# 24
# []
# 25
# newsDate :  14/4/2022
# sortByLength :  ['kamis (14/4/2022)', 'sabtu (9/4/2022)']
# tempTime :  kamis (14/4/2022)
# currTime :  14/4/2022 <class 'str'>
# currTime2 :  14/4/2022
# splitted :  ['14', '4', '2022']
# tempTime :  sabtu (9/4/2022)
# currTime :  9/4/2022 <class 'str'>
# currTime2 :  9/4/2022
# splitted :  ['9', '4', '2022']
# [1649869200, 1649437200]
# 09/04/2022
# ['cilandak', 'jakarta selatan']
# 26
# newsDate :  28/3/2022
# sortByLength :  ['minggu (28/3/2022)', 'senin (28/3/2022)']
# tempTime :  minggu (28/3/2022)
# currTime :  28/3/2022 <class 'str'>
# currTime2 :  28/3/2022
# splitted :  ['28', '3', '2022']
# tempTime :  senin (28/3/2022)
# currTime :  28/3/2022 <class 'str'>
# currTime2 :  28/3/2022
# splitted :  ['28', '3', '2022']
# [1648400400, 1648400400]
# 28/03/2022
# ['surabaya']
# 27
# newsDate :  22/5/2022
# sortByLength :  ['senin (16/5/2022)']
# tempTime :  senin (16/5/2022)
# currTime :  16/5/2022 <class 'str'>
# currTime2 :  16/5/2022
# splitted :  ['16', '5', '2022']
# [1652634000]
# 16/05/2022
# ['buleleng']
# 28
# newsDate :  07/4/2022
# sortByLength :  ['kamis (7/4/2022)']
# tempTime :  kamis (7/4/2022)
# currTime :  7/4/2022 <class 'str'>
# currTime2 :  7/4/2022
# splitted :  ['7', '4', '2022']
# [1649264400]
# 07/04/2022
# ['cilandak', 'jakarta selatan']
# 29
# newsDate :  17/5/2022
# sortByLength :  ['selasa (17/5/2022)']
# tempTime :  selasa (17/5/2022)
# currTime :  17/5/2022 <class 'str'>
# currTime2 :  17/5/2022
# splitted :  ['17', '5', '2022']
# [1652720400]
# 17/05/2022
# ['minahasa', 'sulawesi utara']
# 30
# newsDate :  27/5/2022
# sortByLength :  ['jumat (27/5/2022)', '8 mei 2022']
# tempTime :  jumat (27/5/2022)
# currTime :  27/5/2022 <class 'str'>
# currTime2 :  27/5/2022
# splitted :  ['27', '5', '2022']
# tempTime :  8 mei 2022
# currTime :  None <class 'NoneType'>
# 27/5/2022
# ['punggelan', 'banjarnegara', 'jawa tengah']
# 31
# newsDate :  25/10/2021
# sortByLength :  ['senin (25/10/2021)']
# tempTime :  senin (25/10/2021)
# currTime :  25/10/2021 <class 'str'>
# currTime2 :  25/10/2021
# splitted :  ['25', '10', '2021']
# [1635094800]
# 25/10/2021
# []
# 32
# newsDate :  21/5/2022
# sortByLength :  ['sabtu (21/5/2022)', 'jumat (20/5)']
# tempTime :  sabtu (21/5/2022)
# currTime :  21/5/2022 <class 'str'>
# currTime2 :  21/5/2022
# splitted :  ['21', '5', '2022']
# tempTime :  jumat (20/5)
# currTime :  20/5 <class 'str'>
# currTime2 :  20/5
# splitted :  ['20', '5']
# [1653066000, 1652979600]
# 20/05/2022
# ['makassar']
# 33
# newsDate :  18/5/2022
# sortByLength :  ['minggu siang (15/5)', 'selasa (17/5/2022)']
# tempTime :  minggu siang (15/5)
# currTime :  15/5 <class 'str'>
# currTime2 :  15/5
# splitted :  ['15', '5']
# tempTime :  selasa (17/5/2022)
# currTime :  17/5/2022 <class 'str'>
# currTime2 :  17/5/2022
# splitted :  ['17', '5', '2022']
# [1652547600, 1652720400]
# 15/05/2022
# ['balikpapan', 'kalimantan timur']
# 34
# newsDate :  25/3/2022
# sortByLength :  ['jumat (11/3)']
# tempTime :  jumat (11/3)
# currTime :  11/3 <class 'str'>
# currTime2 :  11/3
# splitted :  ['11', '3']
# [1646931600]
# 11/03/2022
# ['sulawesi selatan']
# 35
# newsDate :  14/6/2022
# sortByLength :  ['selasa (14/6/2022)', 'kamis (9/6/2022)', 'sabtu (11/6)']
# tempTime :  selasa (14/6/2022)
# currTime :  14/6/2022 <class 'str'>
# currTime2 :  14/6/2022
# splitted :  ['14', '6', '2022']
# tempTime :  kamis (9/6/2022)
# currTime :  9/6/2022 <class 'str'>
# currTime2 :  9/6/2022
# splitted :  ['9', '6', '2022']
# tempTime :  sabtu (11/6)
# currTime :  11/6 <class 'str'>
# currTime2 :  11/6
# splitted :  ['11', '6']
# [1655139600, 1654707600, 1654880400]
# 09/06/2022
# ['denpasar']
# 36
# newsDate :  19/3/2022
# sortByLength :  ['sabtu (19/3/2022', 'selasa (16/3', 'senin (15/3']
# tempTime :  sabtu (19/3/2022
# currTime :  19/3/2022 <class 'str'>
# currTime2 :  19/3/2022
# splitted :  ['19', '3', '2022']
# tempTime :  selasa (16/3
# currTime :  16/3 <class 'str'>
# currTime2 :  16/3
# splitted :  ['16', '3']
# tempTime :  senin (15/3
# currTime :  15/3 <class 'str'>
# currTime2 :  15/3
# splitted :  ['15', '3']
# [1647622800, 1647363600, 1647277200]
# 15/03/2022
# ['mowila', 'konawe selatan', 'sulawesi tenggara']
# 37
# newsDate :  24/4/2022
# sortByLength :  ['selasa (12/4/2022)']
# tempTime :  selasa (12/4/2022)
# currTime :  12/4/2022 <class 'str'>
# currTime2 :  12/4/2022
# splitted :  ['12', '4', '2022']
# [1649696400]
# 12/04/2022
# ['tangerang']
# 38
# newsDate :  24/2/2022
# sortByLength :  ['kamis (24/2/2022)', 'rabu (24/2/2022)']
# tempTime :  kamis (24/2/2022)
# currTime :  24/2/2022 <class 'str'>
# currTime2 :  24/2/2022
# splitted :  ['24', '2', '2022']
# tempTime :  rabu (24/2/2022)
# currTime :  24/2/2022 <class 'str'>
# currTime2 :  24/2/2022
# splitted :  ['24', '2', '2022']
# [1645635600, 1645635600]
# 24/02/2022
# ['pasuruan']
# 39
# newsDate :  29/3/2022
# sortByLength :  ['selasa (29/3/2022)']
# tempTime :  selasa (29/3/2022)
# currTime :  29/3/2022 <class 'str'>
# currTime2 :  29/3/2022
# splitted :  ['29', '3', '2022']
# [1648486800]
# 29/03/2022
# ['semarang']
# 40
# newsDate :  15/4/2022
# sortByLength :  ['selasa (12/4/2022)']
# tempTime :  selasa (12/4/2022)
# currTime :  12/4/2022 <class 'str'>
# currTime2 :  12/4/2022
# splitted :  ['12', '4', '2022']
# [1649696400]
# 12/04/2022
# ['lombok tengah', 'nusa tenggara barat']
# 41
# newsDate :  18/5/2022
# sortByLength :  ['selasa (17/5/2022)']
# tempTime :  selasa (17/5/2022)
# currTime :  17/5/2022 <class 'str'>
# currTime2 :  17/5/2022
# splitted :  ['17', '5', '2022']
# [1652720400]
# 17/05/2022
# ['pagerageung', 'tasikmalaya']
# 42
# newsDate :  21/4/2022
# sortByLength :  ['kamis (21/4/2022)', 'minggu (27/3)', 'jumat (8/4)', 'rabu (20/4)', 'jufri (']
# tempTime :  kamis (21/4/2022)
# currTime :  21/4/2022 <class 'str'>
# currTime2 :  21/4/2022
# splitted :  ['21', '4', '2022']
# tempTime :  minggu (27/3)
# currTime :  27/3 <class 'str'>
# currTime2 :  27/3
# splitted :  ['27', '3']
# tempTime :  jumat (8/4)
# currTime :  8/4 <class 'str'>
# currTime2 :  8/4
# splitted :  ['8', '4']
# tempTime :  rabu (20/4)
# currTime :  20/4 <class 'str'>
# currTime2 :  20/4
# splitted :  ['20', '4']
# tempTime :  jufri (
# currTime :   <class 'str'>
# 21/4/2022
# []
# 43
# newsDate :  06/9/2019
# sortByLength :  ['kamis (5/9/2019)']
# tempTime :  kamis (5/9/2019)
# currTime :  5/9/2019 <class 'str'>
# currTime2 :  5/9/2019
# splitted :  ['5', '9', '2019']
# [1567616400]
# 05/09/2019
# ['matakali']
# 44
# newsDate :  17/4/2022
# sortByLength :  ['minggu (17/4/2022)', 'sabtu (16/4/2022)']
# tempTime :  minggu (17/4/2022)
# currTime :  17/4/2022 <class 'str'>
# currTime2 :  17/4/2022
# splitted :  ['17', '4', '2022']
# tempTime :  sabtu (16/4/2022)
# currTime :  16/4/2022 <class 'str'>
# currTime2 :  16/4/2022
# splitted :  ['16', '4', '2022']
# [1650128400, 1650042000]
# 16/04/2022
# ['ogan ilir', 'sumatera selatan']
# 45
# newsDate :  29/4/2022
# sortByLength :  ['kamis (28/4/2022)']
# tempTime :  kamis (28/4/2022)
# currTime :  28/4/2022 <class 'str'>
# currTime2 :  28/4/2022
# splitted :  ['28', '4', '2022']
# [1651078800]
# 28/04/2022
# []
# 46
# newsDate :  24/1/2022
# sortByLength :  ['senin (24/1/2022)', 'senin pagi tadi']
# tempTime :  senin (24/1/2022)
# currTime :  24/1/2022 <class 'str'>
# currTime2 :  24/1/2022
# splitted :  ['24', '1', '2022']
# tempTime :  senin pagi tadi
# currTime :  None <class 'NoneType'>
# 24/1/2022
# ['malang']
# 47
# newsDate :  02/6/2022
# sortByLength :  ['kamis (2/6/2022)', 'rabu (1/6/2022)']
# tempTime :  kamis (2/6/2022)
# currTime :  2/6/2022 <class 'str'>
# currTime2 :  2/6/2022
# splitted :  ['2', '6', '2022']
# tempTime :  rabu (1/6/2022)
# currTime :  1/6/2022 <class 'str'>
# currTime2 :  1/6/2022
# splitted :  ['1', '6', '2022']
# [1654102800, 1654016400]
# 01/06/2022
# ['cilincing', 'jakarta utara']
# 48
# newsDate :  30/4/2022
# sortByLength :  ['sabtu (30/4/2022)', 'ferdy (35)']
# tempTime :  sabtu (30/4/2022)
# currTime :  30/4/2022 <class 'str'>
# currTime2 :  30/4/2022
# splitted :  ['30', '4', '2022']
# tempTime :  ferdy (35)
# currTime :  35 <class 'str'>
# currTime2 :  35
# splitted :  ['35']
# [1651251600]
# 30/04/2022
# ['lampung']
# 49
# newsDate :  17/5/2022
# sortByLength :  ['senin (16/5/2022)', 'senin (16/5)']
# tempTime :  senin (16/5/2022)
# currTime :  16/5/2022 <class 'str'>
# currTime2 :  16/5/2022
# splitted :  ['16', '5', '2022']
# tempTime :  senin (16/5)
# currTime :  16/5 <class 'str'>
# currTime2 :  16/5
# splitted :  ['16', '5']
# [1652634000, 1652634000]
# 16/05/2022
# ['bekasi']
# 50
# newsDate :  15/4/2022
# sortByLength :  ['rabu (13/4)']
# tempTime :  rabu (13/4)
# currTime :  13/4 <class 'str'>
# currTime2 :  13/4
# splitted :  ['13', '4']
# [1649782800]
# 13/04/2022
# ['bulukumba', 'sulawesi selatan']
# 51
# newsDate :  04/5/2022
# sortByLength :  ['rabu (4/5/2022)']
# tempTime :  rabu (4/5/2022)
# currTime :  4/5/2022 <class 'str'>
# currTime2 :  4/5/2022
# splitted :  ['4', '5', '2022']
# [1651597200]
# 04/05/2022
# ['bandung']
# 52
# newsDate :  04/4/2022
# sortByLength :  ['senin (4/4/2022)', 'rabu (30/3/2022)', 'minggu (3/4)']
# tempTime :  senin (4/4/2022)
# currTime :  4/4/2022 <class 'str'>
# currTime2 :  4/4/2022
# splitted :  ['4', '4', '2022']
# tempTime :  rabu (30/3/2022)
# currTime :  30/3/2022 <class 'str'>
# currTime2 :  30/3/2022
# splitted :  ['30', '3', '2022']
# tempTime :  minggu (3/4)
# currTime :  3/4 <class 'str'>
# currTime2 :  3/4
# splitted :  ['3', '4']
# [1649005200, 1648573200, 1648918800]
# 30/03/2022
# ['jawa barat']
# 53
# newsDate :  04/5/2022
# sortByLength :  ['sabtu (30/4/2022)', 'selasa (3/5/2022)', 'senin (2/5/2022)', 'rabu (4/5/2022)']
# tempTime :  sabtu (30/4/2022)
# currTime :  30/4/2022 <class 'str'>
# currTime2 :  30/4/2022
# splitted :  ['30', '4', '2022']
# tempTime :  selasa (3/5/2022)
# currTime :  3/5/2022 <class 'str'>
# currTime2 :  3/5/2022
# splitted :  ['3', '5', '2022']
# tempTime :  senin (2/5/2022)
# currTime :  2/5/2022 <class 'str'>
# currTime2 :  2/5/2022
# splitted :  ['2', '5', '2022']
# tempTime :  rabu (4/5/2022)
# currTime :  4/5/2022 <class 'str'>
# currTime2 :  4/5/2022
# splitted :  ['4', '5', '2022']
# [1651251600, 1651510800, 1651424400, 1651597200]
# 30/04/2022
# []
# 54
# newsDate :  20/4/2022
# sortByLength :  ['rabu (20/4/2022)']
# tempTime :  rabu (20/4/2022)
# currTime :  20/4/2022 <class 'str'>
# currTime2 :  20/4/2022
# splitted :  ['20', '4', '2022']
# [1650387600]
# 20/04/2022
# ['lombok tengah']
# 55
# newsDate :  31/12/2021
# sortByLength :  ['jumat (31/12/2021)']
# tempTime :  jumat (31/12/2021)
# currTime :  31/12/2021 <class 'str'>
# currTime2 :  31/12/2021
# splitted :  ['31', '12', '2021']
# [1640883600]
# 31/12/2021
# ['salatiga', 'jawa tengah']
# 56
# newsDate :  29/3/2022
# sortByLength :  ['selasa (29/3/2022)', 'minggu (27/3)']
# tempTime :  selasa (29/3/2022)
# currTime :  29/3/2022 <class 'str'>
# currTime2 :  29/3/2022
# splitted :  ['29', '3', '2022']
# tempTime :  minggu (27/3)
# currTime :  27/3 <class 'str'>
# currTime2 :  27/3
# splitted :  ['27', '3']
# [1648486800, 1648314000]
# 27/03/2022
# ['surabaya']
# 57
# newsDate :  02/4/2022
# sortByLength :  ['jumat (1/4/2022)']
# tempTime :  jumat (1/4/2022)
# currTime :  1/4/2022 <class 'str'>
# currTime2 :  1/4/2022
# splitted :  ['1', '4', '2022']
# [1648746000]
# 01/04/2022
# ['surabaya']
# 58
# newsDate :  11/4/2022
# sortByLength :  ['senin (11/4/2022)']
# tempTime :  senin (11/4/2022)
# currTime :  11/4/2022 <class 'str'>
# currTime2 :  11/4/2022
# splitted :  ['11', '4', '2022']
# [1649610000]
# 11/04/2022
# ['surabaya']
# 59
# newsDate :  15/5/2022
# sortByLength :  ['minggu (15/5/2022)']
# tempTime :  minggu (15/5/2022)
# currTime :  15/5/2022 <class 'str'>
# currTime2 :  15/5/2022
# splitted :  ['15', '5', '2022']
# [1652547600]
# 15/05/2022
# ['bekasi']
# 60
# newsDate :  11/5/2022
# sortByLength :  ['rabu (11/5/2022)', 'minggu (8/5)']
# tempTime :  rabu (11/5/2022)
# currTime :  11/5/2022 <class 'str'>
# currTime2 :  11/5/2022
# splitted :  ['11', '5', '2022']
# tempTime :  minggu (8/5)
# currTime :  8/5 <class 'str'>
# currTime2 :  8/5
# splitted :  ['8', '5']
# [1652202000, 1651942800]
# 08/05/2022
# ['sumatera utara']
# 61
# newsDate :  26/2/2022
# sortByLength :  ['sabtu (26/2/2022)']
# tempTime :  sabtu (26/2/2022)
# currTime :  26/2/2022 <class 'str'>
# currTime2 :  26/2/2022
# splitted :  ['26', '2', '2022']
# [1645808400]
# 26/02/2022
# ['malang']
# 62
# newsDate :  12/12/2021
# sortByLength :  ['minggu (12/12/2021)']
# tempTime :  minggu (12/12/2021)
# currTime :  12/12/2021 <class 'str'>
# currTime2 :  12/12/2021
# splitted :  ['12', '12', '2021']
# [1639242000]
# 12/12/2021
# ['manado']
# 63
# newsDate :  26/5/2022
# sortByLength :  ['kamis (26/5/2022)']
# tempTime :  kamis (26/5/2022)
# currTime :  26/5/2022 <class 'str'>
# currTime2 :  26/5/2022
# splitted :  ['26', '5', '2022']
# [1653498000]
# 26/05/2022
# ['demak']
# 64
# newsDate :  18/5/2022
# sortByLength :  ['rabu (18/5/2022)']
# tempTime :  rabu (18/5/2022)
# currTime :  18/5/2022 <class 'str'>
# currTime2 :  18/5/2022
# splitted :  ['18', '5', '2022']
# [1652806800]
# 18/05/2022
# ['kendal']
# 65
# newsDate :  13/5/2022
# sortByLength :  ['kamis (12/5/2022)', 'minggu (8/5)']
# tempTime :  kamis (12/5/2022)
# currTime :  12/5/2022 <class 'str'>
# currTime2 :  12/5/2022
# splitted :  ['12', '5', '2022']
# tempTime :  minggu (8/5)
# currTime :  8/5 <class 'str'>
# currTime2 :  8/5
# splitted :  ['8', '5']
# [1652288400, 1651942800]
# 08/05/2022
# ['bogor', 'jawa barat']
# 66
# newsDate :  19/5/2022
# sortByLength :  ['kamis (19/5/2022)', 'kamis, 19']
# tempTime :  kamis (19/5/2022)
# currTime :  19/5/2022 <class 'str'>
# currTime2 :  19/5/2022
# splitted :  ['19', '5', '2022']
# tempTime :  kamis, 19
# currTime :  None <class 'NoneType'>
# 19/5/2022
# ['jakarta selatan']
# 67
# newsDate :  25/11/2021
# sortByLength :  ['kamis (25/11/2021)']
# tempTime :  kamis (25/11/2021)
# currTime :  25/11/2021 <class 'str'>
# currTime2 :  25/11/2021
# splitted :  ['25', '11', '2021']
# [1637773200]
# 25/11/2021
# ['jakarta utara']
# 68
# newsDate :  17/12/2021
# sortByLength :  ['jumat (17/12/2021)']
# tempTime :  jumat (17/12/2021)
# currTime :  17/12/2021 <class 'str'>
# currTime2 :  17/12/2021
# splitted :  ['17', '12', '2021']
# [1639674000]
# 17/12/2021
# ['jakarta barat']
# 69
# newsDate :  09/4/2022
# sortByLength :  ['sabtu (9/4/2022)', 'jumat (8/4)']
# tempTime :  sabtu (9/4/2022)
# currTime :  9/4/2022 <class 'str'>
# currTime2 :  9/4/2022
# splitted :  ['9', '4', '2022']
# tempTime :  jumat (8/4)
# currTime :  8/4 <class 'str'>
# currTime2 :  8/4
# splitted :  ['8', '4']
# [1649437200, 1649350800]
# 08/04/2022
# ['cilandak', 'jakarta selatan']
# 70
# newsDate :  16/6/2022
# sortByLength :  ['kamis (16/6/2022)']
# tempTime :  kamis (16/6/2022)
# currTime :  16/6/2022 <class 'str'>
# currTime2 :  16/6/2022
# splitted :  ['16', '6', '2022']
# [1655312400]
# 16/06/2022
# ['bima']
# 71
# newsDate :  19/4/2022
# sortByLength :  ['selasa (19/4/2022)', 'senin (18/4)']
# tempTime :  selasa (19/4/2022)
# currTime :  19/4/2022 <class 'str'>
# currTime2 :  19/4/2022
# splitted :  ['19', '4', '2022']
# tempTime :  senin (18/4)
# currTime :  18/4 <class 'str'>
# currTime2 :  18/4
# splitted :  ['18', '4']
# [1650301200, 1650214800]
# 18/04/2022
# ['sidoarjo']
# 72
# newsDate :  14/6/2022
# sortByLength :  ['selasa (14/6/2022)']
# tempTime :  selasa (14/6/2022)
# currTime :  14/6/2022 <class 'str'>
# currTime2 :  14/6/2022
# splitted :  ['14', '6', '2022']
# [1655139600]
# 14/06/2022
# []
# 73
# newsDate :  13/12/2021
# sortByLength :  ['selasa (7/12)']
# tempTime :  selasa (7/12)
# currTime :  7/12 <class 'str'>
# currTime2 :  7/12
# splitted :  ['7', '12']
# [1638810000]
# 07/12/2021
# ['jakarta timur']
# 74
# newsDate :  23/2/2022
# sortByLength :  ['rabu (23/2/2022)', 'senin (21/2)']
# tempTime :  rabu (23/2/2022)
# currTime :  23/2/2022 <class 'str'>
# currTime2 :  23/2/2022
# splitted :  ['23', '2', '2022']
# tempTime :  senin (21/2)
# currTime :  21/2 <class 'str'>
# currTime2 :  21/2
# splitted :  ['21', '2']
# [1645549200, 1645376400]
# 21/02/2022
# ['ngoro', 'mojokerto']
# 75
# newsDate :  12/11/2021
# sortByLength :  ['jumat (12/11/2021)']
# tempTime :  jumat (12/11/2021)
# currTime :  12/11/2021 <class 'str'>
# currTime2 :  12/11/2021
# splitted :  ['12', '11', '2021']
# [1636650000]
# 12/11/2021
# ['probolinggo']
# 76
# newsDate :  22/5/2022
# sortByLength :  ['minggu (22/5/2022)', 'selasa (17/5/2022)', 'senin (16/5/2022)']
# tempTime :  minggu (22/5/2022)
# currTime :  22/5/2022 <class 'str'>
# currTime2 :  22/5/2022
# splitted :  ['22', '5', '2022']
# tempTime :  selasa (17/5/2022)
# currTime :  17/5/2022 <class 'str'>
# currTime2 :  17/5/2022
# splitted :  ['17', '5', '2022']
# tempTime :  senin (16/5/2022)
# currTime :  16/5/2022 <class 'str'>
# currTime2 :  16/5/2022
# splitted :  ['16', '5', '2022']
# [1653152400, 1652720400, 1652634000]
# 16/05/2022
# ['negara']
# 77
# newsDate :  26/1/2022
# sortByLength :  ['kamis (20/1/2022)', 'rabu (26/1)']
# tempTime :  kamis (20/1/2022)
# currTime :  20/1/2022 <class 'str'>
# currTime2 :  20/1/2022
# splitted :  ['20', '1', '2022']
# tempTime :  rabu (26/1)
# currTime :  26/1 <class 'str'>
# currTime2 :  26/1
# splitted :  ['26', '1']
# [1642611600, 1643130000]
# 20/01/2022
# ['tangerang']
# 78
# newsDate :  02/6/2022
# sortByLength :  ['kamis (2/6/2022)', 'rabu (1/6)']
# tempTime :  kamis (2/6/2022)
# currTime :  2/6/2022 <class 'str'>
# currTime2 :  2/6/2022
# splitted :  ['2', '6', '2022']
# tempTime :  rabu (1/6)
# currTime :  1/6 <class 'str'>
# currTime2 :  1/6
# splitted :  ['1', '6']
# [1654102800, 1654016400]
# 01/06/2022
# ['batu bara', 'sumatera utara']
# 79
# newsDate :  18/4/2022
# sortByLength :  ['senin (18/4/2022)']
# tempTime :  senin (18/4/2022)
# currTime :  18/4/2022 <class 'str'>
# currTime2 :  18/4/2022
# splitted :  ['18', '4', '2022']
# [1650214800]
# 18/04/2022
# ['berau', 'kalimantan timur']
# 80
# newsDate :  29/3/2022
# sortByLength :  ['selasa (29/3/2022)']
# tempTime :  selasa (29/3/2022)
# currTime :  29/3/2022 <class 'str'>
# currTime2 :  29/3/2022
# splitted :  ['29', '3', '2022']
# [1648486800]
# 29/03/2022
# ['surabaya']
# 81
# newsDate :  30/3/2022
# sortByLength :  ['selasa (29/3/2022)']
# tempTime :  selasa (29/3/2022)
# currTime :  29/3/2022 <class 'str'>
# currTime2 :  29/3/2022
# splitted :  ['29', '3', '2022']
# [1648486800]
# 29/03/2022
# ['surabaya']
# 82
# newsDate :  04/6/2022
# sortByLength :  ['sabtu (4/6/2022)', 'kamis (2/6)', 'jumat (3/6)']
# tempTime :  sabtu (4/6/2022)
# currTime :  4/6/2022 <class 'str'>
# currTime2 :  4/6/2022
# splitted :  ['4', '6', '2022']
# tempTime :  kamis (2/6)
# currTime :  2/6 <class 'str'>
# currTime2 :  2/6
# splitted :  ['2', '6']
# tempTime :  jumat (3/6)
# currTime :  3/6 <class 'str'>
# currTime2 :  3/6
# splitted :  ['3', '6']
# [1654275600, 1654102800, 1654189200]
# 02/06/2022
# ['jakarta timur']
# 83
# newsDate :  27/2/2022
# sortByLength :  ['minggu (27/2/2022)']
# tempTime :  minggu (27/2/2022)
# currTime :  27/2/2022 <class 'str'>
# currTime2 :  27/2/2022
# splitted :  ['27', '2', '2022']
# [1645894800]
# 27/02/2022
# ['kadipaten', 'majalengka', 'jawa barat']
# 84
# newsDate :  07/2/2022
# sortByLength :  ['senin (7/2/2022)', 'kamis (3/2)']
# tempTime :  senin (7/2/2022)
# currTime :  7/2/2022 <class 'str'>
# currTime2 :  7/2/2022
# splitted :  ['7', '2', '2022']
# tempTime :  kamis (3/2)
# currTime :  3/2 <class 'str'>
# currTime2 :  3/2
# splitted :  ['3', '2']
# [1644166800, 1643821200]
# 03/02/2022
# ['jakarta pusat']
# 85
# newsDate :  04/4/2022
# sortByLength :  ['senin (4/4/2022)']
# tempTime :  senin (4/4/2022)
# currTime :  4/4/2022 <class 'str'>
# currTime2 :  4/4/2022
# splitted :  ['4', '4', '2022']
# [1649005200]
# 04/04/2022
# ['bandung']
# 86
# newsDate :  10/5/2022
# sortByLength :  ['sabtu (7/5/2022)', 'senin (9/5)']
# tempTime :  sabtu (7/5/2022)
# currTime :  7/5/2022 <class 'str'>
# currTime2 :  7/5/2022
# splitted :  ['7', '5', '2022']
# tempTime :  senin (9/5)
# currTime :  9/5 <class 'str'>
# currTime2 :  9/5
# splitted :  ['9', '5']
# [1651856400, 1652029200]
# 07/05/2022
# ['kebayoran baru', 'jakarta selatan']
# 87
# newsDate :  06/4/2022
# sortByLength :  ['rabu (6/4/2022)', 'jumat (8/4)']
# tempTime :  rabu (6/4/2022)
# currTime :  6/4/2022 <class 'str'>
# currTime2 :  6/4/2022
# splitted :  ['6', '4', '2022']
# tempTime :  jumat (8/4)
# currTime :  8/4 <class 'str'>
# currTime2 :  8/4
# splitted :  ['8', '4']
# [1649178000, 1649350800]
# 06/04/2022
# ['cilandak', 'jakarta selatan']
# 88
# newsDate :  16/4/2022
# sortByLength :  ['sabtu (16/4/2022)', 'rabu (14/4)']
# tempTime :  sabtu (16/4/2022)
# currTime :  16/4/2022 <class 'str'>
# currTime2 :  16/4/2022
# splitted :  ['16', '4', '2022']
# tempTime :  rabu (14/4)
# currTime :  14/4 <class 'str'>
# currTime2 :  14/4
# splitted :  ['14', '4']
# [1650042000, 1649869200]
# 14/04/2022
# ['pabuaran', 'sukabumi']
# 89
# newsDate :  30/12/2021
# sortByLength :  ['kamis (30/12/2021)', 'selasa (28/12)', 'selasa (14/12)', 'senin (13/12)']
# tempTime :  kamis (30/12/2021)
# currTime :  30/12/2021 <class 'str'>
# currTime2 :  30/12/2021
# splitted :  ['30', '12', '2021']
# tempTime :  selasa (28/12)
# currTime :  28/12 <class 'str'>
# currTime2 :  28/12
# splitted :  ['28', '12']
# tempTime :  selasa (14/12)
# currTime :  14/12 <class 'str'>
# currTime2 :  14/12
# splitted :  ['14', '12']
# tempTime :  senin (13/12)
# currTime :  13/12 <class 'str'>
# currTime2 :  13/12
# splitted :  ['13', '12']
# [1640797200, 1640624400, 1639414800, 1639328400]
# 13/12/2021
# ['jakarta timur']
# 90
# newsDate :  18/4/2022
# sortByLength :  ['selasa (5/4/2022)', 'senin (18/4)', 'senin (18/3)']
# tempTime :  selasa (5/4/2022)
# currTime :  5/4/2022 <class 'str'>
# currTime2 :  5/4/2022
# splitted :  ['5', '4', '2022']
# tempTime :  senin (18/4)
# currTime :  18/4 <class 'str'>
# currTime2 :  18/4
# splitted :  ['18', '4']
# tempTime :  senin (18/3)
# currTime :  18/3 <class 'str'>
# currTime2 :  18/3
# splitted :  ['18', '3']
# [1649091600, 1650214800, 1647536400]
# 18/03/2022
# ['jakarta selatan']
# 91
# newsDate :  20/4/2022
# sortByLength :  ['kamis (20/4/2022)', 'rabu (20/4/2022)']
# tempTime :  kamis (20/4/2022)
# currTime :  20/4/2022 <class 'str'>
# currTime2 :  20/4/2022
# splitted :  ['20', '4', '2022']
# tempTime :  rabu (20/4/2022)
# currTime :  20/4/2022 <class 'str'>
# currTime2 :  20/4/2022
# splitted :  ['20', '4', '2022']
# [1650387600, 1650387600]
# 20/04/2022
# ['bogor', 'jawa barat']
# 92
# newsDate :  20/4/2022
# sortByLength :  ['rabu (20/4/2022)', 'selasa (19/4)']
# tempTime :  rabu (20/4/2022)
# currTime :  20/4/2022 <class 'str'>
# currTime2 :  20/4/2022
# splitted :  ['20', '4', '2022']
# tempTime :  selasa (19/4)
# currTime :  19/4 <class 'str'>
# currTime2 :  19/4
# splitted :  ['19', '4']
# [1650387600, 1650301200]
# 19/04/2022
# ['tangerang']
# 93
# newsDate :  01/6/2022
# sortByLength :  ['selasa (31/5/2022)', 'rabu (18/5/2022)']
# tempTime :  selasa (31/5/2022)
# currTime :  31/5/2022 <class 'str'>
# currTime2 :  31/5/2022
# splitted :  ['31', '5', '2022']
# tempTime :  rabu (18/5/2022)
# currTime :  18/5/2022 <class 'str'>
# currTime2 :  18/5/2022
# splitted :  ['18', '5', '2022']
# [1653930000, 1652806800]
# 18/05/2022
# ['cakranegara']
# 94
# newsDate :  28/5/2022
# sortByLength :  ['jumat (27/5/2022)', 'rabu (25/5/2022)']
# tempTime :  jumat (27/5/2022)
# currTime :  27/5/2022 <class 'str'>
# currTime2 :  27/5/2022
# splitted :  ['27', '5', '2022']
# tempTime :  rabu (25/5/2022)
# currTime :  25/5/2022 <class 'str'>
# currTime2 :  25/5/2022
# splitted :  ['25', '5', '2022']
# [1653584400, 1653411600]
# 25/05/2022
# ['soppeng', 'sulawesi selatan']
# 95
# ['sleman']
# 96
# newsDate :  16/6/2022
# sortByLength :  ['kamis (16/6/2022)']
# tempTime :  kamis (16/6/2022)
# currTime :  16/6/2022 <class 'str'>
# currTime2 :  16/6/2022
# splitted :  ['16', '6', '2022']
# [1655312400]
# 16/06/2022
# ['bekasi']
# 97
# newsDate :  27/3/2022
# sortByLength :  ['minggu (6/3/2022)', 'kamis (24/3)']
# tempTime :  minggu (6/3/2022)
# currTime :  6/3/2022 <class 'str'>
# currTime2 :  6/3/2022
# splitted :  ['6', '3', '2022']
# tempTime :  kamis (24/3)
# currTime :  24/3 <class 'str'>
# currTime2 :  24/3
# splitted :  ['24', '3']
# [1646499600, 1648054800]
# 06/03/2022
# ['tangerang', 'banten']
# 98
# newsDate :  13/6/2022
# sortByLength :  ['sabtu tanggal 11 juni 2022', 'senin (13/6/2022)', 'rabu (8/6/2022)']
# tempTime :  sabtu tanggal 11 juni 2022
# currTime :  None <class 'NoneType'>
# 13/6/2022
# ['bekasi']
# 99
# newsDate :  31/1/2022
# sortByLength :  ['kamis 20 januari 2022', 'senin (31/1/2022)']
# tempTime :  kamis 20 januari 2022
# currTime :  None <class 'NoneType'>
# 31/1/2022
# ['ngawi']
# 100
# newsDate :  06/2/2022
# sortByLength :  ['sabtu (5/2/2022)', 'sabtu (5/2)']
# tempTime :  sabtu (5/2/2022)
# currTime :  5/2/2022 <class 'str'>
# currTime2 :  5/2/2022
# splitted :  ['5', '2', '2022']
# tempTime :  sabtu (5/2)
# currTime :  5/2 <class 'str'>
# currTime2 :  5/2
# splitted :  ['5', '2']
# [1643994000, 1643994000]
# 05/02/2022
# ['pasuruan']
# 101
# newsDate :  07/6/2018
# sortByLength :  ['kamis (7/6/2018)']
# tempTime :  kamis (7/6/2018)
# currTime :  7/6/2018 <class 'str'>
# currTime2 :  7/6/2018
# splitted :  ['7', '6', '2018']
# [1528304400]
# 07/06/2018
# ['jakarta timur']
# 102
# newsDate :  03/4/2022
# sortByLength :  ['sabtu (02/04/2022)']
# tempTime :  sabtu (02/04/2022)
# currTime :  02/04/2022 <class 'str'>
# currTime2 :  02/04/2022
# splitted :  ['02', '04', '2022']
# [1648832400]
# 02/04/2022
# ['purwakarta']
# 103
# newsDate :  28/4/2022
# sortByLength :  ['rabu, tanggal 20 april 2022', 'kamis (28/4/2022)']
# tempTime :  rabu, tanggal 20 april 2022
# currTime :  None <class 'NoneType'>
# 28/4/2022
# ['boyolali']
# 104
# newsDate :  01/6/2022
# sortByLength :  ['rabu (1/6/2022)', 'selasa (31/5)']
# tempTime :  rabu (1/6/2022)
# currTime :  1/6/2022 <class 'str'>
# currTime2 :  1/6/2022
# splitted :  ['1', '6', '2022']
# tempTime :  selasa (31/5)
# currTime :  31/5 <class 'str'>
# currTime2 :  31/5
# splitted :  ['31', '5']
# [1654016400, 1653930000]
# 31/05/2022
# ['cileungsi', 'bogor']
# 105
# newsDate :  02/6/2022
# sortByLength :  ['sabtu (28/5/2022)', 'rabu (1/6/2022)', 'jumat (27/5)']
# tempTime :  sabtu (28/5/2022)
# currTime :  28/5/2022 <class 'str'>
# currTime2 :  28/5/2022
# splitted :  ['28', '5', '2022']
# tempTime :  rabu (1/6/2022)
# currTime :  1/6/2022 <class 'str'>
# currTime2 :  1/6/2022
# splitted :  ['1', '6', '2022']
# tempTime :  jumat (27/5)
# currTime :  27/5 <class 'str'>
# currTime2 :  27/5
# splitted :  ['27', '5']
# [1653670800, 1654016400, 1653584400]
# 27/05/2022
# ['kembangan', 'jakarta barat']
# 106
# newsDate :  19/5/2022
# sortByLength :  ['kamis (19/5/2022)']
# tempTime :  kamis (19/5/2022)
# currTime :  19/5/2022 <class 'str'>
# currTime2 :  19/5/2022
# splitted :  ['19', '5', '2022']
# [1652893200]
# 19/05/2022
# ['jawa barat']
# 107
# newsDate :  01/4/2022
# sortByLength :  ['kamis (31/3/2022)', 'rabu (30/3/2022)']
# tempTime :  kamis (31/3/2022)
# currTime :  31/3/2022 <class 'str'>
# currTime2 :  31/3/2022
# splitted :  ['31', '3', '2022']
# tempTime :  rabu (30/3/2022)
# currTime :  30/3/2022 <class 'str'>
# currTime2 :  30/3/2022
# splitted :  ['30', '3', '2022']
# [1648659600, 1648573200]
# 30/03/2022
# ['surabaya']
# 108
# newsDate :  09/5/2022
# sortByLength :  ['senin (9/5/2022)', 'senin (9/4)', 'sabtu (7/5)']
# tempTime :  senin (9/5/2022)
# currTime :  9/5/2022 <class 'str'>
# currTime2 :  9/5/2022
# splitted :  ['9', '5', '2022']
# tempTime :  senin (9/4)
# currTime :  9/4 <class 'str'>
# currTime2 :  9/4
# splitted :  ['9', '4']
# tempTime :  sabtu (7/5)
# currTime :  7/5 <class 'str'>
# currTime2 :  7/5
# splitted :  ['7', '5']
# [1652029200, 1649437200, 1651856400]
# 09/04/2022
# ['kebayoran baru', 'jakarta selatan']
# 109
# newsDate :  14/3/2022
# sortByLength :  ['minggu (13/3/2022)', 'senin (14/3/2022)']
# tempTime :  minggu (13/3/2022)
# currTime :  13/3/2022 <class 'str'>
# currTime2 :  13/3/2022
# splitted :  ['13', '3', '2022']
# tempTime :  senin (14/3/2022)
# currTime :  14/3/2022 <class 'str'>
# currTime2 :  14/3/2022
# splitted :  ['14', '3', '2022']
# [1647104400, 1647190800]
# 13/03/2022
# ['sumenep']
# 110
# newsDate :  31/3/2022
# sortByLength :  ['kamis (31/3/2022)', 'rabu (30/3/2022)']
# tempTime :  kamis (31/3/2022)
# currTime :  31/3/2022 <class 'str'>
# currTime2 :  31/3/2022
# splitted :  ['31', '3', '2022']
# tempTime :  rabu (30/3/2022)
# currTime :  30/3/2022 <class 'str'>
# currTime2 :  30/3/2022
# splitted :  ['30', '3', '2022']
# [1648659600, 1648573200]
# 30/03/2022
# ['surabaya']
# 111
# newsDate :  16/4/2022
# sortByLength :  ['sabtu (16/4/2022)', 'r (']
# tempTime :  sabtu (16/4/2022)
# currTime :  16/4/2022 <class 'str'>
# currTime2 :  16/4/2022
# splitted :  ['16', '4', '2022']
# tempTime :  r (
# currTime :   <class 'str'>
# 16/4/2022
# ['bogor', 'jawa barat']
# 112
# newsDate :  05/4/2022
# sortByLength :  ['sabtu (21/8/2021)']
# tempTime :  sabtu (21/8/2021)
# currTime :  21/8/2021 <class 'str'>
# currTime2 :  21/8/2021
# splitted :  ['21', '8', '2021']
# [1629478800]
# 21/08/2021
# ['tangerang', 'banten']
# 113
# newsDate :  01/4/2022
# sortByLength :  ['jumat (1/4/2022)', 'rabu (30/3/2022)']
# tempTime :  jumat (1/4/2022)
# currTime :  1/4/2022 <class 'str'>
# currTime2 :  1/4/2022
# splitted :  ['1', '4', '2022']
# tempTime :  rabu (30/3/2022)
# currTime :  30/3/2022 <class 'str'>
# currTime2 :  30/3/2022
# splitted :  ['30', '3', '2022']
# [1648746000, 1648573200]
# 30/03/2022
# ['surabaya']
# 114
# newsDate :  06/5/2022
# sortByLength :  ['jumat (6/5/2022)', 'sabtu (30/4)']
# tempTime :  jumat (6/5/2022)
# currTime :  6/5/2022 <class 'str'>
# currTime2 :  6/5/2022
# splitted :  ['6', '5', '2022']
# tempTime :  sabtu (30/4)
# currTime :  30/4 <class 'str'>
# currTime2 :  30/4
# splitted :  ['30', '4']
# [1651770000, 1651251600]
# 30/04/2022
# ['bekasi', 'jawa barat']
# 115
# newsDate :  19/4/2022
# sortByLength :  ['selasa (19/4/2022)']
# tempTime :  selasa (19/4/2022)
# currTime :  19/4/2022 <class 'str'>
# currTime2 :  19/4/2022
# splitted :  ['19', '4', '2022']
# [1650301200]
# 19/04/2022
# ['bekasi']
# 116
# newsDate :  09/6/2022
# sortByLength :  ['kamis (9/6/2022)', 'senin (30/5)', 'rabu (8/6)']
# tempTime :  kamis (9/6/2022)
# currTime :  9/6/2022 <class 'str'>
# currTime2 :  9/6/2022
# splitted :  ['9', '6', '2022']
# tempTime :  senin (30/5)
# currTime :  30/5 <class 'str'>
# currTime2 :  30/5
# splitted :  ['30', '5']
# tempTime :  rabu (8/6)
# currTime :  8/6 <class 'str'>
# currTime2 :  8/6
# splitted :  ['8', '6']
# [1654707600, 1653843600, 1654621200]
# 30/05/2022
# ['sumbang', 'banyumas']
# 117
# newsDate :  05/6/2022
# sortByLength :  ['kamis tanggal 16 desember 2021', 'minggu (05/06/2022)', 'minggu (5/6/2022)']
# tempTime :  kamis tanggal 16 desember 2021
# currTime :  None <class 'NoneType'>
# 05/6/2022
# []
# 118
# newsDate :  29/8/2020
# sortByLength :  ['sabtu (29/8/2020)', 'senin (24/8)', 'sabtu (15/8)']
# tempTime :  sabtu (29/8/2020)
# currTime :  29/8/2020 <class 'str'>
# currTime2 :  29/8/2020
# splitted :  ['29', '8', '2020']
# tempTime :  senin (24/8)
# currTime :  24/8 <class 'str'>
# currTime2 :  24/8
# splitted :  ['24', '8']
# tempTime :  sabtu (15/8)
# currTime :  15/8 <class 'str'>
# currTime2 :  15/8
# splitted :  ['15', '8']
# [1598634000, 1598202000, 1597424400]
# 15/08/2020
# ['medan']
# 119
# newsDate :  16/5/2022
# sortByLength :  ['sabtu siang (14/5)', 'senin (16/5/2022)', 'jumat (13/5)', 'sabtu (14/5)']
# tempTime :  sabtu siang (14/5)
# currTime :  14/5 <class 'str'>
# currTime2 :  14/5
# splitted :  ['14', '5']
# tempTime :  senin (16/5/2022)
# currTime :  16/5/2022 <class 'str'>
# currTime2 :  16/5/2022
# splitted :  ['16', '5', '2022']
# tempTime :  jumat (13/5)
# currTime :  13/5 <class 'str'>
# currTime2 :  13/5
# splitted :  ['13', '5']
# tempTime :  sabtu (14/5)
# currTime :  14/5 <class 'str'>
# currTime2 :  14/5
# splitted :  ['14', '5']
# [1652461200, 1652634000, 1652374800, 1652461200]
# 13/05/2022
# ['sulawesi barat']
# 120
# newsDate :  16/4/2022
# sortByLength :  ['sabtu (16/4/2022)']
# tempTime :  sabtu (16/4/2022)
# currTime :  16/4/2022 <class 'str'>
# currTime2 :  16/4/2022
# splitted :  ['16', '4', '2022']
# [1650042000]
# 16/04/2022
# ['bekasi']
# 121
# newsDate :  10/3/2022
# sortByLength :  ['kamis (10/3/2022)', 'selasa (8/3/2022)', 'rabu (2/3)']
# tempTime :  kamis (10/3/2022)
# currTime :  10/3/2022 <class 'str'>
# currTime2 :  10/3/2022
# splitted :  ['10', '3', '2022']
# tempTime :  selasa (8/3/2022)
# currTime :  8/3/2022 <class 'str'>
# currTime2 :  8/3/2022
# splitted :  ['8', '3', '2022']
# tempTime :  rabu (2/3)
# currTime :  2/3 <class 'str'>
# currTime2 :  2/3
# splitted :  ['2', '3']
# [1646845200, 1646672400, 1646154000]
# 02/03/2022
# ['barito kuala', 'kalimantan selatan']
# 122
# newsDate :  27/1/2022
# sortByLength :  ['kamis (20/1/2022)', 'selasa (25/1)']
# tempTime :  kamis (20/1/2022)
# currTime :  20/1/2022 <class 'str'>
# currTime2 :  20/1/2022
# splitted :  ['20', '1', '2022']
# tempTime :  selasa (25/1)
# currTime :  25/1 <class 'str'>
# currTime2 :  25/1
# splitted :  ['25', '1']
# [1642611600, 1643043600]
# 20/01/2022
# ['tangerang']
# 123
# newsDate :  14/6/2022
# sortByLength :  ['senin (13/6/2022)', 'minggu (12/6)']
# tempTime :  senin (13/6/2022)
# currTime :  13/6/2022 <class 'str'>
# currTime2 :  13/6/2022
# splitted :  ['13', '6', '2022']
# tempTime :  minggu (12/6)
# currTime :  12/6 <class 'str'>
# currTime2 :  12/6
# splitted :  ['12', '6']
# [1655053200, 1654966800]
# 12/06/2022
# ['probolinggo']
# 124
# newsDate :  06/6/2022
# sortByLength :  ['senin (6/6/2022)']
# tempTime :  senin (6/6/2022)
# currTime :  6/6/2022 <class 'str'>
# currTime2 :  6/6/2022
# splitted :  ['6', '6', '2022']
# [1654448400]
# 06/06/2022
# ['sumatera utara']
# 125
# newsDate :  02/2/2022
# sortByLength :  ['rabu (2/2/2022)', 'senin (1/2)']
# tempTime :  rabu (2/2/2022)
# currTime :  2/2/2022 <class 'str'>
# currTime2 :  2/2/2022
# splitted :  ['2', '2', '2022']
# tempTime :  senin (1/2)
# currTime :  1/2 <class 'str'>
# currTime2 :  1/2
# splitted :  ['1', '2']
# [1643734800, 1643648400]
# 01/02/2022
# ['penjaringan', 'jakarta utara']
# 126
# newsDate :  11/3/2022
# sortByLength :  ['jumat (11/3/2022)', 'selasa (8/3)']
# tempTime :  jumat (11/3/2022)
# currTime :  11/3/2022 <class 'str'>
# currTime2 :  11/3/2022
# splitted :  ['11', '3', '2022']
# tempTime :  selasa (8/3)
# currTime :  8/3 <class 'str'>
# currTime2 :  8/3
# splitted :  ['8', '3']
# [1646931600, 1646672400]
# 08/03/2022
# ['bekasi']
# 127
# newsDate :  11/4/2022
# sortByLength :  ['senin (11/4/2022)']
# tempTime :  senin (11/4/2022)
# currTime :  11/4/2022 <class 'str'>
# currTime2 :  11/4/2022
# splitted :  ['11', '4', '2022']
# [1649610000]
# 11/04/2022
# ['tabanan']
# 128
# newsDate :  15/6/2022
# sortByLength :  ['rabu (15/6/2022)', 'selasa (14/6)']
# tempTime :  rabu (15/6/2022)
# currTime :  15/6/2022 <class 'str'>
# currTime2 :  15/6/2022
# splitted :  ['15', '6', '2022']
# tempTime :  selasa (14/6)
# currTime :  14/6 <class 'str'>
# currTime2 :  14/6
# splitted :  ['14', '6']
# [1655226000, 1655139600]
# 14/06/2022
# ['klaten', 'jawa tengah']
# 129
# newsDate :  28/5/2022
# sortByLength :  ['sabtu (28/5/2022)', 'selasa (3/5)', 'jumat (']
# tempTime :  sabtu (28/5/2022)
# currTime :  28/5/2022 <class 'str'>
# currTime2 :  28/5/2022
# splitted :  ['28', '5', '2022']
# tempTime :  selasa (3/5)
# currTime :  3/5 <class 'str'>
# currTime2 :  3/5
# splitted :  ['3', '5']
# tempTime :  jumat (
# currTime :   <class 'str'>
# 28/5/2022
# ['konawe', 'sulawesi tenggara']
# 130
# newsDate :  28/4/2022
# sortByLength :  ['rabu (27/4/2022)', 'sabtu (2/4)']
# tempTime :  rabu (27/4/2022)
# currTime :  27/4/2022 <class 'str'>
# currTime2 :  27/4/2022
# splitted :  ['27', '4', '2022']
# tempTime :  sabtu (2/4)
# currTime :  2/4 <class 'str'>
# currTime2 :  2/4
# splitted :  ['2', '4']
# [1650992400, 1648832400]
# 02/04/2022
# ['sulawesi tenggara']
# 131
# newsDate :  12/3/2022
# sortByLength :  ['jumat (11/3/2022)', 'selasa (8/3)']
# tempTime :  jumat (11/3/2022)
# currTime :  11/3/2022 <class 'str'>
# currTime2 :  11/3/2022
# splitted :  ['11', '3', '2022']
# tempTime :  selasa (8/3)
# currTime :  8/3 <class 'str'>
# currTime2 :  8/3
# splitted :  ['8', '3']
# [1646931600, 1646672400]
# 08/03/2022
# ['bekasi']
# 132
# newsDate :  26/4/2022
# sortByLength :  ['selasa (26/4/2022)']
# tempTime :  selasa (26/4/2022)
# currTime :  26/4/2022 <class 'str'>
# currTime2 :  26/4/2022
# splitted :  ['26', '4', '2022']
# [1650906000]
# 26/04/2022
# ['cibadak', 'sukabumi']
# 133
# newsDate :  20/1/2022
# sortByLength :  ['kamis (20/1/2022)', 'senin (3/1)']
# tempTime :  kamis (20/1/2022)
# currTime :  20/1/2022 <class 'str'>
# currTime2 :  20/1/2022
# splitted :  ['20', '1', '2022']
# tempTime :  senin (3/1)
# currTime :  3/1 <class 'str'>
# currTime2 :  3/1
# splitted :  ['3', '1']
# [1642611600, 1641142800]
# 03/01/2022
# ['banyuasin', 'sumatera selatan']
# 134
# newsDate :  04/6/2022
# sortByLength :  ['sabtu (4/6/2022)']
# tempTime :  sabtu (4/6/2022)
# currTime :  4/6/2022 <class 'str'>
# currTime2 :  4/6/2022
# splitted :  ['4', '6', '2022']
# [1654275600]
# 04/06/2022
# ['jakarta timur']

# %%
# PERSON:      People, including fictional.
# NORP:        Nationalities or religious or political groups.
# FAC:         Buildings, airports, highways, bridges, etc.
# ORG:         Companies, agencies, institutions, etc.
# GPE:         Countries, cities, states.
# LOC:         Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# EVENT:       Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# LAW:         Named documents made into laws.
# LANGUAGE:    Any named language.
# DATE:        Absolute or relative dates or periods.
# TIME:        Times smaller than a day.
# PERCENT:     Percentage, including ”%“.
# MONEY:       Monetary values, including unit.
# QUANTITY:    Measurements, as of weight or distance.
# ORDINAL:     “first”, “second”, etc.
# CARDINAL:    Numerals that do not fall under another type.
